# %% [markdown]
# # Data Preparation

# %% [markdown]
# ## Why do this step?
#
# - The data we scraped from the UFC website is raw data. Every row contains information about a fight that took place i.e. details like how many strikes were thrown in that fight and who won the fight.
# - To prepare the data for prediction, every row can contain only an accurate representation of what each fighter has done in fights up until that fight! No data that was recorded during the fight can be present in that row.
# - Our Target variable is Winner. The task has to be to predict the winner from the data available of each fighter up until the fight

# %% [markdown]
# ## Looking at the data

# %%
import pandas as pd
import numpy as np
import math

df = pd.read_csv('../data/total_fight_data.csv', sep=';')
fighter_details = pd.read_csv('../data/fighter_details.csv', index_col='fighter_name')

# %%
df.head()
# Out:
#            R_fighter           B_fighter  R_KD  B_KD  R_SIG_STR. B_SIG_STR.  \
# 0       Brian Ortega      Chan Sung Jung     2     0  127 of 212  62 of 163
# 1  Katlyn Chookagian     Jessica Andrade     0     1    19 of 53   28 of 43
# 2        Jimmy Crute  Modestas Bukauskas     2     0    17 of 24    7 of 17
# 3      Claudio Silva        James Krause     0     0   64 of 214  94 of 159
# 4     Thomas Almeida   Jonathan Martinez     0     0   64 of 171  73 of 205
#
#   R_SIG_STR_pct B_SIG_STR_pct R_TOTAL_STR. B_TOTAL_STR.  ... B_GROUND  \
# 0           59%           38%   129 of 214    64 of 166  ...   0 of 0
# 1           35%           65%     27 of 61     62 of 79  ...   6 of 6
# 2           70%           41%     18 of 25      7 of 17  ...   0 of 0
# 3           29%           59%    66 of 216    96 of 162  ...   0 of 0
# 4           37%           35%    64 of 171    73 of 205  ...   0 of 0
#
#                  win_by last_round last_round_time             Format  \
# 0  Decision - Unanimous          5            5:00  5 Rnd (5-5-5-5-5)
# 1                KO/TKO          1            4:55      3 Rnd (5-5-5)
# 2                KO/TKO          1            2:01      3 Rnd (5-5-5)
# 3  Decision - Unanimous          3            5:00      3 Rnd (5-5-5)
# 4  Decision - Unanimous          3            5:00      3 Rnd (5-5-5)
#
#           Referee              date  \
# 0  Lukasz Bosacki  October 17, 2020
# 1  Lukasz Bosacki  October 17, 2020
# 2  Anders Ohlsson  October 17, 2020
# 3  Lukasz Bosacki  October 17, 2020
# 4  Anders Ohlsson  October 17, 2020
#
#                                      location              Fight_type  \
# 0  Abu Dhabi, Abu Dhabi, United Arab Emirates      Featherweight Bout
# 1  Abu Dhabi, Abu Dhabi, United Arab Emirates  Women's Flyweight Bout
# 2  Abu Dhabi, Abu Dhabi, United Arab Emirates  Light Heavyweight Bout
# 3  Abu Dhabi, Abu Dhabi, United Arab Emirates       Welterweight Bout
# 4  Abu Dhabi, Abu Dhabi, United Arab Emirates      Featherweight Bout
#
#               Winner
# 0       Brian Ortega
# 1    Jessica Andrade
# 2        Jimmy Crute
# 3       James Krause
# 4  Jonathan Martinez
#
# [5 rows x 41 columns]

# %%
df.T
# Out:
#                                                        0     \
# R_fighter                                      Brian Ortega
# B_fighter                                    Chan Sung Jung
# R_KD                                                      2
# B_KD                                                      0
# R_SIG_STR.                                       127 of 212
# B_SIG_STR.                                        62 of 163
# R_SIG_STR_pct                                           59%
# B_SIG_STR_pct                                           38%
# R_TOTAL_STR.                                     129 of 214
# B_TOTAL_STR.                                      64 of 166
# R_TD                                                3 of 10
# B_TD                                                 0 of 0
# R_TD_pct                                                30%
# B_TD_pct                                                ---
# R_SUB_ATT                                                 0
# B_SUB_ATT                                                 0
# R_REV                                                     0
# B_REV                                                     0
# R_CTRL                                                 0:57
# B_CTRL                                                 0:00
# R_HEAD                                            64 of 135
# B_HEAD                                            35 of 127
# R_BODY                                             22 of 28
# B_BODY                                             14 of 21
# R_LEG                                              41 of 49
# B_LEG                                              13 of 15
# R_DISTANCE                                       118 of 199
# B_DISTANCE                                        62 of 162
# R_CLINCH                                             5 of 7
# B_CLINCH                                             0 of 1
# R_GROUND                                             4 of 6
# B_GROUND                                             0 of 0
# win_by                                 Decision - Unanimous
# last_round                                                5
# last_round_time                                        5:00
# Format                                    5 Rnd (5-5-5-5-5)
# Referee                                      Lukasz Bosacki
# date                                       October 17, 2020
# location         Abu Dhabi, Abu Dhabi, United Arab Emirates
# Fight_type                               Featherweight Bout
# Winner                                         Brian Ortega
#
#                                                        1     \
# R_fighter                                 Katlyn Chookagian
# B_fighter                                   Jessica Andrade
# R_KD                                                      0
# B_KD                                                      1
# R_SIG_STR.                                         19 of 53
# B_SIG_STR.                                         28 of 43
# R_SIG_STR_pct                                           35%
# B_SIG_STR_pct                                           65%
# R_TOTAL_STR.                                       27 of 61
# B_TOTAL_STR.                                       62 of 79
# R_TD                                                 0 of 0
# B_TD                                                 2 of 3
# R_TD_pct                                                ---
# B_TD_pct                                                66%
# R_SUB_ATT                                                 0
# B_SUB_ATT                                                 0
# R_REV                                                     0
# B_REV                                                     0
# R_CTRL                                                 0:25
# B_CTRL                                                 2:26
# R_HEAD                                              7 of 35
# B_HEAD                                             11 of 24
# R_BODY                                             12 of 18
# B_BODY                                             11 of 12
# R_LEG                                                0 of 0
# B_LEG                                                6 of 7
# R_DISTANCE                                         10 of 41
# B_DISTANCE                                         14 of 28
# R_CLINCH                                            9 of 12
# B_CLINCH                                             8 of 9
# R_GROUND                                             0 of 0
# B_GROUND                                             6 of 6
# win_by                                               KO/TKO
# last_round                                                1
# last_round_time                                        4:55
# Format                                        3 Rnd (5-5-5)
# Referee                                      Lukasz Bosacki
# date                                       October 17, 2020
# location         Abu Dhabi, Abu Dhabi, United Arab Emirates
# Fight_type                           Women's Flyweight Bout
# Winner                                      Jessica Andrade
#
#                                                        2     \
# R_fighter                                       Jimmy Crute
# B_fighter                                Modestas Bukauskas
# R_KD                                                      2
# B_KD                                                      0
# R_SIG_STR.                                         17 of 24
# B_SIG_STR.                                          7 of 17
# R_SIG_STR_pct                                           70%
# B_SIG_STR_pct                                           41%
# R_TOTAL_STR.                                       18 of 25
# B_TOTAL_STR.                                        7 of 17
# R_TD                                                 0 of 1
# B_TD                                                 0 of 0
# R_TD_pct                                                 0%
# B_TD_pct                                                ---
# R_SUB_ATT                                                 0
# B_SUB_ATT                                                 0
# R_REV                                                     0
# B_REV                                                     0
# R_CTRL                                                 0:25
# B_CTRL                                                 0:00
# R_HEAD                                              8 of 14
# B_HEAD                                              2 of 11
# R_BODY                                               1 of 1
# B_BODY                                               2 of 3
# R_LEG                                                8 of 9
# B_LEG                                                3 of 3
# R_DISTANCE                                         14 of 21
# B_DISTANCE                                          7 of 17
# R_CLINCH                                             1 of 1
# B_CLINCH                                             0 of 0
# R_GROUND                                             2 of 2
# B_GROUND                                             0 of 0
# win_by                                               KO/TKO
# last_round                                                1
# last_round_time                                        2:01
# Format                                        3 Rnd (5-5-5)
# Referee                                      Anders Ohlsson
# date                                       October 17, 2020
# location         Abu Dhabi, Abu Dhabi, United Arab Emirates
# Fight_type                           Light Heavyweight Bout
# Winner                                          Jimmy Crute
#
#                                                        3     \
# R_fighter                                     Claudio Silva
# B_fighter                                      James Krause
# R_KD                                                      0
# B_KD                                                      0
# R_SIG_STR.                                        64 of 214
# B_SIG_STR.                                        94 of 159
# R_SIG_STR_pct                                           29%
# B_SIG_STR_pct                                           59%
# R_TOTAL_STR.                                      66 of 216
# B_TOTAL_STR.                                      96 of 162
# R_TD                                                2 of 12
# B_TD                                                 0 of 1
# R_TD_pct                                                16%
# B_TD_pct                                                 0%
# R_SUB_ATT                                                 0
# B_SUB_ATT                                                 0
# R_REV                                                     0
# B_REV                                                     0
# R_CTRL                                                 0:58
# B_CTRL                                                 0:14
# R_HEAD                                            30 of 143
# B_HEAD                                            73 of 135
# R_BODY                                             11 of 43
# B_BODY                                             18 of 21
# R_LEG                                              23 of 28
# B_LEG                                                3 of 3
# R_DISTANCE                                        64 of 214
# B_DISTANCE                                        94 of 159
# R_CLINCH                                             0 of 0
# B_CLINCH                                             0 of 0
# R_GROUND                                             0 of 0
# B_GROUND                                             0 of 0
# win_by                                 Decision - Unanimous
# last_round                                                3
# last_round_time                                        5:00
# Format                                        3 Rnd (5-5-5)
# Referee                                      Lukasz Bosacki
# date                                       October 17, 2020
# location         Abu Dhabi, Abu Dhabi, United Arab Emirates
# Fight_type                                Welterweight Bout
# Winner                                         James Krause
#
#                                                        4     \
# R_fighter                                    Thomas Almeida
# B_fighter                                 Jonathan Martinez
# R_KD                                                      0
# B_KD                                                      0
# R_SIG_STR.                                        64 of 171
# B_SIG_STR.                                        73 of 205
# R_SIG_STR_pct                                           37%
# B_SIG_STR_pct                                           35%
# R_TOTAL_STR.                                      64 of 171
# B_TOTAL_STR.                                      73 of 205
# R_TD                                                 0 of 5
# B_TD                                                 0 of 0
# R_TD_pct                                                 0%
# B_TD_pct                                                ---
# R_SUB_ATT                                                 0
# B_SUB_ATT                                                 0
# R_REV                                                     0
# B_REV                                                     0
# R_CTRL                                                 0:02
# B_CTRL                                                 0:00
# R_HEAD                                            33 of 127
# B_HEAD                                            53 of 170
# R_BODY                                             17 of 29
# B_BODY                                             18 of 33
# R_LEG                                              14 of 15
# B_LEG                                                2 of 2
# R_DISTANCE                                        56 of 163
# B_DISTANCE                                        69 of 201
# R_CLINCH                                             8 of 8
# B_CLINCH                                             4 of 4
# R_GROUND                                             0 of 0
# B_GROUND                                             0 of 0
# win_by                                 Decision - Unanimous
# last_round                                                3
# last_round_time                                        5:00
# Format                                        3 Rnd (5-5-5)
# Referee                                      Anders Ohlsson
# date                                       October 17, 2020
# location         Abu Dhabi, Abu Dhabi, United Arab Emirates
# Fight_type                               Featherweight Bout
# Winner                                    Jonathan Martinez
#
#                                                        5     \
# R_fighter                                    Mateusz Gamrot
# B_fighter                                 Guram Kutateladze
# R_KD                                                      0
# B_KD                                                      1
# R_SIG_STR.                                        52 of 126
# B_SIG_STR.                                         37 of 86
# R_SIG_STR_pct                                           41%
# B_SIG_STR_pct                                           43%
# R_TOTAL_STR.                                      69 of 151
# B_TOTAL_STR.                                       43 of 93
# R_TD                                                5 of 16
# B_TD                                                 0 of 1
# R_TD_pct                                                31%
# B_TD_pct                                                 0%
# R_SUB_ATT                                                 0
# B_SUB_ATT                                                 0
# R_REV                                                     0
# B_REV                                                     0
# R_CTRL                                                 3:29
# B_CTRL                                                 0:01
# R_HEAD                                            42 of 112
# B_HEAD                                             12 of 48
# R_BODY                                              6 of 10
# B_BODY                                             12 of 24
# R_LEG                                                4 of 4
# B_LEG                                              13 of 14
# R_DISTANCE                                        37 of 103
# B_DISTANCE                                         35 of 84
# R_CLINCH                                             4 of 4
# B_CLINCH                                             0 of 0
# R_GROUND                                           11 of 19
# B_GROUND                                             2 of 2
# win_by                                     Decision - Split
# last_round                                                3
# last_round_time                                        5:00
# Format                                        3 Rnd (5-5-5)
# Referee                                      Lukasz Bosacki
# date                                       October 17, 2020
# location         Abu Dhabi, Abu Dhabi, United Arab Emirates
# Fight_type                                 Lightweight Bout
# Winner                                    Guram Kutateladze
#
#                                                        6     \
# R_fighter                                 Gillian Robertson
# B_fighter                                   Poliana Botelho
# R_KD                                                      0
# B_KD                                                      0
# R_SIG_STR.                                         57 of 98
# B_SIG_STR.                                         22 of 43
# R_SIG_STR_pct                                           58%
# B_SIG_STR_pct                                           51%
# R_TOTAL_STR.                                     104 of 161
# B_TOTAL_STR.                                       39 of 61
# R_TD                                                 3 of 7
# B_TD                                                 0 of 0
# R_TD_pct                                                42%
# B_TD_pct                                                ---
# R_SUB_ATT                                                 0
# B_SUB_ATT                                                 0
# R_REV                                                     0
# B_REV                                                     0
# R_CTRL                                                 9:34
# B_CTRL                                                 1:16
# R_HEAD                                             43 of 77
# B_HEAD                                             11 of 32
# R_BODY                                              7 of 10
# B_BODY                                               8 of 8
# R_LEG                                               7 of 11
# B_LEG                                                3 of 3
# R_DISTANCE                                          9 of 30
# B_DISTANCE                                         15 of 35
# R_CLINCH                                             0 of 0
# B_CLINCH                                             4 of 5
# R_GROUND                                           48 of 68
# B_GROUND                                             3 of 3
# win_by                                 Decision - Unanimous
# last_round                                                3
# last_round_time                                        5:00
# Format                                        3 Rnd (5-5-5)
# Referee                                      Anders Ohlsson
# date                                       October 17, 2020
# location         Abu Dhabi, Abu Dhabi, United Arab Emirates
# Fight_type                           Women's Flyweight Bout
# Winner                                    Gillian Robertson
#
#                                                        7     \
# R_fighter                                      Junyong Park
# B_fighter                                     John Phillips
# R_KD                                                      0
# B_KD                                                      0
# R_SIG_STR.                                         10 of 21
# B_SIG_STR.                                          5 of 14
# R_SIG_STR_pct                                           47%
# B_SIG_STR_pct                                           35%
# R_TOTAL_STR.                                     260 of 350
# B_TOTAL_STR.                                       13 of 25
# R_TD                                                 4 of 4
# B_TD                                                 0 of 0
# R_TD_pct                                               100%
# B_TD_pct                                                ---
# R_SUB_ATT                                                 0
# B_SUB_ATT                                                 0
# R_REV                                                     0
# B_REV                                                     0
# R_CTRL                                                13:11
# B_CTRL                                                 0:00
# R_HEAD                                             10 of 21
# B_HEAD                                              1 of 10
# R_BODY                                               0 of 0
# B_BODY                                               2 of 2
# R_LEG                                                0 of 0
# B_LEG                                                2 of 2
# R_DISTANCE                                           2 of 2
# B_DISTANCE                                          5 of 14
# R_CLINCH                                             0 of 0
# B_CLINCH                                             0 of 0
# R_GROUND                                            8 of 19
# B_GROUND                                             0 of 0
# win_by                                 Decision - Unanimous
# last_round                                                3
# last_round_time                                        5:00
# Format                                        3 Rnd (5-5-5)
# Referee                                      Lukasz Bosacki
# date                                       October 17, 2020
# location         Abu Dhabi, Abu Dhabi, United Arab Emirates
# Fight_type                                Middleweight Bout
# Winner                                         Junyong Park
#
#                                                        8     \
# R_fighter                                   Jamie Mullarkey
# B_fighter                                        Fares Ziam
# R_KD                                                      0
# B_KD                                                      0
# R_SIG_STR.                                         20 of 72
# B_SIG_STR.                                         47 of 89
# R_SIG_STR_pct                                           27%
# B_SIG_STR_pct                                           52%
# R_TOTAL_STR.                                       29 of 84
# B_TOTAL_STR.                                       54 of 98
# R_TD                                                5 of 11
# B_TD                                                 1 of 5
# R_TD_pct                                                45%
# B_TD_pct                                                20%
# R_SUB_ATT                                                 0
# B_SUB_ATT                                                 0
# R_REV                                                     0
# B_REV                                                     2
# R_CTRL                                                 6:56
# B_CTRL                                                 1:12
# R_HEAD                                              7 of 51
# B_HEAD                                             34 of 76
# R_BODY                                               2 of 8
# B_BODY                                               4 of 4
# R_LEG                                              11 of 13
# B_LEG                                                9 of 9
# R_DISTANCE                                         18 of 65
# B_DISTANCE                                         35 of 72
# R_CLINCH                                             2 of 7
# B_CLINCH                                             6 of 8
# R_GROUND                                             0 of 0
# B_GROUND                                             6 of 9
# win_by                                 Decision - Unanimous
# last_round                                                3
# last_round_time                                        5:00
# Format                                        3 Rnd (5-5-5)
# Referee                                      Lukasz Bosacki
# date                                       October 17, 2020
# location         Abu Dhabi, Abu Dhabi, United Arab Emirates
# Fight_type                                 Lightweight Bout
# Winner                                           Fares Ziam
#
#                                                        9     ...  \
# R_fighter                             Gadzhimurad Antigulov  ...
# B_fighter                                     Maxim Grishin  ...
# R_KD                                                      0  ...
# B_KD                                                      0  ...
# R_SIG_STR.                                         12 of 23  ...
# B_SIG_STR.                                         34 of 76  ...
# R_SIG_STR_pct                                           52%  ...
# B_SIG_STR_pct                                           44%  ...
# R_TOTAL_STR.                                       31 of 44  ...
# B_TOTAL_STR.                                      66 of 126  ...
# R_TD                                                 1 of 5  ...
# B_TD                                                 1 of 1  ...
# R_TD_pct                                                20%  ...
# B_TD_pct                                               100%  ...
# R_SUB_ATT                                                 0  ...
# B_SUB_ATT                                                 0  ...
# R_REV                                                     0  ...
# B_REV                                                     0  ...
# R_CTRL                                                 2:39  ...
# B_CTRL                                                 2:21  ...
# R_HEAD                                              5 of 15  ...
# B_HEAD                                             20 of 61  ...
# R_BODY                                               4 of 5  ...
# B_BODY                                               6 of 7  ...
# R_LEG                                                3 of 3  ...
# B_LEG                                                8 of 8  ...
# R_DISTANCE                                          8 of 17  ...
# B_DISTANCE                                         22 of 45  ...
# R_CLINCH                                             3 of 5  ...
# B_CLINCH                                             3 of 6  ...
# R_GROUND                                             1 of 1  ...
# B_GROUND                                            9 of 25  ...
# win_by                                               KO/TKO  ...
# last_round                                                2  ...
# last_round_time                                        4:58  ...
# Format                                        3 Rnd (5-5-5)  ...
# Referee                                      Anders Ohlsson  ...
# date                                       October 17, 2020  ...
# location         Abu Dhabi, Abu Dhabi, United Arab Emirates  ...
# Fight_type                           Light Heavyweight Bout  ...
# Winner                                        Maxim Grishin  ...
#
#                                   5792                   5793  \
# R_fighter                Johnny Rhodes          Patrick Smith
# B_fighter                  Fred Ettish           Scott Morris
# R_KD                                 1                      0
# B_KD                                 0                      0
# R_SIG_STR.                    13 of 29               13 of 17
# B_SIG_STR.                      4 of 7                 0 of 0
# R_SIG_STR_pct                      44%                    76%
# B_SIG_STR_pct                      57%                    ---
# R_TOTAL_STR.                  21 of 38               19 of 25
# B_TOTAL_STR.                   7 of 11                 0 of 0
# R_TD                            0 of 0                 0 of 0
# B_TD                            0 of 0                 0 of 1
# R_TD_pct                           ---                    ---
# B_TD_pct                           ---                     0%
# R_SUB_ATT                            1                      0
# B_SUB_ATT                            0                      0
# R_REV                                0                      0
# B_REV                                0                      0
# R_CTRL                              --                     --
# B_CTRL                              --                     --
# R_HEAD                        12 of 28               12 of 16
# B_HEAD                          0 of 1                 0 of 0
# R_BODY                          0 of 0                 1 of 1
# B_BODY                          2 of 4                 0 of 0
# R_LEG                           1 of 1                 0 of 0
# B_LEG                           2 of 2                 0 of 0
# R_DISTANCE                      3 of 6                 0 of 0
# B_DISTANCE                      4 of 7                 0 of 0
# R_CLINCH                        1 of 2                 1 of 1
# B_CLINCH                        0 of 0                 0 of 0
# R_GROUND                       9 of 21               12 of 16
# B_GROUND                        0 of 0                 0 of 0
# win_by                      Submission                 KO/TKO
# last_round                           1                      1
# last_round_time                   3:07                   0:30
# Format                   No Time Limit          No Time Limit
# Referee                  John McCarthy          John McCarthy
# date                    March 11, 1994         March 11, 1994
# location         Denver, Colorado, USA  Denver, Colorado, USA
# Fight_type            Open Weight Bout       Open Weight Bout
# Winner                   Johnny Rhodes          Patrick Smith
#
#                                   5794                   5795  \
# R_fighter                 Royce Gracie          Jason DeLucia
# B_fighter              Minoki Ichihara            Scott Baker
# R_KD                                 0                      0
# B_KD                                 0                      0
# R_SIG_STR.                      2 of 4                 3 of 5
# B_SIG_STR.                      3 of 7                 0 of 2
# R_SIG_STR_pct                      50%                    60%
# B_SIG_STR_pct                      42%                     0%
# R_TOTAL_STR.                110 of 114               20 of 25
# B_TOTAL_STR.                  12 of 16               14 of 23
# R_TD                            1 of 1                 0 of 1
# B_TD                            0 of 0                 1 of 1
# R_TD_pct                          100%                     0%
# B_TD_pct                           ---                   100%
# R_SUB_ATT                            2                      5
# B_SUB_ATT                            0                      0
# R_REV                                0                      4
# B_REV                                0                      2
# R_CTRL                              --                     --
# B_CTRL                              --                     --
# R_HEAD                          0 of 0                 1 of 2
# B_HEAD                          3 of 6                 0 of 2
# R_BODY                          0 of 0                 1 of 2
# B_BODY                          0 of 0                 0 of 0
# R_LEG                           2 of 4                 1 of 1
# B_LEG                           0 of 1                 0 of 0
# R_DISTANCE                      2 of 4                 2 of 4
# B_DISTANCE                      0 of 2                 0 of 2
# R_CLINCH                        0 of 0                 0 of 0
# B_CLINCH                        0 of 0                 0 of 0
# R_GROUND                        0 of 0                 1 of 1
# B_GROUND                        3 of 5                 0 of 0
# win_by                      Submission             Submission
# last_round                           1                      1
# last_round_time                   5:08                   6:41
# Format                   No Time Limit          No Time Limit
# Referee                  John McCarthy          John McCarthy
# date                    March 11, 1994         March 11, 1994
# location         Denver, Colorado, USA  Denver, Colorado, USA
# Fight_type            Open Weight Bout       Open Weight Bout
# Winner                    Royce Gracie          Jason DeLucia
#
#                                   5796                   5797  \
# R_fighter                Remco Pardoel           Orlando Wiet
# B_fighter           Alberta Cerra Leon       Robert Lucarelli
# R_KD                                 0                      0
# B_KD                                 0                      0
# R_SIG_STR.                      4 of 6                8 of 12
# B_SIG_STR.                      1 of 3                 2 of 6
# R_SIG_STR_pct                      66%                    66%
# B_SIG_STR_pct                      33%                    33%
# R_TOTAL_STR.                  20 of 22               11 of 15
# B_TOTAL_STR.                   9 of 11                 2 of 6
# R_TD                            1 of 1                 0 of 0
# B_TD                            0 of 0                 1 of 1
# R_TD_pct                          100%                    ---
# B_TD_pct                           ---                   100%
# R_SUB_ATT                            1                      0
# B_SUB_ATT                            0                      1
# R_REV                                0                      0
# B_REV                                0                      0
# R_CTRL                              --                     --
# B_CTRL                              --                     --
# R_HEAD                          4 of 5                7 of 11
# B_HEAD                          1 of 3                 1 of 2
# R_BODY                          0 of 0                 1 of 1
# B_BODY                          0 of 0                 0 of 1
# R_LEG                           0 of 1                 0 of 0
# B_LEG                           0 of 0                 1 of 3
# R_DISTANCE                      0 of 1                 1 of 3
# B_DISTANCE                      1 of 1                 2 of 6
# R_CLINCH                        0 of 0                 0 of 0
# B_CLINCH                        0 of 0                 0 of 0
# R_GROUND                        4 of 5                 7 of 9
# B_GROUND                        0 of 2                 0 of 0
# win_by                      Submission                 KO/TKO
# last_round                           1                      1
# last_round_time                   9:51                   2:50
# Format                   No Time Limit          No Time Limit
# Referee                  John McCarthy          John McCarthy
# date                    March 11, 1994         March 11, 1994
# location         Denver, Colorado, USA  Denver, Colorado, USA
# Fight_type            Open Weight Bout       Open Weight Bout
# Winner                   Remco Pardoel           Orlando Wiet
#
#                                   5798                   5799  \
# R_fighter                Frank Hamaker          Johnny Rhodes
# B_fighter              Thaddeus Luster          David Levicki
# R_KD                                 0                      0
# B_KD                                 0                      0
# R_SIG_STR.                      2 of 3               11 of 17
# B_SIG_STR.                      0 of 0                 4 of 5
# R_SIG_STR_pct                      66%                    64%
# B_SIG_STR_pct                      ---                    80%
# R_TOTAL_STR.                  14 of 15               74 of 86
# B_TOTAL_STR.                    0 of 0              95 of 102
# R_TD                            1 of 1                 1 of 1
# B_TD                            0 of 1                 0 of 0
# R_TD_pct                          100%                   100%
# B_TD_pct                            0%                    ---
# R_SUB_ATT                            3                      0
# B_SUB_ATT                            0                      0
# R_REV                                1                      0
# B_REV                                0                      0
# R_CTRL                              --                     --
# B_CTRL                              --                     --
# R_HEAD                          2 of 3                9 of 15
# B_HEAD                          0 of 0                 4 of 5
# R_BODY                          0 of 0                 1 of 1
# B_BODY                          0 of 0                 0 of 0
# R_LEG                           0 of 0                 1 of 1
# B_LEG                           0 of 0                 0 of 0
# R_DISTANCE                      1 of 1                 1 of 1
# B_DISTANCE                      0 of 0                 1 of 2
# R_CLINCH                        0 of 0                 1 of 1
# B_CLINCH                        0 of 0                 2 of 2
# R_GROUND                        1 of 2                9 of 15
# B_GROUND                        0 of 0                 1 of 1
# win_by                      Submission                 KO/TKO
# last_round                           1                      1
# last_round_time                   4:52                  12:13
# Format                   No Time Limit          No Time Limit
# Referee                  John McCarthy          John McCarthy
# date                    March 11, 1994         March 11, 1994
# location         Denver, Colorado, USA  Denver, Colorado, USA
# Fight_type            Open Weight Bout       Open Weight Bout
# Winner                   Frank Hamaker          Johnny Rhodes
#
#                                   5800                   5801
# R_fighter                Patrick Smith           Scott Morris
# B_fighter                   Ray Wizard         Sean Daugherty
# R_KD                                 0                      0
# B_KD                                 0                      0
# R_SIG_STR.                      1 of 1                 1 of 1
# B_SIG_STR.                      1 of 1                 0 of 4
# R_SIG_STR_pct                     100%                   100%
# B_SIG_STR_pct                     100%                     0%
# R_TOTAL_STR.                    1 of 1                 2 of 2
# B_TOTAL_STR.                    2 of 2                 1 of 5
# R_TD                            0 of 1                 1 of 1
# B_TD                            0 of 0                 0 of 0
# R_TD_pct                            0%                   100%
# B_TD_pct                           ---                    ---
# R_SUB_ATT                            1                      1
# B_SUB_ATT                            0                      0
# R_REV                                0                      0
# B_REV                                0                      0
# R_CTRL                              --                     --
# B_CTRL                              --                     --
# R_HEAD                          0 of 0                 1 of 1
# B_HEAD                          0 of 0                 0 of 2
# R_BODY                          1 of 1                 0 of 0
# B_BODY                          0 of 0                 0 of 0
# R_LEG                           0 of 0                 0 of 0
# B_LEG                           1 of 1                 0 of 2
# R_DISTANCE                      0 of 0                 0 of 0
# B_DISTANCE                      1 of 1                 0 of 3
# R_CLINCH                        1 of 1                 1 of 1
# B_CLINCH                        0 of 0                 0 of 1
# R_GROUND                        0 of 0                 0 of 0
# B_GROUND                        0 of 0                 0 of 0
# win_by                      Submission             Submission
# last_round                           1                      1
# last_round_time                   0:58                   0:20
# Format                   No Time Limit          No Time Limit
# Referee                  John McCarthy          John McCarthy
# date                    March 11, 1994         March 11, 1994
# location         Denver, Colorado, USA  Denver, Colorado, USA
# Fight_type            Open Weight Bout       Open Weight Bout
# Winner                   Patrick Smith           Scott Morris
#
# [41 rows x 5802 columns]

# %%
df.describe()
# Out:
#               R_KD         B_KD    R_SUB_ATT    B_SUB_ATT        R_REV  \
# count  5802.000000  5802.000000  5802.000000  5802.000000  5802.000000
# mean      0.249569     0.180972     0.487246     0.347466     0.139607
# std       0.521330     0.458590     0.930951     0.796639     0.425226
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     0.000000     0.000000     0.000000     0.000000
# 50%       0.000000     0.000000     0.000000     0.000000     0.000000
# 75%       0.000000     0.000000     1.000000     0.000000     0.000000
# max       5.000000     4.000000    10.000000     7.000000     5.000000
#
#              B_REV   last_round
# count  5802.000000  5802.000000
# mean      0.134436     2.311961
# std       0.415428     1.007757
# min       0.000000     1.000000
# 25%       0.000000     1.000000
# 50%       0.000000     3.000000
# 75%       0.000000     3.000000
# max       3.000000     5.000000

# %%
df.dtypes
# Out:
# R_fighter          object
# B_fighter          object
# R_KD                int64
# B_KD                int64
# R_SIG_STR.         object
# B_SIG_STR.         object
# R_SIG_STR_pct      object
# B_SIG_STR_pct      object
# R_TOTAL_STR.       object
# B_TOTAL_STR.       object
# R_TD               object
# B_TD               object
# R_TD_pct           object
# B_TD_pct           object
# R_SUB_ATT           int64
# B_SUB_ATT           int64
# R_REV               int64
# B_REV               int64
# R_CTRL             object
# B_CTRL             object
# R_HEAD             object
# B_HEAD             object
# R_BODY             object
# B_BODY             object
# R_LEG              object
# B_LEG              object
# R_DISTANCE         object
# B_DISTANCE         object
# R_CLINCH           object
# B_CLINCH           object
# R_GROUND           object
# B_GROUND           object
# win_by             object
# last_round          int64
# last_round_time    object
# Format             object
# Referee            object
# date               object
# location           object
# Fight_type         object
# Winner             object
# dtype: object

# %%
df.columns
# Out:
# Index(['R_fighter', 'B_fighter', 'R_KD', 'B_KD', 'R_SIG_STR.', 'B_SIG_STR.',
#        'R_SIG_STR_pct', 'B_SIG_STR_pct', 'R_TOTAL_STR.', 'B_TOTAL_STR.',
#        'R_TD', 'B_TD', 'R_TD_pct', 'B_TD_pct', 'R_SUB_ATT', 'B_SUB_ATT',
#        'R_REV', 'B_REV', 'R_CTRL', 'B_CTRL', 'R_HEAD', 'B_HEAD', 'R_BODY',
#        'B_BODY', 'R_LEG', 'B_LEG', 'R_DISTANCE', 'B_DISTANCE', 'R_CLINCH',
#        'B_CLINCH', 'R_GROUND', 'B_GROUND', 'win_by', 'last_round',
#        'last_round_time', 'Format', 'Referee', 'date', 'location',
#        'Fight_type', 'Winner'],
#       dtype='object')

# %% [markdown]
# ### Column definitions:
#
# - `R_` and `B_` prefix signifies red and blue corner fighter stats respectively
# - `KD` is number of knockdowns
# - `SIG_STR` is no. of significant strikes 'landed of attempted'
# - `SIG_STR_pct` is significant strikes percentage
# - `TOTAL_STR` is total strikes 'landed of attempted'
# - `TD` is no. of takedowns
# - `TD_pct` is takedown percentages
# - `SUB_ATT` is no. of submission attempts
# - `PASS` is no. times the guard was passed?
# - `REV` is the no. of reversals
# - `CTRL` is the time spent with ground control
# - `HEAD` is no. of significant strinks to the head 'landed of attempted'
# - `BODY` is no. of significant strikes to the body 'landed of attempted'
# - `CLINCH` is no. of significant strikes in the clinch 'landed of attempted'
# - `GROUND` is no. of significant strikes on the ground 'landed of attempted'
# - `win_by` is method of win
# - `last_round` is last round of the fight (ex. if it was a KO in 1st, then this will be 1)
# - `last_round_time` is when the fight ended in the last round
# - `Format` is the format of the fight (3 rounds, 5 rounds etc.)
# - `Referee` is the name of the Ref
# - `date` is the date of the fight
# - `location` is the location in which the event took place
# - `Fight_type` is which weight class and whether it's a title bout or not
# - `Winner` is the winner of the fight
#
# #### Per fighter career wide stats
# - `SLpM` - Significant Strikes Landed per Minute
# - `Str_Acc.` - Significant Striking Accuracy
# - `SApM` - Significant Strikes Absorbed per Minute
# - `Str_Def` - Significant Strike Defence (the % of opponents strikes that did not land)
# - `TD_Avg` - Average Takedowns Landed per 15 minutes
# - `TD_Acc` - Takedown Accuracy
# - `TD_Def` - Takedown Defense (the % of opponents TD attempts that did not land)
# - `Sub_Avg` - Average Submissions Attempted per 15 minutes

# %% [markdown]
# ## Todo:
#
# - Separate `landed of attempted` to separate columns
#
# - Convert `Fight_type` into two separate columns, `weight_class` and `Title_fight` (True or False)
#
# - Convert `last_round_time` to `total_time_fought` by using `last_round` and `Format`
#
# - Convert `CTRL` to `time_in_CTRL`
#
# - Convert percentages to fractions
#
# - Since the data is a description of each fight, we have to convert it into a format that shows the compilation data of each fighter up until that fight. This means every row will look a lot different than it looks now.
#
# - Create `current_win_streak`, `current_lose_streak`, `longest_win_streak`, `wins`, `losses`, `draw`
#
# - Create fighter `height`, `reach`, `weight`, `age`

# %% [markdown]
# ### Splitting landed of attempted to different columns

# %%
columns = ['R_SIG_STR.', 'B_SIG_STR.', 'R_TOTAL_STR.', 'B_TOTAL_STR.',
       'R_TD', 'B_TD', 'R_HEAD', 'B_HEAD', 'R_BODY','B_BODY', 'R_LEG', 'B_LEG', 
        'R_DISTANCE', 'B_DISTANCE', 'R_CLINCH','B_CLINCH', 'R_GROUND', 'B_GROUND']

for column in columns:
    print(f"{column} data type is: {df[column].dtype}")
# Out:
# R_SIG_STR. data type is: object
# B_SIG_STR. data type is: object
# R_TOTAL_STR. data type is: object
# B_TOTAL_STR. data type is: object
# R_TD data type is: object
# B_TD data type is: object
# R_HEAD data type is: object
# B_HEAD data type is: object
# R_BODY data type is: object
# B_BODY data type is: object
# R_LEG data type is: object
# B_LEG data type is: object
# R_DISTANCE data type is: object
# B_DISTANCE data type is: object
# R_CLINCH data type is: object
# B_CLINCH data type is: object
# R_GROUND data type is: object
# B_GROUND data type is: object

# %%
attempt_suffix = '_att'
landed_suffix = '_landed'

for column in columns:
    df[column+attempt_suffix] = df[column].apply(lambda X: int(X.split('of')[1]))
    df[column+landed_suffix] = df[column].apply(lambda X: int(X.split('of')[0]))
    
df.drop(columns, axis=1, inplace=True)

# %%
df.columns
# Out:
# Index(['R_fighter', 'B_fighter', 'R_KD', 'B_KD', 'R_SIG_STR_pct',
#        'B_SIG_STR_pct', 'R_TD_pct', 'B_TD_pct', 'R_SUB_ATT', 'B_SUB_ATT',
#        'R_REV', 'B_REV', 'R_CTRL', 'B_CTRL', 'win_by', 'last_round',
#        'last_round_time', 'Format', 'Referee', 'date', 'location',
#        'Fight_type', 'Winner', 'R_SIG_STR._att', 'R_SIG_STR._landed',
#        'B_SIG_STR._att', 'B_SIG_STR._landed', 'R_TOTAL_STR._att',
#        'R_TOTAL_STR._landed', 'B_TOTAL_STR._att', 'B_TOTAL_STR._landed',
#        'R_TD_att', 'R_TD_landed', 'B_TD_att', 'B_TD_landed', 'R_HEAD_att',
#        'R_HEAD_landed', 'B_HEAD_att', 'B_HEAD_landed', 'R_BODY_att',
#        'R_BODY_landed', 'B_BODY_att', 'B_BODY_landed', 'R_LEG_att',
#        'R_LEG_landed', 'B_LEG_att', 'B_LEG_landed', 'R_DISTANCE_att',
#        'R_DISTANCE_landed', 'B_DISTANCE_att', 'B_DISTANCE_landed',
#        'R_CLINCH_att', 'R_CLINCH_landed', 'B_CLINCH_att', 'B_CLINCH_landed',
#        'R_GROUND_att', 'R_GROUND_landed', 'B_GROUND_att', 'B_GROUND_landed'],
#       dtype='object')

# %% [markdown]
# ### Replacing Winner NaNs as Draw

# %%
for column in df.columns:
    if df[column].isnull().sum() != 0:
        print(f"NaN values in {column} = {df[column].isnull().sum()}")
# Out:
# NaN values in Referee = 30
# NaN values in Winner = 100

# %% [markdown]
# * 83 missing values in winner and 23 missing values in Referee

# %%
df[df['Winner'].isnull()]['win_by'].value_counts()
# Out:
# Overturned              40
# Decision - Majority     24
# Could Not Continue      15
# Decision - Split        12
# Decision - Unanimous     6
# Other                    2
# Submission               1
# Name: win_by, dtype: int64

# %% [markdown]
# * Here, Overturned means due to drug test being positive and Could not Continue means there was an illegal blow which was not enough to be disqualified but the fighter could not continue.
# * The rest are different forms of draw
#
# * Replacing all of these with draw

# %%
df['Winner'].fillna('Draw', inplace=True)

# %% [markdown]
# ### Converting percentages to fractions

# %%
pct_columns = ['R_SIG_STR_pct','B_SIG_STR_pct', 'R_TD_pct', 'B_TD_pct']

def pct_to_frac(X):
    if X != '---':
        return float(X.replace('%', ''))/100
    else:
        # if '---' means it's taking pct of `0 of 0`. 
        # Taking a call here to consider 0 landed of 0 attempted as 0 percentage
        return 0

for column in pct_columns:
    df[column] = df[column].apply(pct_to_frac)

# %%
df.T
# Out:
#                                                            0     \
# R_fighter                                          Brian Ortega
# B_fighter                                        Chan Sung Jung
# R_KD                                                          2
# B_KD                                                          0
# R_SIG_STR_pct                                              0.59
# B_SIG_STR_pct                                              0.38
# R_TD_pct                                                    0.3
# B_TD_pct                                                      0
# R_SUB_ATT                                                     0
# B_SUB_ATT                                                     0
# R_REV                                                         0
# B_REV                                                         0
# R_CTRL                                                     0:57
# B_CTRL                                                     0:00
# win_by                                     Decision - Unanimous
# last_round                                                    5
# last_round_time                                            5:00
# Format                                        5 Rnd (5-5-5-5-5)
# Referee                                          Lukasz Bosacki
# date                                           October 17, 2020
# location             Abu Dhabi, Abu Dhabi, United Arab Emirates
# Fight_type                                   Featherweight Bout
# Winner                                             Brian Ortega
# R_SIG_STR._att                                              212
# R_SIG_STR._landed                                           127
# B_SIG_STR._att                                              163
# B_SIG_STR._landed                                            62
# R_TOTAL_STR._att                                            214
# R_TOTAL_STR._landed                                         129
# B_TOTAL_STR._att                                            166
# B_TOTAL_STR._landed                                          64
# R_TD_att                                                     10
# R_TD_landed                                                   3
# B_TD_att                                                      0
# B_TD_landed                                                   0
# R_HEAD_att                                                  135
# R_HEAD_landed                                                64
# B_HEAD_att                                                  127
# B_HEAD_landed                                                35
# R_BODY_att                                                   28
# R_BODY_landed                                                22
# B_BODY_att                                                   21
# B_BODY_landed                                                14
# R_LEG_att                                                    49
# R_LEG_landed                                                 41
# B_LEG_att                                                    15
# B_LEG_landed                                                 13
# R_DISTANCE_att                                              199
# R_DISTANCE_landed                                           118
# B_DISTANCE_att                                              162
# B_DISTANCE_landed                                            62
# R_CLINCH_att                                                  7
# R_CLINCH_landed                                               5
# B_CLINCH_att                                                  1
# B_CLINCH_landed                                               0
# R_GROUND_att                                                  6
# R_GROUND_landed                                               4
# B_GROUND_att                                                  0
# B_GROUND_landed                                               0
#
#                                                            1     \
# R_fighter                                     Katlyn Chookagian
# B_fighter                                       Jessica Andrade
# R_KD                                                          0
# B_KD                                                          1
# R_SIG_STR_pct                                              0.35
# B_SIG_STR_pct                                              0.65
# R_TD_pct                                                      0
# B_TD_pct                                                   0.66
# R_SUB_ATT                                                     0
# B_SUB_ATT                                                     0
# R_REV                                                         0
# B_REV                                                         0
# R_CTRL                                                     0:25
# B_CTRL                                                     2:26
# win_by                                                   KO/TKO
# last_round                                                    1
# last_round_time                                            4:55
# Format                                            3 Rnd (5-5-5)
# Referee                                          Lukasz Bosacki
# date                                           October 17, 2020
# location             Abu Dhabi, Abu Dhabi, United Arab Emirates
# Fight_type                               Women's Flyweight Bout
# Winner                                          Jessica Andrade
# R_SIG_STR._att                                               53
# R_SIG_STR._landed                                            19
# B_SIG_STR._att                                               43
# B_SIG_STR._landed                                            28
# R_TOTAL_STR._att                                             61
# R_TOTAL_STR._landed                                          27
# B_TOTAL_STR._att                                             79
# B_TOTAL_STR._landed                                          62
# R_TD_att                                                      0
# R_TD_landed                                                   0
# B_TD_att                                                      3
# B_TD_landed                                                   2
# R_HEAD_att                                                   35
# R_HEAD_landed                                                 7
# B_HEAD_att                                                   24
# B_HEAD_landed                                                11
# R_BODY_att                                                   18
# R_BODY_landed                                                12
# B_BODY_att                                                   12
# B_BODY_landed                                                11
# R_LEG_att                                                     0
# R_LEG_landed                                                  0
# B_LEG_att                                                     7
# B_LEG_landed                                                  6
# R_DISTANCE_att                                               41
# R_DISTANCE_landed                                            10
# B_DISTANCE_att                                               28
# B_DISTANCE_landed                                            14
# R_CLINCH_att                                                 12
# R_CLINCH_landed                                               9
# B_CLINCH_att                                                  9
# B_CLINCH_landed                                               8
# R_GROUND_att                                                  0
# R_GROUND_landed                                               0
# B_GROUND_att                                                  6
# B_GROUND_landed                                               6
#
#                                                            2     \
# R_fighter                                           Jimmy Crute
# B_fighter                                    Modestas Bukauskas
# R_KD                                                          2
# B_KD                                                          0
# R_SIG_STR_pct                                               0.7
# B_SIG_STR_pct                                              0.41
# R_TD_pct                                                      0
# B_TD_pct                                                      0
# R_SUB_ATT                                                     0
# B_SUB_ATT                                                     0
# R_REV                                                         0
# B_REV                                                         0
# R_CTRL                                                     0:25
# B_CTRL                                                     0:00
# win_by                                                   KO/TKO
# last_round                                                    1
# last_round_time                                            2:01
# Format                                            3 Rnd (5-5-5)
# Referee                                          Anders Ohlsson
# date                                           October 17, 2020
# location             Abu Dhabi, Abu Dhabi, United Arab Emirates
# Fight_type                               Light Heavyweight Bout
# Winner                                              Jimmy Crute
# R_SIG_STR._att                                               24
# R_SIG_STR._landed                                            17
# B_SIG_STR._att                                               17
# B_SIG_STR._landed                                             7
# R_TOTAL_STR._att                                             25
# R_TOTAL_STR._landed                                          18
# B_TOTAL_STR._att                                             17
# B_TOTAL_STR._landed                                           7
# R_TD_att                                                      1
# R_TD_landed                                                   0
# B_TD_att                                                      0
# B_TD_landed                                                   0
# R_HEAD_att                                                   14
# R_HEAD_landed                                                 8
# B_HEAD_att                                                   11
# B_HEAD_landed                                                 2
# R_BODY_att                                                    1
# R_BODY_landed                                                 1
# B_BODY_att                                                    3
# B_BODY_landed                                                 2
# R_LEG_att                                                     9
# R_LEG_landed                                                  8
# B_LEG_att                                                     3
# B_LEG_landed                                                  3
# R_DISTANCE_att                                               21
# R_DISTANCE_landed                                            14
# B_DISTANCE_att                                               17
# B_DISTANCE_landed                                             7
# R_CLINCH_att                                                  1
# R_CLINCH_landed                                               1
# B_CLINCH_att                                                  0
# B_CLINCH_landed                                               0
# R_GROUND_att                                                  2
# R_GROUND_landed                                               2
# B_GROUND_att                                                  0
# B_GROUND_landed                                               0
#
#                                                            3     \
# R_fighter                                         Claudio Silva
# B_fighter                                          James Krause
# R_KD                                                          0
# B_KD                                                          0
# R_SIG_STR_pct                                              0.29
# B_SIG_STR_pct                                              0.59
# R_TD_pct                                                   0.16
# B_TD_pct                                                      0
# R_SUB_ATT                                                     0
# B_SUB_ATT                                                     0
# R_REV                                                         0
# B_REV                                                         0
# R_CTRL                                                     0:58
# B_CTRL                                                     0:14
# win_by                                     Decision - Unanimous
# last_round                                                    3
# last_round_time                                            5:00
# Format                                            3 Rnd (5-5-5)
# Referee                                          Lukasz Bosacki
# date                                           October 17, 2020
# location             Abu Dhabi, Abu Dhabi, United Arab Emirates
# Fight_type                                    Welterweight Bout
# Winner                                             James Krause
# R_SIG_STR._att                                              214
# R_SIG_STR._landed                                            64
# B_SIG_STR._att                                              159
# B_SIG_STR._landed                                            94
# R_TOTAL_STR._att                                            216
# R_TOTAL_STR._landed                                          66
# B_TOTAL_STR._att                                            162
# B_TOTAL_STR._landed                                          96
# R_TD_att                                                     12
# R_TD_landed                                                   2
# B_TD_att                                                      1
# B_TD_landed                                                   0
# R_HEAD_att                                                  143
# R_HEAD_landed                                                30
# B_HEAD_att                                                  135
# B_HEAD_landed                                                73
# R_BODY_att                                                   43
# R_BODY_landed                                                11
# B_BODY_att                                                   21
# B_BODY_landed                                                18
# R_LEG_att                                                    28
# R_LEG_landed                                                 23
# B_LEG_att                                                     3
# B_LEG_landed                                                  3
# R_DISTANCE_att                                              214
# R_DISTANCE_landed                                            64
# B_DISTANCE_att                                              159
# B_DISTANCE_landed                                            94
# R_CLINCH_att                                                  0
# R_CLINCH_landed                                               0
# B_CLINCH_att                                                  0
# B_CLINCH_landed                                               0
# R_GROUND_att                                                  0
# R_GROUND_landed                                               0
# B_GROUND_att                                                  0
# B_GROUND_landed                                               0
#
#                                                            4     \
# R_fighter                                        Thomas Almeida
# B_fighter                                     Jonathan Martinez
# R_KD                                                          0
# B_KD                                                          0
# R_SIG_STR_pct                                              0.37
# B_SIG_STR_pct                                              0.35
# R_TD_pct                                                      0
# B_TD_pct                                                      0
# R_SUB_ATT                                                     0
# B_SUB_ATT                                                     0
# R_REV                                                         0
# B_REV                                                         0
# R_CTRL                                                     0:02
# B_CTRL                                                     0:00
# win_by                                     Decision - Unanimous
# last_round                                                    3
# last_round_time                                            5:00
# Format                                            3 Rnd (5-5-5)
# Referee                                          Anders Ohlsson
# date                                           October 17, 2020
# location             Abu Dhabi, Abu Dhabi, United Arab Emirates
# Fight_type                                   Featherweight Bout
# Winner                                        Jonathan Martinez
# R_SIG_STR._att                                              171
# R_SIG_STR._landed                                            64
# B_SIG_STR._att                                              205
# B_SIG_STR._landed                                            73
# R_TOTAL_STR._att                                            171
# R_TOTAL_STR._landed                                          64
# B_TOTAL_STR._att                                            205
# B_TOTAL_STR._landed                                          73
# R_TD_att                                                      5
# R_TD_landed                                                   0
# B_TD_att                                                      0
# B_TD_landed                                                   0
# R_HEAD_att                                                  127
# R_HEAD_landed                                                33
# B_HEAD_att                                                  170
# B_HEAD_landed                                                53
# R_BODY_att                                                   29
# R_BODY_landed                                                17
# B_BODY_att                                                   33
# B_BODY_landed                                                18
# R_LEG_att                                                    15
# R_LEG_landed                                                 14
# B_LEG_att                                                     2
# B_LEG_landed                                                  2
# R_DISTANCE_att                                              163
# R_DISTANCE_landed                                            56
# B_DISTANCE_att                                              201
# B_DISTANCE_landed                                            69
# R_CLINCH_att                                                  8
# R_CLINCH_landed                                               8
# B_CLINCH_att                                                  4
# B_CLINCH_landed                                               4
# R_GROUND_att                                                  0
# R_GROUND_landed                                               0
# B_GROUND_att                                                  0
# B_GROUND_landed                                               0
#
#                                                            5     \
# R_fighter                                        Mateusz Gamrot
# B_fighter                                     Guram Kutateladze
# R_KD                                                          0
# B_KD                                                          1
# R_SIG_STR_pct                                              0.41
# B_SIG_STR_pct                                              0.43
# R_TD_pct                                                   0.31
# B_TD_pct                                                      0
# R_SUB_ATT                                                     0
# B_SUB_ATT                                                     0
# R_REV                                                         0
# B_REV                                                         0
# R_CTRL                                                     3:29
# B_CTRL                                                     0:01
# win_by                                         Decision - Split
# last_round                                                    3
# last_round_time                                            5:00
# Format                                            3 Rnd (5-5-5)
# Referee                                          Lukasz Bosacki
# date                                           October 17, 2020
# location             Abu Dhabi, Abu Dhabi, United Arab Emirates
# Fight_type                                     Lightweight Bout
# Winner                                        Guram Kutateladze
# R_SIG_STR._att                                              126
# R_SIG_STR._landed                                            52
# B_SIG_STR._att                                               86
# B_SIG_STR._landed                                            37
# R_TOTAL_STR._att                                            151
# R_TOTAL_STR._landed                                          69
# B_TOTAL_STR._att                                             93
# B_TOTAL_STR._landed                                          43
# R_TD_att                                                     16
# R_TD_landed                                                   5
# B_TD_att                                                      1
# B_TD_landed                                                   0
# R_HEAD_att                                                  112
# R_HEAD_landed                                                42
# B_HEAD_att                                                   48
# B_HEAD_landed                                                12
# R_BODY_att                                                   10
# R_BODY_landed                                                 6
# B_BODY_att                                                   24
# B_BODY_landed                                                12
# R_LEG_att                                                     4
# R_LEG_landed                                                  4
# B_LEG_att                                                    14
# B_LEG_landed                                                 13
# R_DISTANCE_att                                              103
# R_DISTANCE_landed                                            37
# B_DISTANCE_att                                               84
# B_DISTANCE_landed                                            35
# R_CLINCH_att                                                  4
# R_CLINCH_landed                                               4
# B_CLINCH_att                                                  0
# B_CLINCH_landed                                               0
# R_GROUND_att                                                 19
# R_GROUND_landed                                              11
# B_GROUND_att                                                  2
# B_GROUND_landed                                               2
#
#                                                            6     \
# R_fighter                                     Gillian Robertson
# B_fighter                                       Poliana Botelho
# R_KD                                                          0
# B_KD                                                          0
# R_SIG_STR_pct                                              0.58
# B_SIG_STR_pct                                              0.51
# R_TD_pct                                                   0.42
# B_TD_pct                                                      0
# R_SUB_ATT                                                     0
# B_SUB_ATT                                                     0
# R_REV                                                         0
# B_REV                                                         0
# R_CTRL                                                     9:34
# B_CTRL                                                     1:16
# win_by                                     Decision - Unanimous
# last_round                                                    3
# last_round_time                                            5:00
# Format                                            3 Rnd (5-5-5)
# Referee                                          Anders Ohlsson
# date                                           October 17, 2020
# location             Abu Dhabi, Abu Dhabi, United Arab Emirates
# Fight_type                               Women's Flyweight Bout
# Winner                                        Gillian Robertson
# R_SIG_STR._att                                               98
# R_SIG_STR._landed                                            57
# B_SIG_STR._att                                               43
# B_SIG_STR._landed                                            22
# R_TOTAL_STR._att                                            161
# R_TOTAL_STR._landed                                         104
# B_TOTAL_STR._att                                             61
# B_TOTAL_STR._landed                                          39
# R_TD_att                                                      7
# R_TD_landed                                                   3
# B_TD_att                                                      0
# B_TD_landed                                                   0
# R_HEAD_att                                                   77
# R_HEAD_landed                                                43
# B_HEAD_att                                                   32
# B_HEAD_landed                                                11
# R_BODY_att                                                   10
# R_BODY_landed                                                 7
# B_BODY_att                                                    8
# B_BODY_landed                                                 8
# R_LEG_att                                                    11
# R_LEG_landed                                                  7
# B_LEG_att                                                     3
# B_LEG_landed                                                  3
# R_DISTANCE_att                                               30
# R_DISTANCE_landed                                             9
# B_DISTANCE_att                                               35
# B_DISTANCE_landed                                            15
# R_CLINCH_att                                                  0
# R_CLINCH_landed                                               0
# B_CLINCH_att                                                  5
# B_CLINCH_landed                                               4
# R_GROUND_att                                                 68
# R_GROUND_landed                                              48
# B_GROUND_att                                                  3
# B_GROUND_landed                                               3
#
#                                                            7     \
# R_fighter                                          Junyong Park
# B_fighter                                         John Phillips
# R_KD                                                          0
# B_KD                                                          0
# R_SIG_STR_pct                                              0.47
# B_SIG_STR_pct                                              0.35
# R_TD_pct                                                      1
# B_TD_pct                                                      0
# R_SUB_ATT                                                     0
# B_SUB_ATT                                                     0
# R_REV                                                         0
# B_REV                                                         0
# R_CTRL                                                    13:11
# B_CTRL                                                     0:00
# win_by                                     Decision - Unanimous
# last_round                                                    3
# last_round_time                                            5:00
# Format                                            3 Rnd (5-5-5)
# Referee                                          Lukasz Bosacki
# date                                           October 17, 2020
# location             Abu Dhabi, Abu Dhabi, United Arab Emirates
# Fight_type                                    Middleweight Bout
# Winner                                             Junyong Park
# R_SIG_STR._att                                               21
# R_SIG_STR._landed                                            10
# B_SIG_STR._att                                               14
# B_SIG_STR._landed                                             5
# R_TOTAL_STR._att                                            350
# R_TOTAL_STR._landed                                         260
# B_TOTAL_STR._att                                             25
# B_TOTAL_STR._landed                                          13
# R_TD_att                                                      4
# R_TD_landed                                                   4
# B_TD_att                                                      0
# B_TD_landed                                                   0
# R_HEAD_att                                                   21
# R_HEAD_landed                                                10
# B_HEAD_att                                                   10
# B_HEAD_landed                                                 1
# R_BODY_att                                                    0
# R_BODY_landed                                                 0
# B_BODY_att                                                    2
# B_BODY_landed                                                 2
# R_LEG_att                                                     0
# R_LEG_landed                                                  0
# B_LEG_att                                                     2
# B_LEG_landed                                                  2
# R_DISTANCE_att                                                2
# R_DISTANCE_landed                                             2
# B_DISTANCE_att                                               14
# B_DISTANCE_landed                                             5
# R_CLINCH_att                                                  0
# R_CLINCH_landed                                               0
# B_CLINCH_att                                                  0
# B_CLINCH_landed                                               0
# R_GROUND_att                                                 19
# R_GROUND_landed                                               8
# B_GROUND_att                                                  0
# B_GROUND_landed                                               0
#
#                                                            8     \
# R_fighter                                       Jamie Mullarkey
# B_fighter                                            Fares Ziam
# R_KD                                                          0
# B_KD                                                          0
# R_SIG_STR_pct                                              0.27
# B_SIG_STR_pct                                              0.52
# R_TD_pct                                                   0.45
# B_TD_pct                                                    0.2
# R_SUB_ATT                                                     0
# B_SUB_ATT                                                     0
# R_REV                                                         0
# B_REV                                                         2
# R_CTRL                                                     6:56
# B_CTRL                                                     1:12
# win_by                                     Decision - Unanimous
# last_round                                                    3
# last_round_time                                            5:00
# Format                                            3 Rnd (5-5-5)
# Referee                                          Lukasz Bosacki
# date                                           October 17, 2020
# location             Abu Dhabi, Abu Dhabi, United Arab Emirates
# Fight_type                                     Lightweight Bout
# Winner                                               Fares Ziam
# R_SIG_STR._att                                               72
# R_SIG_STR._landed                                            20
# B_SIG_STR._att                                               89
# B_SIG_STR._landed                                            47
# R_TOTAL_STR._att                                             84
# R_TOTAL_STR._landed                                          29
# B_TOTAL_STR._att                                             98
# B_TOTAL_STR._landed                                          54
# R_TD_att                                                     11
# R_TD_landed                                                   5
# B_TD_att                                                      5
# B_TD_landed                                                   1
# R_HEAD_att                                                   51
# R_HEAD_landed                                                 7
# B_HEAD_att                                                   76
# B_HEAD_landed                                                34
# R_BODY_att                                                    8
# R_BODY_landed                                                 2
# B_BODY_att                                                    4
# B_BODY_landed                                                 4
# R_LEG_att                                                    13
# R_LEG_landed                                                 11
# B_LEG_att                                                     9
# B_LEG_landed                                                  9
# R_DISTANCE_att                                               65
# R_DISTANCE_landed                                            18
# B_DISTANCE_att                                               72
# B_DISTANCE_landed                                            35
# R_CLINCH_att                                                  7
# R_CLINCH_landed                                               2
# B_CLINCH_att                                                  8
# B_CLINCH_landed                                               6
# R_GROUND_att                                                  0
# R_GROUND_landed                                               0
# B_GROUND_att                                                  9
# B_GROUND_landed                                               6
#
#                                                            9     ...  \
# R_fighter                                 Gadzhimurad Antigulov  ...
# B_fighter                                         Maxim Grishin  ...
# R_KD                                                          0  ...
# B_KD                                                          0  ...
# R_SIG_STR_pct                                              0.52  ...
# B_SIG_STR_pct                                              0.44  ...
# R_TD_pct                                                    0.2  ...
# B_TD_pct                                                      1  ...
# R_SUB_ATT                                                     0  ...
# B_SUB_ATT                                                     0  ...
# R_REV                                                         0  ...
# B_REV                                                         0  ...
# R_CTRL                                                     2:39  ...
# B_CTRL                                                     2:21  ...
# win_by                                                   KO/TKO  ...
# last_round                                                    2  ...
# last_round_time                                            4:58  ...
# Format                                            3 Rnd (5-5-5)  ...
# Referee                                          Anders Ohlsson  ...
# date                                           October 17, 2020  ...
# location             Abu Dhabi, Abu Dhabi, United Arab Emirates  ...
# Fight_type                               Light Heavyweight Bout  ...
# Winner                                            Maxim Grishin  ...
# R_SIG_STR._att                                               23  ...
# R_SIG_STR._landed                                            12  ...
# B_SIG_STR._att                                               76  ...
# B_SIG_STR._landed                                            34  ...
# R_TOTAL_STR._att                                             44  ...
# R_TOTAL_STR._landed                                          31  ...
# B_TOTAL_STR._att                                            126  ...
# B_TOTAL_STR._landed                                          66  ...
# R_TD_att                                                      5  ...
# R_TD_landed                                                   1  ...
# B_TD_att                                                      1  ...
# B_TD_landed                                                   1  ...
# R_HEAD_att                                                   15  ...
# R_HEAD_landed                                                 5  ...
# B_HEAD_att                                                   61  ...
# B_HEAD_landed                                                20  ...
# R_BODY_att                                                    5  ...
# R_BODY_landed                                                 4  ...
# B_BODY_att                                                    7  ...
# B_BODY_landed                                                 6  ...
# R_LEG_att                                                     3  ...
# R_LEG_landed                                                  3  ...
# B_LEG_att                                                     8  ...
# B_LEG_landed                                                  8  ...
# R_DISTANCE_att                                               17  ...
# R_DISTANCE_landed                                             8  ...
# B_DISTANCE_att                                               45  ...
# B_DISTANCE_landed                                            22  ...
# R_CLINCH_att                                                  5  ...
# R_CLINCH_landed                                               3  ...
# B_CLINCH_att                                                  6  ...
# B_CLINCH_landed                                               3  ...
# R_GROUND_att                                                  1  ...
# R_GROUND_landed                                               1  ...
# B_GROUND_att                                                 25  ...
# B_GROUND_landed                                               9  ...
#
#                                       5792                   5793  \
# R_fighter                    Johnny Rhodes          Patrick Smith
# B_fighter                      Fred Ettish           Scott Morris
# R_KD                                     1                      0
# B_KD                                     0                      0
# R_SIG_STR_pct                         0.44                   0.76
# B_SIG_STR_pct                         0.57                      0
# R_TD_pct                                 0                      0
# B_TD_pct                                 0                      0
# R_SUB_ATT                                1                      0
# B_SUB_ATT                                0                      0
# R_REV                                    0                      0
# B_REV                                    0                      0
# R_CTRL                                  --                     --
# B_CTRL                                  --                     --
# win_by                          Submission                 KO/TKO
# last_round                               1                      1
# last_round_time                       3:07                   0:30
# Format                       No Time Limit          No Time Limit
# Referee                      John McCarthy          John McCarthy
# date                        March 11, 1994         March 11, 1994
# location             Denver, Colorado, USA  Denver, Colorado, USA
# Fight_type                Open Weight Bout       Open Weight Bout
# Winner                       Johnny Rhodes          Patrick Smith
# R_SIG_STR._att                          29                     17
# R_SIG_STR._landed                       13                     13
# B_SIG_STR._att                           7                      0
# B_SIG_STR._landed                        4                      0
# R_TOTAL_STR._att                        38                     25
# R_TOTAL_STR._landed                     21                     19
# B_TOTAL_STR._att                        11                      0
# B_TOTAL_STR._landed                      7                      0
# R_TD_att                                 0                      0
# R_TD_landed                              0                      0
# B_TD_att                                 0                      1
# B_TD_landed                              0                      0
# R_HEAD_att                              28                     16
# R_HEAD_landed                           12                     12
# B_HEAD_att                               1                      0
# B_HEAD_landed                            0                      0
# R_BODY_att                               0                      1
# R_BODY_landed                            0                      1
# B_BODY_att                               4                      0
# B_BODY_landed                            2                      0
# R_LEG_att                                1                      0
# R_LEG_landed                             1                      0
# B_LEG_att                                2                      0
# B_LEG_landed                             2                      0
# R_DISTANCE_att                           6                      0
# R_DISTANCE_landed                        3                      0
# B_DISTANCE_att                           7                      0
# B_DISTANCE_landed                        4                      0
# R_CLINCH_att                             2                      1
# R_CLINCH_landed                          1                      1
# B_CLINCH_att                             0                      0
# B_CLINCH_landed                          0                      0
# R_GROUND_att                            21                     16
# R_GROUND_landed                          9                     12
# B_GROUND_att                             0                      0
# B_GROUND_landed                          0                      0
#
#                                       5794                   5795  \
# R_fighter                     Royce Gracie          Jason DeLucia
# B_fighter                  Minoki Ichihara            Scott Baker
# R_KD                                     0                      0
# B_KD                                     0                      0
# R_SIG_STR_pct                          0.5                    0.6
# B_SIG_STR_pct                         0.42                      0
# R_TD_pct                                 1                      0
# B_TD_pct                                 0                      1
# R_SUB_ATT                                2                      5
# B_SUB_ATT                                0                      0
# R_REV                                    0                      4
# B_REV                                    0                      2
# R_CTRL                                  --                     --
# B_CTRL                                  --                     --
# win_by                          Submission             Submission
# last_round                               1                      1
# last_round_time                       5:08                   6:41
# Format                       No Time Limit          No Time Limit
# Referee                      John McCarthy          John McCarthy
# date                        March 11, 1994         March 11, 1994
# location             Denver, Colorado, USA  Denver, Colorado, USA
# Fight_type                Open Weight Bout       Open Weight Bout
# Winner                        Royce Gracie          Jason DeLucia
# R_SIG_STR._att                           4                      5
# R_SIG_STR._landed                        2                      3
# B_SIG_STR._att                           7                      2
# B_SIG_STR._landed                        3                      0
# R_TOTAL_STR._att                       114                     25
# R_TOTAL_STR._landed                    110                     20
# B_TOTAL_STR._att                        16                     23
# B_TOTAL_STR._landed                     12                     14
# R_TD_att                                 1                      1
# R_TD_landed                              1                      0
# B_TD_att                                 0                      1
# B_TD_landed                              0                      1
# R_HEAD_att                               0                      2
# R_HEAD_landed                            0                      1
# B_HEAD_att                               6                      2
# B_HEAD_landed                            3                      0
# R_BODY_att                               0                      2
# R_BODY_landed                            0                      1
# B_BODY_att                               0                      0
# B_BODY_landed                            0                      0
# R_LEG_att                                4                      1
# R_LEG_landed                             2                      1
# B_LEG_att                                1                      0
# B_LEG_landed                             0                      0
# R_DISTANCE_att                           4                      4
# R_DISTANCE_landed                        2                      2
# B_DISTANCE_att                           2                      2
# B_DISTANCE_landed                        0                      0
# R_CLINCH_att                             0                      0
# R_CLINCH_landed                          0                      0
# B_CLINCH_att                             0                      0
# B_CLINCH_landed                          0                      0
# R_GROUND_att                             0                      1
# R_GROUND_landed                          0                      1
# B_GROUND_att                             5                      0
# B_GROUND_landed                          3                      0
#
#                                       5796                   5797  \
# R_fighter                    Remco Pardoel           Orlando Wiet
# B_fighter               Alberta Cerra Leon       Robert Lucarelli
# R_KD                                     0                      0
# B_KD                                     0                      0
# R_SIG_STR_pct                         0.66                   0.66
# B_SIG_STR_pct                         0.33                   0.33
# R_TD_pct                                 1                      0
# B_TD_pct                                 0                      1
# R_SUB_ATT                                1                      0
# B_SUB_ATT                                0                      1
# R_REV                                    0                      0
# B_REV                                    0                      0
# R_CTRL                                  --                     --
# B_CTRL                                  --                     --
# win_by                          Submission                 KO/TKO
# last_round                               1                      1
# last_round_time                       9:51                   2:50
# Format                       No Time Limit          No Time Limit
# Referee                      John McCarthy          John McCarthy
# date                        March 11, 1994         March 11, 1994
# location             Denver, Colorado, USA  Denver, Colorado, USA
# Fight_type                Open Weight Bout       Open Weight Bout
# Winner                       Remco Pardoel           Orlando Wiet
# R_SIG_STR._att                           6                     12
# R_SIG_STR._landed                        4                      8
# B_SIG_STR._att                           3                      6
# B_SIG_STR._landed                        1                      2
# R_TOTAL_STR._att                        22                     15
# R_TOTAL_STR._landed                     20                     11
# B_TOTAL_STR._att                        11                      6
# B_TOTAL_STR._landed                      9                      2
# R_TD_att                                 1                      0
# R_TD_landed                              1                      0
# B_TD_att                                 0                      1
# B_TD_landed                              0                      1
# R_HEAD_att                               5                     11
# R_HEAD_landed                            4                      7
# B_HEAD_att                               3                      2
# B_HEAD_landed                            1                      1
# R_BODY_att                               0                      1
# R_BODY_landed                            0                      1
# B_BODY_att                               0                      1
# B_BODY_landed                            0                      0
# R_LEG_att                                1                      0
# R_LEG_landed                             0                      0
# B_LEG_att                                0                      3
# B_LEG_landed                             0                      1
# R_DISTANCE_att                           1                      3
# R_DISTANCE_landed                        0                      1
# B_DISTANCE_att                           1                      6
# B_DISTANCE_landed                        1                      2
# R_CLINCH_att                             0                      0
# R_CLINCH_landed                          0                      0
# B_CLINCH_att                             0                      0
# B_CLINCH_landed                          0                      0
# R_GROUND_att                             5                      9
# R_GROUND_landed                          4                      7
# B_GROUND_att                             2                      0
# B_GROUND_landed                          0                      0
#
#                                       5798                   5799  \
# R_fighter                    Frank Hamaker          Johnny Rhodes
# B_fighter                  Thaddeus Luster          David Levicki
# R_KD                                     0                      0
# B_KD                                     0                      0
# R_SIG_STR_pct                         0.66                   0.64
# B_SIG_STR_pct                            0                    0.8
# R_TD_pct                                 1                      1
# B_TD_pct                                 0                      0
# R_SUB_ATT                                3                      0
# B_SUB_ATT                                0                      0
# R_REV                                    1                      0
# B_REV                                    0                      0
# R_CTRL                                  --                     --
# B_CTRL                                  --                     --
# win_by                          Submission                 KO/TKO
# last_round                               1                      1
# last_round_time                       4:52                  12:13
# Format                       No Time Limit          No Time Limit
# Referee                      John McCarthy          John McCarthy
# date                        March 11, 1994         March 11, 1994
# location             Denver, Colorado, USA  Denver, Colorado, USA
# Fight_type                Open Weight Bout       Open Weight Bout
# Winner                       Frank Hamaker          Johnny Rhodes
# R_SIG_STR._att                           3                     17
# R_SIG_STR._landed                        2                     11
# B_SIG_STR._att                           0                      5
# B_SIG_STR._landed                        0                      4
# R_TOTAL_STR._att                        15                     86
# R_TOTAL_STR._landed                     14                     74
# B_TOTAL_STR._att                         0                    102
# B_TOTAL_STR._landed                      0                     95
# R_TD_att                                 1                      1
# R_TD_landed                              1                      1
# B_TD_att                                 1                      0
# B_TD_landed                              0                      0
# R_HEAD_att                               3                     15
# R_HEAD_landed                            2                      9
# B_HEAD_att                               0                      5
# B_HEAD_landed                            0                      4
# R_BODY_att                               0                      1
# R_BODY_landed                            0                      1
# B_BODY_att                               0                      0
# B_BODY_landed                            0                      0
# R_LEG_att                                0                      1
# R_LEG_landed                             0                      1
# B_LEG_att                                0                      0
# B_LEG_landed                             0                      0
# R_DISTANCE_att                           1                      1
# R_DISTANCE_landed                        1                      1
# B_DISTANCE_att                           0                      2
# B_DISTANCE_landed                        0                      1
# R_CLINCH_att                             0                      1
# R_CLINCH_landed                          0                      1
# B_CLINCH_att                             0                      2
# B_CLINCH_landed                          0                      2
# R_GROUND_att                             2                     15
# R_GROUND_landed                          1                      9
# B_GROUND_att                             0                      1
# B_GROUND_landed                          0                      1
#
#                                       5800                   5801
# R_fighter                    Patrick Smith           Scott Morris
# B_fighter                       Ray Wizard         Sean Daugherty
# R_KD                                     0                      0
# B_KD                                     0                      0
# R_SIG_STR_pct                            1                      1
# B_SIG_STR_pct                            1                      0
# R_TD_pct                                 0                      1
# B_TD_pct                                 0                      0
# R_SUB_ATT                                1                      1
# B_SUB_ATT                                0                      0
# R_REV                                    0                      0
# B_REV                                    0                      0
# R_CTRL                                  --                     --
# B_CTRL                                  --                     --
# win_by                          Submission             Submission
# last_round                               1                      1
# last_round_time                       0:58                   0:20
# Format                       No Time Limit          No Time Limit
# Referee                      John McCarthy          John McCarthy
# date                        March 11, 1994         March 11, 1994
# location             Denver, Colorado, USA  Denver, Colorado, USA
# Fight_type                Open Weight Bout       Open Weight Bout
# Winner                       Patrick Smith           Scott Morris
# R_SIG_STR._att                           1                      1
# R_SIG_STR._landed                        1                      1
# B_SIG_STR._att                           1                      4
# B_SIG_STR._landed                        1                      0
# R_TOTAL_STR._att                         1                      2
# R_TOTAL_STR._landed                      1                      2
# B_TOTAL_STR._att                         2                      5
# B_TOTAL_STR._landed                      2                      1
# R_TD_att                                 1                      1
# R_TD_landed                              0                      1
# B_TD_att                                 0                      0
# B_TD_landed                              0                      0
# R_HEAD_att                               0                      1
# R_HEAD_landed                            0                      1
# B_HEAD_att                               0                      2
# B_HEAD_landed                            0                      0
# R_BODY_att                               1                      0
# R_BODY_landed                            1                      0
# B_BODY_att                               0                      0
# B_BODY_landed                            0                      0
# R_LEG_att                                0                      0
# R_LEG_landed                             0                      0
# B_LEG_att                                1                      2
# B_LEG_landed                             1                      0
# R_DISTANCE_att                           0                      0
# R_DISTANCE_landed                        0                      0
# B_DISTANCE_att                           1                      3
# B_DISTANCE_landed                        1                      0
# R_CLINCH_att                             1                      1
# R_CLINCH_landed                          1                      1
# B_CLINCH_att                             0                      1
# B_CLINCH_landed                          0                      0
# R_GROUND_att                             0                      0
# R_GROUND_landed                          0                      0
# B_GROUND_att                             0                      0
# B_GROUND_landed                          0                      0
#
# [59 rows x 5802 columns]

# %% [markdown]
# ### Creating a title_bout feature and weight_class

# %%
df['Fight_type'].value_counts()
# Out:
# Lightweight Bout                                                       1028
# Welterweight Bout                                                      1002
# Middleweight Bout                                                       745
# Heavyweight Bout                                                        512
# Featherweight Bout                                                      507
#                                                                        ...
# Ultimate Fighter Brazil 3 Heavyweight Tournament Title Bout               1
# Ultimate Fighter Latin America 2 Lightweight Tournament Title Bout        1
# Ultimate Fighter 22 Lightweight Tournament Title Bout                     1
# Ultimate Japan Heavyweight Tournament Title Bout                          1
# TUF Nations Canada vs. Australia Middleweight Tournament Title Bout       1
# Name: Fight_type, Length: 109, dtype: int64

# %%
df['Fight_type'].value_counts()[df['Fight_type'].value_counts() > 1].index
# Out:
# Index(['Lightweight Bout', 'Welterweight Bout', 'Middleweight Bout',
#        'Heavyweight Bout', 'Featherweight Bout', 'Light Heavyweight Bout',
#        'Bantamweight Bout', 'Flyweight Bout', 'Women's Strawweight Bout',
#        'Women's Bantamweight Bout', 'Women's Flyweight Bout',
#        'Open Weight Bout', 'UFC Light Heavyweight Title Bout',
#        'UFC Welterweight Title Bout', 'UFC Heavyweight Title Bout',
#        'Catch Weight Bout', 'UFC Middleweight Title Bout',
#        'UFC Lightweight Title Bout', 'UFC Flyweight Title Bout',
#        'UFC Women's Bantamweight Title Bout', 'UFC Bantamweight Title Bout',
#        'UFC Featherweight Title Bout', 'UFC Women's Strawweight Title Bout',
#        'Women's Featherweight Bout', 'UFC Women's Featherweight Title Bout',
#        'UFC Interim Heavyweight Title Bout',
#        'UFC Superfight Championship Bout', 'UFC Women's Flyweight Title Bout',
#        'UFC Interim Featherweight Title Bout',
#        'UFC Interim Middleweight Title Bout',
#        'UFC Interim Welterweight Title Bout',
#        'UFC Interim Bantamweight Title Bout',
#        'UFC Interim Lightweight Title Bout',
#        'UFC Interim Light Heavyweight Title Bout'],
#       dtype='object')

# %%
df['title_bout'] = df['Fight_type'].apply(lambda X: True if 'Title Bout' in X else False)

# %%
def make_weight_class(X):
    for weight_class in weight_classes:
        if weight_class in X:
            return weight_class
    if X == 'Catch Weight Bout' or 'Catchweight Bout':
        return 'Catch Weight'
    else:
        return 'Open Weight'

# %%
weight_classes = ['Women\'s Strawweight', 'Women\'s Bantamweight', 
                  'Women\'s Featherweight', 'Women\'s Flyweight', 'Lightweight', 
                  'Welterweight', 'Middleweight','Light Heavyweight', 
                  'Heavyweight', 'Featherweight','Bantamweight', 'Flyweight', 'Open Weight']

df['weight_class'] = df['Fight_type'].apply(make_weight_class)

# %%
df[df['weight_class'].isnull()]['Fight_type'].value_counts()
# Out:
# Series([], Name: Fight_type, dtype: int64)

# %% [markdown]
# ### Creating total_time_fought

# %%
df['Format'].value_counts()
# Out:
# 3 Rnd (5-5-5)           5101
# 5 Rnd (5-5-5-5-5)        485
# 1 Rnd + OT (12-3)         80
# No Time Limit             29
# 3 Rnd + OT (5-5-5-5)      22
# 1 Rnd (20)                21
# 1 Rnd + 2OT (15-3-3)      20
# 2 Rnd (5-5)               14
# 1 Rnd (15)                 8
# 1 Rnd (10)                 6
# 1 Rnd (12)                 4
# 1 Rnd + OT (30-5)          3
# 1 Rnd (18)                 2
# 1 Rnd + OT (15-3)          2
# 1 Rnd + OT (27-3)          1
# 1 Rnd + OT (31-5)          1
# 1 Rnd + OT (30-3)          1
# 1 Rnd (30)                 1
# 1 Rnd + 2OT (24-3-3)       1
# Name: Format, dtype: int64

# %%
df['Format'].value_counts().index
# Out:
# Index(['3 Rnd (5-5-5)', '5 Rnd (5-5-5-5-5)', '1 Rnd + OT (12-3)',
#        'No Time Limit', '3 Rnd + OT (5-5-5-5)', '1 Rnd (20)',
#        '1 Rnd + 2OT (15-3-3)', '2 Rnd (5-5)', '1 Rnd (15)', '1 Rnd (10)',
#        '1 Rnd (12)', '1 Rnd + OT (30-5)', '1 Rnd (18)', '1 Rnd + OT (15-3)',
#        '1 Rnd + OT (27-3)', '1 Rnd + OT (31-5)', '1 Rnd + OT (30-3)',
#        '1 Rnd (30)', '1 Rnd + 2OT (24-3-3)'],
#       dtype='object')

# %%
time_in_first_round = {'3 Rnd (5-5-5)': 5*60, '5 Rnd (5-5-5-5-5)': 5*60, '1 Rnd + OT (12-3)': 12*60,
       'No Time Limit': 1, '3 Rnd + OT (5-5-5-5)': 5*60, '1 Rnd (20)': 1*20,
       '2 Rnd (5-5)': 5*60, '1 Rnd (15)': 15*60, '1 Rnd (10)': 10*60,
       '1 Rnd (12)':12*60, '1 Rnd + OT (30-5)': 30*60, '1 Rnd (18)': 18*60, '1 Rnd + OT (15-3)': 15*60,
       '1 Rnd (30)': 30*60, '1 Rnd + OT (31-5)': 31*5,
       '1 Rnd + OT (27-3)': 27*60, '1 Rnd + OT (30-3)': 30*60}

exception_format_time = {'1 Rnd + 2OT (15-3-3)': [15*60, 3*60], '1 Rnd + 2OT (24-3-3)': [24*60, 3*60]}

# '1 Rnd + 2OT (15-3-3)' and '1 Rnd + 2OT (24-3-3)' is not included because it has 3 uneven timed rounds. 
# We'll have to deal with it separately

# %%
# Converting to seconds
df['last_round_time'] = df['last_round_time'].apply(lambda X: int(X.split(':')[0])*60 + int(X.split(':')[1]))

# %%
def get_total_time(row):
    if row['Format'] in time_in_first_round.keys():
        return (row['last_round'] - 1) * time_in_first_round[row['Format']] + row['last_round_time']
    elif row['Format'] in exception_format_time.keys():
        if (row['last_round'] - 1) >= 2:
            return exception_format_time[row['Format']][0] + (row['last_round'] - 2) * \
                    exception_format_time[row['Format']][1] + row['last_round_time']
        else:
            return (row['last_round'] - 1) * exception_format_time[row['Format']][0] + row['last_round_time']
    
# So if the fight ended in round 1, we only need last_round_time. 
# If it ended in round 2, we need the full time of round 1 and the last_round_time
# This works for fights with same time in each round and fights with only two rounds.

# %%
df['total_time_fought(seconds)'] = df.apply(get_total_time, axis=1)

# %%
def get_no_of_rounds(X):
    if X == 'No Time Limit':
        return 1
    else:
        return len(X.split('(')[1].replace(')', '').split('-'))

df['no_of_rounds'] = df['Format'].apply(get_no_of_rounds)

# %%
df
# Out:
#               R_fighter           B_fighter  R_KD  B_KD  R_SIG_STR_pct  \
# 0          Brian Ortega      Chan Sung Jung     2     0           0.59
# 1     Katlyn Chookagian     Jessica Andrade     0     1           0.35
# 2           Jimmy Crute  Modestas Bukauskas     2     0           0.70
# 3         Claudio Silva        James Krause     0     0           0.29
# 4        Thomas Almeida   Jonathan Martinez     0     0           0.37
# ...                 ...                 ...   ...   ...            ...
# 5797       Orlando Wiet    Robert Lucarelli     0     0           0.66
# 5798      Frank Hamaker     Thaddeus Luster     0     0           0.66
# 5799      Johnny Rhodes       David Levicki     0     0           0.64
# 5800      Patrick Smith          Ray Wizard     0     0           1.00
# 5801       Scott Morris      Sean Daugherty     0     0           1.00
#
#       B_SIG_STR_pct  R_TD_pct  B_TD_pct  R_SUB_ATT  B_SUB_ATT  ...  \
# 0              0.38      0.30      0.00          0          0  ...
# 1              0.65      0.00      0.66          0          0  ...
# 2              0.41      0.00      0.00          0          0  ...
# 3              0.59      0.16      0.00          0          0  ...
# 4              0.35      0.00      0.00          0          0  ...
# ...             ...       ...       ...        ...        ...  ...
# 5797           0.33      0.00      1.00          0          1  ...
# 5798           0.00      1.00      0.00          3          0  ...
# 5799           0.80      1.00      0.00          0          0  ...
# 5800           1.00      0.00      0.00          1          0  ...
# 5801           0.00      1.00      0.00          1          0  ...
#
#       B_CLINCH_att  B_CLINCH_landed R_GROUND_att R_GROUND_landed B_GROUND_att  \
# 0                1                0            6               4            0
# 1                9                8            0               0            6
# 2                0                0            2               2            0
# 3                0                0            0               0            0
# 4                4                4            0               0            0
# ...            ...              ...          ...             ...          ...
# 5797             0                0            9               7            0
# 5798             0                0            2               1            0
# 5799             2                2           15               9            1
# 5800             0                0            0               0            0
# 5801             1                0            0               0            0
#
#       B_GROUND_landed  title_bout       weight_class  \
# 0                   0       False      Featherweight
# 1                   6       False  Women's Flyweight
# 2                   0       False  Light Heavyweight
# 3                   0       False       Welterweight
# 4                   0       False      Featherweight
# ...               ...         ...                ...
# 5797                0       False        Open Weight
# 5798                0       False        Open Weight
# 5799                1       False        Open Weight
# 5800                0       False        Open Weight
# 5801                0       False        Open Weight
#
#      total_time_fought(seconds) no_of_rounds
# 0                          1500            5
# 1                           295            3
# 2                           121            3
# 3                           900            3
# 4                           900            3
# ...                         ...          ...
# 5797                        170            1
# 5798                        292            1
# 5799                        733            1
# 5800                         58            1
# 5801                         20            1
#
# [5802 rows x 63 columns]

# %%
df.drop(['Format', 'Fight_type', 'last_round_time'], axis = 1, inplace=True)

# %% [markdown]
# ### Create CTRL_time(seconds)

# %%
CTRL_columns = ['R_CTRL','B_CTRL']

def conv_to_sec(X):
    if X != '--':
        return int(X.split(':')[0])*60 + int(X.split(':')[1])
    else:
        # if '--' means there was no time spent on the ground. 
        # Taking a call here to consider this as 0 seconds
        return 0

for column in CTRL_columns:
    df[column+'_time(seconds)'] = df[column].apply(conv_to_sec)

# %%
df.T
# Out:
#                                       0                  1     \
# R_fighter                     Brian Ortega  Katlyn Chookagian
# B_fighter                   Chan Sung Jung    Jessica Andrade
# R_KD                                     2                  0
# B_KD                                     0                  1
# R_SIG_STR_pct                         0.59               0.35
# ...                                    ...                ...
# weight_class                 Featherweight  Women's Flyweight
# total_time_fought(seconds)            1500                295
# no_of_rounds                             5                  3
# R_CTRL_time(seconds)                    57                 25
# B_CTRL_time(seconds)                     0                146
#
#                                           2              3     \
# R_fighter                          Jimmy Crute  Claudio Silva
# B_fighter                   Modestas Bukauskas   James Krause
# R_KD                                         2              0
# B_KD                                         0              0
# R_SIG_STR_pct                              0.7           0.29
# ...                                        ...            ...
# weight_class                 Light Heavyweight   Welterweight
# total_time_fought(seconds)                 121            900
# no_of_rounds                                 3              3
# R_CTRL_time(seconds)                        25             58
# B_CTRL_time(seconds)                         0             14
#
#                                          4                  5     \
# R_fighter                      Thomas Almeida     Mateusz Gamrot
# B_fighter                   Jonathan Martinez  Guram Kutateladze
# R_KD                                        0                  0
# B_KD                                        0                  1
# R_SIG_STR_pct                            0.37               0.41
# ...                                       ...                ...
# weight_class                    Featherweight        Lightweight
# total_time_fought(seconds)                900                900
# no_of_rounds                                3                  3
# R_CTRL_time(seconds)                        2                209
# B_CTRL_time(seconds)                        0                  1
#
#                                          6              7                8     \
# R_fighter                   Gillian Robertson   Junyong Park  Jamie Mullarkey
# B_fighter                     Poliana Botelho  John Phillips       Fares Ziam
# R_KD                                        0              0                0
# B_KD                                        0              0                0
# R_SIG_STR_pct                            0.58           0.47             0.27
# ...                                       ...            ...              ...
# weight_class                Women's Flyweight   Middleweight      Lightweight
# total_time_fought(seconds)                900            900              900
# no_of_rounds                                3              3                3
# R_CTRL_time(seconds)                      574            791              416
# B_CTRL_time(seconds)                       76              0               72
#
#                                              9     ...           5792  \
# R_fighter                   Gadzhimurad Antigulov  ...  Johnny Rhodes
# B_fighter                           Maxim Grishin  ...    Fred Ettish
# R_KD                                            0  ...              1
# B_KD                                            0  ...              0
# R_SIG_STR_pct                                0.52  ...           0.44
# ...                                           ...  ...            ...
# weight_class                    Light Heavyweight  ...    Open Weight
# total_time_fought(seconds)                    598  ...            187
# no_of_rounds                                    3  ...              1
# R_CTRL_time(seconds)                          159  ...              0
# B_CTRL_time(seconds)                          141  ...              0
#
#                                      5793             5794           5795  \
# R_fighter                   Patrick Smith     Royce Gracie  Jason DeLucia
# B_fighter                    Scott Morris  Minoki Ichihara    Scott Baker
# R_KD                                    0                0              0
# B_KD                                    0                0              0
# R_SIG_STR_pct                        0.76              0.5            0.6
# ...                                   ...              ...            ...
# weight_class                  Open Weight      Open Weight    Open Weight
# total_time_fought(seconds)             30              308            401
# no_of_rounds                            1                1              1
# R_CTRL_time(seconds)                    0                0              0
# B_CTRL_time(seconds)                    0                0              0
#
#                                           5796              5797  \
# R_fighter                        Remco Pardoel      Orlando Wiet
# B_fighter                   Alberta Cerra Leon  Robert Lucarelli
# R_KD                                         0                 0
# B_KD                                         0                 0
# R_SIG_STR_pct                             0.66              0.66
# ...                                        ...               ...
# weight_class                       Open Weight       Open Weight
# total_time_fought(seconds)                 591               170
# no_of_rounds                                 1                 1
# R_CTRL_time(seconds)                         0                 0
# B_CTRL_time(seconds)                         0                 0
#
#                                        5798           5799           5800  \
# R_fighter                     Frank Hamaker  Johnny Rhodes  Patrick Smith
# B_fighter                   Thaddeus Luster  David Levicki     Ray Wizard
# R_KD                                      0              0              0
# B_KD                                      0              0              0
# R_SIG_STR_pct                          0.66           0.64              1
# ...                                     ...            ...            ...
# weight_class                    Open Weight    Open Weight    Open Weight
# total_time_fought(seconds)              292            733             58
# no_of_rounds                              1              1              1
# R_CTRL_time(seconds)                      0              0              0
# B_CTRL_time(seconds)                      0              0              0
#
#                                       5801
# R_fighter                     Scott Morris
# B_fighter                   Sean Daugherty
# R_KD                                     0
# B_KD                                     0
# R_SIG_STR_pct                            1
# ...                                    ...
# weight_class                   Open Weight
# total_time_fought(seconds)              20
# no_of_rounds                             1
# R_CTRL_time(seconds)                     0
# B_CTRL_time(seconds)                     0
#
# [62 rows x 5802 columns]

# %%
df.drop(['R_CTRL','B_CTRL'], axis = 1, inplace=True)

# %% [markdown]
# ### Create another DataFrame to save the compiled data per fighter (Our Prediction DataFrame)

# %%
df.columns
# Out:
# Index(['R_fighter', 'B_fighter', 'R_KD', 'B_KD', 'R_SIG_STR_pct',
#        'B_SIG_STR_pct', 'R_TD_pct', 'B_TD_pct', 'R_SUB_ATT', 'B_SUB_ATT',
#        'R_REV', 'B_REV', 'win_by', 'last_round', 'Referee', 'date', 'location',
#        'Winner', 'R_SIG_STR._att', 'R_SIG_STR._landed', 'B_SIG_STR._att',
#        'B_SIG_STR._landed', 'R_TOTAL_STR._att', 'R_TOTAL_STR._landed',
#        'B_TOTAL_STR._att', 'B_TOTAL_STR._landed', 'R_TD_att', 'R_TD_landed',
#        'B_TD_att', 'B_TD_landed', 'R_HEAD_att', 'R_HEAD_landed', 'B_HEAD_att',
#        'B_HEAD_landed', 'R_BODY_att', 'R_BODY_landed', 'B_BODY_att',
#        'B_BODY_landed', 'R_LEG_att', 'R_LEG_landed', 'B_LEG_att',
#        'B_LEG_landed', 'R_DISTANCE_att', 'R_DISTANCE_landed', 'B_DISTANCE_att',
#        'B_DISTANCE_landed', 'R_CLINCH_att', 'R_CLINCH_landed', 'B_CLINCH_att',
#        'B_CLINCH_landed', 'R_GROUND_att', 'R_GROUND_landed', 'B_GROUND_att',
#        'B_GROUND_landed', 'title_bout', 'weight_class',
#        'total_time_fought(seconds)', 'no_of_rounds', 'R_CTRL_time(seconds)',
#        'B_CTRL_time(seconds)'],
#       dtype='object')

# %%
df2 = df.copy()

# %%
df2.drop(['R_KD', 'B_KD', 'R_SIG_STR_pct',
       'B_SIG_STR_pct', 'R_TD_pct', 'B_TD_pct', 'R_SUB_ATT', 'B_SUB_ATT',
       'R_CTRL_time(seconds)', 'B_CTRL_time(seconds)', 'R_REV', 'B_REV', 'win_by', 'last_round', 
        'R_SIG_STR._att', 'R_SIG_STR._landed',
       'B_SIG_STR._att', 'B_SIG_STR._landed', 'R_TOTAL_STR._att',
       'R_TOTAL_STR._landed', 'B_TOTAL_STR._att', 'B_TOTAL_STR._landed',
       'R_TD_att', 'R_TD_landed', 'B_TD_att', 'B_TD_landed', 'R_HEAD_att',
       'R_HEAD_landed', 'B_HEAD_att', 'B_HEAD_landed', 'R_BODY_att',
       'R_BODY_landed', 'B_BODY_att', 'B_BODY_landed', 'R_LEG_att',
       'R_LEG_landed', 'B_LEG_att', 'B_LEG_landed', 'R_DISTANCE_att',
       'R_DISTANCE_landed', 'B_DISTANCE_att', 'B_DISTANCE_landed',
       'R_CLINCH_att', 'R_CLINCH_landed', 'B_CLINCH_att', 'B_CLINCH_landed',
       'R_GROUND_att', 'R_GROUND_landed', 'B_GROUND_att', 'B_GROUND_landed',
        'total_time_fought(seconds)'], axis = 1, inplace=True)
df2
# Out:
#               R_fighter           B_fighter         Referee              date  \
# 0          Brian Ortega      Chan Sung Jung  Lukasz Bosacki  October 17, 2020
# 1     Katlyn Chookagian     Jessica Andrade  Lukasz Bosacki  October 17, 2020
# 2           Jimmy Crute  Modestas Bukauskas  Anders Ohlsson  October 17, 2020
# 3         Claudio Silva        James Krause  Lukasz Bosacki  October 17, 2020
# 4        Thomas Almeida   Jonathan Martinez  Anders Ohlsson  October 17, 2020
# ...                 ...                 ...             ...               ...
# 5797       Orlando Wiet    Robert Lucarelli   John McCarthy    March 11, 1994
# 5798      Frank Hamaker     Thaddeus Luster   John McCarthy    March 11, 1994
# 5799      Johnny Rhodes       David Levicki   John McCarthy    March 11, 1994
# 5800      Patrick Smith          Ray Wizard   John McCarthy    March 11, 1994
# 5801       Scott Morris      Sean Daugherty   John McCarthy    March 11, 1994
#
#                                         location             Winner  \
# 0     Abu Dhabi, Abu Dhabi, United Arab Emirates       Brian Ortega
# 1     Abu Dhabi, Abu Dhabi, United Arab Emirates    Jessica Andrade
# 2     Abu Dhabi, Abu Dhabi, United Arab Emirates        Jimmy Crute
# 3     Abu Dhabi, Abu Dhabi, United Arab Emirates       James Krause
# 4     Abu Dhabi, Abu Dhabi, United Arab Emirates  Jonathan Martinez
# ...                                          ...                ...
# 5797                       Denver, Colorado, USA       Orlando Wiet
# 5798                       Denver, Colorado, USA      Frank Hamaker
# 5799                       Denver, Colorado, USA      Johnny Rhodes
# 5800                       Denver, Colorado, USA      Patrick Smith
# 5801                       Denver, Colorado, USA       Scott Morris
#
#       title_bout       weight_class  no_of_rounds
# 0          False      Featherweight             5
# 1          False  Women's Flyweight             3
# 2          False  Light Heavyweight             3
# 3          False       Welterweight             3
# 4          False      Featherweight             3
# ...          ...                ...           ...
# 5797       False        Open Weight             1
# 5798       False        Open Weight             1
# 5799       False        Open Weight             1
# 5800       False        Open Weight             1
# 5801       False        Open Weight             1
#
# [5802 rows x 9 columns]

# %% [markdown]
# ### Compiling Data per fighter

# %%
red_fighters = df['R_fighter'].value_counts().index
blue_fighters = df['B_fighter'].value_counts().index

fighters = list(set(red_fighters) | set(blue_fighters))

# %%
def get_renamed_winner(row):
    if row['R_fighter'] == row['Winner']:
        return 'Red'
    elif row['B_fighter'] == row['Winner']:
        return 'Blue'
    elif row['Winner'] == 'Draw':
        return 'Draw'

df2['Winner'] = df2[['R_fighter', 'B_fighter', 'Winner']].apply(get_renamed_winner, axis=1)

# %%
df = pd.concat([df,pd.get_dummies(df['win_by'], prefix='win_by')],axis=1)
df.drop(['win_by'],axis=1, inplace=True)

# %%
Numerical_columns = ['hero_KD', 'opp_KD', 'hero_SIG_STR_pct',
       'opp_SIG_STR_pct', 'hero_TD_pct', 'opp_TD_pct', 'hero_SUB_ATT', 'opp_SUB_ATT',
        'hero_REV', 'opp_REV', 'hero_SIG_STR._att', 'hero_SIG_STR._landed',
       'opp_SIG_STR._att', 'opp_SIG_STR._landed', 'hero_TOTAL_STR._att',
       'hero_TOTAL_STR._landed', 'opp_TOTAL_STR._att', 'opp_TOTAL_STR._landed',
       'hero_TD_att', 'hero_TD_landed', 'opp_TD_att', 'opp_TD_landed', 'hero_HEAD_att',
       'hero_HEAD_landed', 'opp_HEAD_att', 'opp_HEAD_landed', 'hero_BODY_att',
       'hero_BODY_landed', 'opp_BODY_att', 'opp_BODY_landed', 'hero_LEG_att',
       'hero_LEG_landed', 'opp_LEG_att', 'opp_LEG_landed', 'hero_DISTANCE_att',
       'hero_DISTANCE_landed', 'opp_DISTANCE_att', 'opp_DISTANCE_landed',
       'hero_CLINCH_att', 'hero_CLINCH_landed', 'opp_CLINCH_att', 'opp_CLINCH_landed',
       'hero_GROUND_att', 'hero_GROUND_landed', 'opp_GROUND_att', 'opp_GROUND_landed', 
        'hero_CTRL_time(seconds)', 'opp_CTRL_time(seconds)',
       'total_time_fought(seconds)']

Categorical_columns = ['win_by', 'last_round',
        'Winner', 'title_bout']

# %% [markdown]
# For all `Numerical_columns`, we take the average of those columns for every fighter of every fight they had up until that point.
#
# For `Categorical_columns`, we have to come up with different ideas for each column:
#
# * Each `win_by` will be a column of it's own
# * from `last_round` we can get, `total_rounds_fought`
# * from `total_time_fought` we can get `average_time_fought`
# * from `Winner` we get `wins`, `losses`, `draw`, `current_streak`, `longest_streak`
# * from `title_bout` we can get `no_of_title_fights`

# %%
import re

def lreplace(pattern, sub, string):
    """
    Replaces 'pattern' in 'string' with 'sub' if 'pattern' starts 'string'.
    """
    return re.sub('^%s' % pattern, sub, string)

# %%
red = df.groupby('R_fighter')
blue = df.groupby('B_fighter')

# %%
def get_fighter_red(fighter_name):
    try:
        fighter_red = red.get_group(fighter_name)
    except:
        return None
    rename_columns = {}
    for column in fighter_red.columns:
        if re.search('^R_', column) is not None:
            rename_columns[column] = lreplace('R_', 'hero_', column)
        elif re.search('^B_', column) is not None:
            rename_columns[column] = lreplace('B_', 'opp_', column)
    fighter_red = fighter_red.rename(rename_columns, axis='columns')
    return fighter_red

# %%
def get_fighter_blue(fighter_name):
    try:
        fighter_blue = blue.get_group(fighter_name)
    except:
        return None
    rename_columns = {}
    for column in fighter_blue.columns:
        if re.search('^B_', column) is not None:
            rename_columns[column] = lreplace('B_', 'hero_', column)
        elif re.search('^R_', column) is not None:
            rename_columns[column] = lreplace('R_', 'opp_', column)
    fighter_blue = fighter_blue.rename(rename_columns, axis='columns')
    return fighter_blue

# %%
def get_result_stats(result_list):
    result_list.reverse() # To get it in ascending order
    current_win_streak = 0
    current_lose_streak = 0
    longest_win_streak = 0
    wins = 0
    losses = 0
    draw = 0
    for result in result_list:
        if result == 'hero':
            wins += 1
            current_win_streak += 1
            current_lose_streak = 0
            if longest_win_streak < current_win_streak:
                longest_win_streak += 1
        elif result == 'opp':
            losses += 1
            current_win_streak = 0
            current_lose_streak += 1
        elif result == 'draw':
            draw += 1
            current_lose_streak = 0
            current_win_streak = 0
            
    return current_win_streak, current_lose_streak, longest_win_streak, wins, losses, draw

# %%
win_by_columns = ['win_by_Decision - Majority', 'win_by_Decision - Split',
       'win_by_Decision - Unanimous', 'win_by_KO/TKO','win_by_Submission',
       'win_by_TKO - Doctor\'s Stoppage']

# %%
temp_blue_frame = pd.DataFrame()
temp_red_frame = pd.DataFrame()
result_stats = ['current_win_streak', 'current_lose_streak', 'longest_win_streak', 'wins', 'losses', 'draw']

for fighter_name in fighters:
    fighter_red = get_fighter_red(fighter_name)
    fighter_blue = get_fighter_blue(fighter_name)
    fighter_index = None
    
    if fighter_red is None:
        fighter = fighter_blue
        fighter_index = 'blue'
    elif fighter_blue is None:
        fighter = fighter_red
        fighter_index = 'red'
    else:
        fighter = pd.concat([fighter_red, fighter_blue]).sort_index(ascending=False)
    
    fighter['Winner'] = fighter['Winner'].apply(lambda X: 'hero' if X == fighter_name else 'opp')

    for i, index in enumerate(fighter.index):
        fighter_slice = fighter[(i+1):].sort_index(ascending=False)
        s = fighter_slice[Numerical_columns].ewm(span=3, adjust=False).mean().tail(1)
        if len(s) != 0:
            pass
        else:
            s.loc[len(s)] = [np.NaN for _ in s.columns]
        s['total_rounds_fought'] = fighter_slice['last_round'].sum()
        s['total_title_bouts'] = fighter_slice[fighter_slice['title_bout']==True]['title_bout'].count()
        s['hero_fighter'] = fighter_name
        results = get_result_stats(list(fighter_slice['Winner']))
        for result_stat, result in zip(result_stats, results):
            s[result_stat] = result
        win_by_results = fighter_slice[fighter_slice['Winner'] == 'hero'][win_by_columns].sum()
        for win_by_column,win_by_result in zip(win_by_columns, win_by_results):
            s[win_by_column] = win_by_result
        s.index = [index]


        if fighter_index is None:
            if index in fighter_blue.index:
                temp_blue_frame = temp_blue_frame.append(s)
            elif index in fighter_red.index:
                temp_red_frame = temp_red_frame.append(s)
        elif fighter_index == 'blue':
            temp_blue_frame = temp_blue_frame.append(s)
        elif fighter_index == 'red':
            temp_red_frame = temp_red_frame.append(s)

# %%
temp_blue_frame.T
# Out:
#                                   1130  3629 3726      1702   710   473   \
# hero_KD                              0     0  NaN     0.625    0.5     1
# opp_KD                               0     0  NaN         0      0     0
# hero_SIG_STR_pct                0.4375  0.29  NaN  0.423125  0.355   0.5
# opp_SIG_STR_pct                 0.4225  0.51  NaN  0.438125   0.41  0.41
# hero_TD_pct                      0.125  0.16  NaN    0.0575      0     0
# ...                                ...   ...  ...       ...    ...   ...
# win_by_Decision - Split              0     0    0         0      0     0
# win_by_Decision - Unanimous          1     0    0         2      0     0
# win_by_KO/TKO                        0     0    0         1      1     1
# win_by_Submission                    0     0    0         0      0     0
# win_by_TKO - Doctor's Stoppage       0     0    0         0      0     0
#
#                                     1165     788    330  156   ...      5046  \
# hero_KD                          0.09375    0.125      0  NaN  ...    0.0625
# opp_KD                              0.25     0.25    0.5  NaN  ...       0.5
# hero_SIG_STR_pct                0.439375     0.44   0.43  NaN  ...   0.33625
# opp_SIG_STR_pct                 0.425938  0.41125  0.475  NaN  ...   0.39625
# hero_TD_pct                        0.185  0.15625  0.125  NaN  ...  0.143125
# ...                                  ...      ...    ...  ...  ...       ...
# win_by_Decision - Split                2        2      1    0  ...         0
# win_by_Decision - Unanimous            2        1      0    0  ...         0
# win_by_KO/TKO                          0        0      0    0  ...         1
# win_by_Submission                      1        0      0    0  ...         1
# win_by_TKO - Doctor's Stoppage         0        0      0    0  ...         0
#
#                                  4877  4820 4644 317       4569      4241  \
# hero_KD                             0     0  NaN  NaN  0.015625         0
# opp_KD                            0.5     1  NaN  NaN  0.046875    0.0625
# hero_SIG_STR_pct                 0.32  0.26  NaN  NaN  0.396484    0.3925
# opp_SIG_STR_pct                 0.425  0.36  NaN  NaN   0.53709  0.537187
# hero_TD_pct                     0.155   0.2  NaN  NaN  0.382656   0.37875
# ...                               ...   ...  ...  ...       ...       ...
# win_by_Decision - Split             0     0    0    0         0         0
# win_by_Decision - Unanimous         0     0    0    0         2         1
# win_by_KO/TKO                       0     0    0    0         3         0
# win_by_Submission                   0     0    0    0         1         1
# win_by_TKO - Doctor's Stoppage      0     0    0    0         0         0
#
#                                    4126  3059 2812
# hero_KD                               0     0  NaN
# opp_KD                           0.0625     0  NaN
# hero_SIG_STR_pct                0.40125  0.38  NaN
# opp_SIG_STR_pct                 0.53875  0.67  NaN
# hero_TD_pct                     0.37875  0.33  NaN
# ...                                 ...   ...  ...
# win_by_Decision - Split               0     0    0
# win_by_Decision - Unanimous           1     0    0
# win_by_KO/TKO                         0     0    0
# win_by_Submission                     1     0    0
# win_by_TKO - Doctor's Stoppage        0     0    0
#
# [64 rows x 5802 columns]

# %% [markdown]
# ### Adding fighter details like height, weight, reach, stance and dob

# %%
fighter_details = fighter_details[fighter_details.index.isin(fighters)]
for col in fighter_details.columns:
    print(f"Number of NaN in {col} : {fighter_details[col].isnull().sum()}")
# Out:
# Number of NaN in Height : 13
# Number of NaN in Weight : 10
# Number of NaN in Reach : 645
# Number of NaN in Stance : 75
# Number of NaN in DOB : 141
# Number of NaN in SLpM : 0
# Number of NaN in Str_Acc : 0
# Number of NaN in SApM : 0
# Number of NaN in Str_Def : 0
# Number of NaN in TD_Avg : 0
# Number of NaN in TD_Acc : 0
# Number of NaN in TD_Def : 0
# Number of NaN in Sub_Avg : 0

# %%
def convert_to_cms(X):
    if X is np.NaN:
        return X
    elif len(X.split("'")) == 2:
        feet = float(X.split("'")[0])
        inches = int(X.split("'")[1].replace(' ', '').replace('"',''))
        return (feet * 30.48) + (inches * 2.54)
    else:
        return float(X.replace('"','')) * 2.54

# %%
fighter_details['Height_cms'] = fighter_details['Height'].apply(convert_to_cms)
fighter_details['Reach_cms'] = fighter_details['Reach'].apply(convert_to_cms)

# %%
fighter_details['Weight_lbs'] = fighter_details['Weight'].apply(lambda X: float(X.replace(' lbs.', '')) if X is not np.NaN else X)

# %%
pct_columns = ['Str_Acc','Str_Def', 'TD_Acc', 'TD_Def']

def pct_to_frac(X):
    if X != np.NaN:
        return float(X.replace('%', ''))/100
    else:
        return 0

for column in pct_columns:
    fighter_details[column] = fighter_details[column].apply(pct_to_frac)

# %%
fighter_details.drop(['Height', 'Weight', 'Reach'], axis=1, inplace=True)

# %%
fighter_details.reset_index(inplace=True)
temp_red_frame.reset_index(inplace=True)
temp_blue_frame.reset_index(inplace=True)

# %%
temp_blue_frame = temp_blue_frame.merge(fighter_details, left_on='hero_fighter', right_on='fighter_name', how='left')
temp_blue_frame.set_index('index', inplace=True)

# %%
temp_blue_frame[['hero_fighter', 'fighter_name', 'Height_cms', 'Weight_lbs', 'DOB']].head(20)
# Out:
#           hero_fighter     fighter_name  Height_cms  Weight_lbs           DOB
# index
# 1130       Brad Katona      Brad Katona      167.64       135.0  Dec 19, 1991
# 3629   Motonobu Tezuka  Motonobu Tezuka      170.18       135.0  Aug 29, 1987
# 3726   Motonobu Tezuka  Motonobu Tezuka      170.18       135.0  Aug 29, 1987
# 1702    Andrew Sanchez   Andrew Sanchez      185.42       185.0  Apr 08, 1988
# 710     Andrew Sanchez   Andrew Sanchez      185.42       185.0  Apr 08, 1988
# 473     Andrew Sanchez   Andrew Sanchez      185.42       185.0  Apr 08, 1988
# 1165           Dan Ige          Dan Ige      170.18       145.0  Aug 06, 1991
# 788            Dan Ige          Dan Ige      170.18       145.0  Aug 06, 1991
# 330            Dan Ige          Dan Ige      170.18       145.0  Aug 06, 1991
# 156            Dan Ige          Dan Ige      170.18       145.0  Aug 06, 1991
# 1628     Frank Camacho    Frank Camacho      177.80       170.0  May 18, 1989
# 1431     Frank Camacho    Frank Camacho      177.80       170.0  May 18, 1989
# 1321     Frank Camacho    Frank Camacho      177.80       170.0  May 18, 1989
# 1047     Frank Camacho    Frank Camacho      177.80       170.0  May 18, 1989
# 676      Frank Camacho    Frank Camacho      177.80       170.0  May 18, 1989
# 2500    Teemu Packalen   Teemu Packalen      185.42       155.0  May 22, 1987
# 1726    Teemu Packalen   Teemu Packalen      185.42       155.0  May 22, 1987
# 531     Teemu Packalen   Teemu Packalen      185.42       155.0  May 22, 1987
# 5619       Royce Alger      Royce Alger      177.80       199.0           NaN
# 5692       Royce Alger      Royce Alger      177.80       199.0           NaN

# %%
temp_red_frame = temp_red_frame.merge(fighter_details, left_on='hero_fighter', right_on='fighter_name', how='left')
temp_red_frame.set_index('index', inplace=True)

# %%
temp_blue_frame.drop('fighter_name', axis=1, inplace=True)
temp_red_frame.drop('fighter_name', axis=1, inplace=True)

# %%
blue_frame = temp_blue_frame.add_prefix('B_')
red_frame = temp_red_frame.add_prefix('R_')

# %%
frame = blue_frame.join(red_frame, how='outer')

# %%
rename_cols = {}
for col in frame.columns:
    if 'hero' in col:
        rename_cols[col] = col.replace('_hero_', '_avg_').replace('.', '')
    if 'opp' in col:
        rename_cols[col] = col.replace('_opp_', '_avg_opp_').replace('.', '')
    if 'win_by' in col:
        rename_cols[col] = col.replace(' ', '').replace('-', '_').replace('\'s', '_')

# %%
frame.rename(rename_cols, axis='columns', inplace=True)

# %%
frame.drop(['R_avg_fighter','B_avg_fighter'], axis=1, inplace=True)

# %%
df2 = df2.join(frame, how='outer')

# %% [markdown]
# ### Create Age

# %%
df2['R_DOB'] = pd.to_datetime(df2['R_DOB'])
df2['B_DOB'] = pd.to_datetime(df2['B_DOB'])
df2['date'] = pd.to_datetime(df2['date'])

# %%
def get_age(row):
    B_age = (row['date'] - row['B_DOB']).days
    R_age = (row['date'] - row['R_DOB']).days
    if np.isnan(B_age)!=True:
        B_age = math.floor(B_age/365.25)
    if np.isnan(R_age)!=True:
        R_age = math.floor(R_age/365.25)
    return pd.Series([B_age, R_age], index=['B_age', 'R_age'])

# %%
df2[['B_age', 'R_age']]= df2[['date', 'R_DOB', 'B_DOB']].apply(get_age, axis=1)

# %%
df2.drop(['R_DOB', 'B_DOB'], axis=1, inplace=True)

# %%
# df2.drop(df2.index[df2['Winner'] == 'draw'], inplace = True)

# %%
# df2.to_csv('../data/data.csv', index=False)

# %%
df2
# Out:
#               R_fighter           B_fighter         Referee       date  \
# 0          Brian Ortega      Chan Sung Jung  Lukasz Bosacki 2020-10-17
# 1     Katlyn Chookagian     Jessica Andrade  Lukasz Bosacki 2020-10-17
# 2           Jimmy Crute  Modestas Bukauskas  Anders Ohlsson 2020-10-17
# 3         Claudio Silva        James Krause  Lukasz Bosacki 2020-10-17
# 4        Thomas Almeida   Jonathan Martinez  Anders Ohlsson 2020-10-17
# ...                 ...                 ...             ...        ...
# 5797       Orlando Wiet    Robert Lucarelli   John McCarthy 1994-03-11
# 5798      Frank Hamaker     Thaddeus Luster   John McCarthy 1994-03-11
# 5799      Johnny Rhodes       David Levicki   John McCarthy 1994-03-11
# 5800      Patrick Smith          Ray Wizard   John McCarthy 1994-03-11
# 5801       Scott Morris      Sean Daugherty   John McCarthy 1994-03-11
#
#                                         location Winner  title_bout  \
# 0     Abu Dhabi, Abu Dhabi, United Arab Emirates    Red       False
# 1     Abu Dhabi, Abu Dhabi, United Arab Emirates   Blue       False
# 2     Abu Dhabi, Abu Dhabi, United Arab Emirates    Red       False
# 3     Abu Dhabi, Abu Dhabi, United Arab Emirates   Blue       False
# 4     Abu Dhabi, Abu Dhabi, United Arab Emirates   Blue       False
# ...                                          ...    ...         ...
# 5797                       Denver, Colorado, USA    Red       False
# 5798                       Denver, Colorado, USA    Red       False
# 5799                       Denver, Colorado, USA    Red       False
# 5800                       Denver, Colorado, USA    Red       False
# 5801                       Denver, Colorado, USA    Red       False
#
#            weight_class  no_of_rounds  B_avg_KD  ...  R_Str_Def  R_TD_Avg  \
# 0         Featherweight             5       NaN  ...       0.52      0.80
# 1     Women's Flyweight             3       NaN  ...       0.62      0.30
# 2     Light Heavyweight             3       NaN  ...       0.54      4.33
# 3          Welterweight             3       NaN  ...       0.43      3.01
# 4         Featherweight             3     1.625  ...       0.64      0.00
# ...                 ...           ...       ...  ...        ...       ...
# 5797        Open Weight             1       NaN  ...       0.00      0.00
# 5798        Open Weight             1       NaN  ...       0.00      0.00
# 5799        Open Weight             1       NaN  ...       0.00      0.00
# 5800        Open Weight             1       NaN  ...       0.00      0.00
# 5801        Open Weight             1       NaN  ...       0.00      0.00
#
#       R_TD_Acc  R_TD_Def  R_Sub_Avg  R_Height_cms  R_Reach_cms  R_Weight_lbs  \
# 0         0.21      0.56        1.1        172.72       175.26         145.0
# 1         0.15      0.48        0.5        175.26       172.72         125.0
# 2         0.75      0.60        2.4        187.96       187.96         205.0
# 3         0.28      0.66        1.6        180.34       180.34         170.0
# 4         0.00      0.75        0.0        170.18       177.80         145.0
# ...        ...       ...        ...           ...          ...           ...
# 5797      0.00      0.00        0.0        177.80          NaN         170.0
# 5798      0.00      0.00        0.0           NaN          NaN           NaN
# 5799      0.00      0.00        0.0        182.88          NaN         210.0
# 5800      0.00      0.00        0.0        187.96          NaN         225.0
# 5801      0.00      0.00        0.0        177.80          NaN         210.0
#
#       B_age  R_age
# 0      33.0   29.0
# 1      29.0   31.0
# 2      26.0   24.0
# 3      34.0   38.0
# 4      26.0   29.0
# ...     ...    ...
# 5797    NaN    NaN
# 5798    NaN    NaN
# 5799    NaN    NaN
# 5800    NaN   30.0
# 5801   18.0    NaN
#
# [5802 rows x 161 columns]
