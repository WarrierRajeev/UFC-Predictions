# %% [markdown]
# # Data Preparation

# %% [markdown]
# ## Why do this step?
#
# - The data we scraped from the UFC website is raw data. Every row contains information about a fight that took place i.e. details like how many strikes were thrown in that fight and who won the fight.
# - To prepare the data for prediction, every row can contain only an accurate representation of what each fighter has done in fights up until that fight! No data that was recorded during the fight can be present in that row.
# - Our Target variable is Winner. The task has to be to predict the winner from the data available of each fighter up until the fight

# %% [markdown]
# ## Looking at the data

# %%
import pandas as pd
import numpy as np
import math

df = pd.read_csv('../../total_fight_data.csv', sep=';')
fighter_details = pd.read_csv('../data/fighter_details.csv', index_col='fighter_name')

# %%
df.head()
# Out:
#               R_fighter        B_fighter  R_KD  B_KD  R_SIG_STR. B_SIG_STR.  \
# 0            Holly Holm     Irene Aldana     0     0  154 of 301  69 of 185
# 1      Yorgan De Castro    Carlos Felipe     0     0   48 of 100  78 of 177
# 2  Germaine de Randamie    Julianna Pena     0     0    37 of 91   27 of 91
# 3        Kyler Phillips     Cameron Else     0     0    32 of 78   11 of 30
# 4       Dequan Townsend  Dusko Todorovic     0     0    13 of 41  85 of 134
#
#   R_SIG_STR_pct B_SIG_STR_pct R_TOTAL_STR. B_TOTAL_STR.  ...  B_GROUND  \
# 0           51%           37%   187 of 342    92 of 210  ...    0 of 0
# 1           48%           44%   113 of 174    88 of 187  ...    0 of 0
# 2           40%           29%    57 of 119    58 of 125  ...   7 of 14
# 3           41%           36%     34 of 80     20 of 43  ...    1 of 2
# 4           31%           63%     21 of 49   109 of 167  ...  29 of 47
#
#                  win_by last_round last_round_time             Format  \
# 0  Decision - Unanimous          5            5:00  5 Rnd (5-5-5-5-5)
# 1  Decision - Unanimous          3            5:00      3 Rnd (5-5-5)
# 2            Submission          3            3:25      3 Rnd (5-5-5)
# 3                KO/TKO          2            0:44      3 Rnd (5-5-5)
# 4                KO/TKO          2            3:15      3 Rnd (5-5-5)
#
#         Referee              date                                    location  \
# 0  Marc Goddard  October 03, 2020  Abu Dhabi, Abu Dhabi, United Arab Emirates
# 1  Kevin Sataki  October 03, 2020  Abu Dhabi, Abu Dhabi, United Arab Emirates
# 2           NaN  October 03, 2020  Abu Dhabi, Abu Dhabi, United Arab Emirates
# 3  Marc Goddard  October 03, 2020  Abu Dhabi, Abu Dhabi, United Arab Emirates
# 4  Jason Herzog  October 03, 2020  Abu Dhabi, Abu Dhabi, United Arab Emirates
#
#                   Fight_type                Winner
# 0  Women's Bantamweight Bout            Holly Holm
# 1           Heavyweight Bout         Carlos Felipe
# 2  Women's Bantamweight Bout  Germaine de Randamie
# 3          Bantamweight Bout        Kyler Phillips
# 4          Middleweight Bout       Dusko Todorovic
#
# [5 rows x 41 columns]

# %%
df.T
# Out:
#                                                        0     \
# R_fighter                                        Holly Holm
# B_fighter                                      Irene Aldana
# R_KD                                                      0
# B_KD                                                      0
# R_SIG_STR.                                       154 of 301
# B_SIG_STR.                                        69 of 185
# R_SIG_STR_pct                                           51%
# B_SIG_STR_pct                                           37%
# R_TOTAL_STR.                                     187 of 342
# B_TOTAL_STR.                                      92 of 210
# R_TD                                                5 of 14
# B_TD                                                 0 of 0
# R_TD_pct                                                35%
# B_TD_pct                                                ---
# R_SUB_ATT                                                 0
# B_SUB_ATT                                                 0
# R_REV                                                     0
# B_REV                                                     0
# R_CTRL                                                 5:16
# B_CTRL                                                 0:03
# R_HEAD                                            81 of 214
# B_HEAD                                            38 of 128
# R_BODY                                             56 of 68
# B_BODY                                             12 of 30
# R_LEG                                              17 of 19
# B_LEG                                              19 of 27
# R_DISTANCE                                       140 of 272
# B_DISTANCE                                        65 of 181
# R_CLINCH                                             1 of 1
# B_CLINCH                                             4 of 4
# R_GROUND                                           13 of 28
# B_GROUND                                             0 of 0
# win_by                                 Decision - Unanimous
# last_round                                                5
# last_round_time                                        5:00
# Format                                    5 Rnd (5-5-5-5-5)
# Referee                                        Marc Goddard
# date                                       October 03, 2020
# location         Abu Dhabi, Abu Dhabi, United Arab Emirates
# Fight_type                        Women's Bantamweight Bout
# Winner                                           Holly Holm
#
#                                                        1     \
# R_fighter                                  Yorgan De Castro
# B_fighter                                     Carlos Felipe
# R_KD                                                      0
# B_KD                                                      0
# R_SIG_STR.                                        48 of 100
# B_SIG_STR.                                        78 of 177
# R_SIG_STR_pct                                           48%
# B_SIG_STR_pct                                           44%
# R_TOTAL_STR.                                     113 of 174
# B_TOTAL_STR.                                      88 of 187
# R_TD                                                 0 of 1
# B_TD                                                 0 of 0
# R_TD_pct                                                 0%
# B_TD_pct                                                ---
# R_SUB_ATT                                                 0
# B_SUB_ATT                                                 0
# R_REV                                                     0
# B_REV                                                     0
# R_CTRL                                                 3:13
# B_CTRL                                                 1:28
# R_HEAD                                             24 of 72
# B_HEAD                                            39 of 127
# R_BODY                                              8 of 11
# B_BODY                                             28 of 38
# R_LEG                                              16 of 17
# B_LEG                                              11 of 12
# R_DISTANCE                                         48 of 99
# B_DISTANCE                                        65 of 161
# R_CLINCH                                             0 of 1
# B_CLINCH                                           13 of 16
# R_GROUND                                             0 of 0
# B_GROUND                                             0 of 0
# win_by                                 Decision - Unanimous
# last_round                                                3
# last_round_time                                        5:00
# Format                                        3 Rnd (5-5-5)
# Referee                                        Kevin Sataki
# date                                       October 03, 2020
# location         Abu Dhabi, Abu Dhabi, United Arab Emirates
# Fight_type                                 Heavyweight Bout
# Winner                                        Carlos Felipe
#
#                                                        2     \
# R_fighter                              Germaine de Randamie
# B_fighter                                     Julianna Pena
# R_KD                                                      0
# B_KD                                                      0
# R_SIG_STR.                                         37 of 91
# B_SIG_STR.                                         27 of 91
# R_SIG_STR_pct                                           40%
# B_SIG_STR_pct                                           29%
# R_TOTAL_STR.                                      57 of 119
# B_TOTAL_STR.                                      58 of 125
# R_TD                                                 0 of 0
# B_TD                                                 3 of 6
# R_TD_pct                                                ---
# B_TD_pct                                                50%
# R_SUB_ATT                                                 2
# B_SUB_ATT                                                 0
# R_REV                                                     0
# B_REV                                                     0
# R_CTRL                                                 0:48
# B_CTRL                                                 5:55
# R_HEAD                                             32 of 86
# B_HEAD                                             19 of 79
# R_BODY                                               5 of 5
# B_BODY                                              7 of 10
# R_LEG                                                0 of 0
# B_LEG                                                1 of 2
# R_DISTANCE                                         32 of 84
# B_DISTANCE                                         18 of 75
# R_CLINCH                                             4 of 6
# B_CLINCH                                             2 of 2
# R_GROUND                                             1 of 1
# B_GROUND                                            7 of 14
# win_by                                           Submission
# last_round                                                3
# last_round_time                                        3:25
# Format                                        3 Rnd (5-5-5)
# Referee                                                 NaN
# date                                       October 03, 2020
# location         Abu Dhabi, Abu Dhabi, United Arab Emirates
# Fight_type                        Women's Bantamweight Bout
# Winner                                 Germaine de Randamie
#
#                                                        3     \
# R_fighter                                    Kyler Phillips
# B_fighter                                      Cameron Else
# R_KD                                                      0
# B_KD                                                      0
# R_SIG_STR.                                         32 of 78
# B_SIG_STR.                                         11 of 30
# R_SIG_STR_pct                                           41%
# B_SIG_STR_pct                                           36%
# R_TOTAL_STR.                                       34 of 80
# B_TOTAL_STR.                                       20 of 43
# R_TD                                                 2 of 2
# B_TD                                                 0 of 0
# R_TD_pct                                               100%
# B_TD_pct                                                ---
# R_SUB_ATT                                                 0
# B_SUB_ATT                                                 0
# R_REV                                                     0
# B_REV                                                     0
# R_CTRL                                                 2:25
# B_CTRL                                                 0:03
# R_HEAD                                             22 of 63
# B_HEAD                                              4 of 20
# R_BODY                                               5 of 8
# B_BODY                                               6 of 8
# R_LEG                                                5 of 7
# B_LEG                                                1 of 2
# R_DISTANCE                                         13 of 41
# B_DISTANCE                                         10 of 28
# R_CLINCH                                             0 of 0
# B_CLINCH                                             0 of 0
# R_GROUND                                           19 of 37
# B_GROUND                                             1 of 2
# win_by                                               KO/TKO
# last_round                                                2
# last_round_time                                        0:44
# Format                                        3 Rnd (5-5-5)
# Referee                                        Marc Goddard
# date                                       October 03, 2020
# location         Abu Dhabi, Abu Dhabi, United Arab Emirates
# Fight_type                                Bantamweight Bout
# Winner                                       Kyler Phillips
#
#                                                        4     \
# R_fighter                                   Dequan Townsend
# B_fighter                                   Dusko Todorovic
# R_KD                                                      0
# B_KD                                                      0
# R_SIG_STR.                                         13 of 41
# B_SIG_STR.                                        85 of 134
# R_SIG_STR_pct                                           31%
# B_SIG_STR_pct                                           63%
# R_TOTAL_STR.                                       21 of 49
# B_TOTAL_STR.                                     109 of 167
# R_TD                                                 0 of 0
# B_TD                                                 1 of 2
# R_TD_pct                                                ---
# B_TD_pct                                                50%
# R_SUB_ATT                                                 0
# B_SUB_ATT                                                 0
# R_REV                                                     0
# B_REV                                                     0
# R_CTRL                                                 0:18
# B_CTRL                                                 3:25
# R_HEAD                                              5 of 28
# B_HEAD                                            66 of 114
# R_BODY                                              6 of 11
# B_BODY                                             11 of 12
# R_LEG                                                2 of 2
# B_LEG                                                8 of 8
# R_DISTANCE                                         10 of 38
# B_DISTANCE                                         39 of 67
# R_CLINCH                                             3 of 3
# B_CLINCH                                           17 of 20
# R_GROUND                                             0 of 0
# B_GROUND                                           29 of 47
# win_by                                               KO/TKO
# last_round                                                2
# last_round_time                                        3:15
# Format                                        3 Rnd (5-5-5)
# Referee                                        Jason Herzog
# date                                       October 03, 2020
# location         Abu Dhabi, Abu Dhabi, United Arab Emirates
# Fight_type                                Middleweight Bout
# Winner                                      Dusko Todorovic
#
#                                                        5     \
# R_fighter                                     Carlos Condit
# B_fighter                                       Court McGee
# R_KD                                                      1
# B_KD                                                      0
# R_SIG_STR.                                        88 of 230
# B_SIG_STR.                                        84 of 182
# R_SIG_STR_pct                                           38%
# B_SIG_STR_pct                                           46%
# R_TOTAL_STR.                                      88 of 230
# B_TOTAL_STR.                                      84 of 182
# R_TD                                                 0 of 0
# B_TD                                                 0 of 0
# R_TD_pct                                                ---
# B_TD_pct                                                ---
# R_SUB_ATT                                                 0
# B_SUB_ATT                                                 0
# R_REV                                                     0
# B_REV                                                     0
# R_CTRL                                                 0:02
# B_CTRL                                                 0:00
# R_HEAD                                            50 of 173
# B_HEAD                                              9 of 73
# R_BODY                                             17 of 34
# B_BODY                                             28 of 51
# R_LEG                                              21 of 23
# B_LEG                                              47 of 58
# R_DISTANCE                                        87 of 228
# B_DISTANCE                                        84 of 182
# R_CLINCH                                             0 of 0
# B_CLINCH                                             0 of 0
# R_GROUND                                             1 of 2
# B_GROUND                                             0 of 0
# win_by                                 Decision - Unanimous
# last_round                                                3
# last_round_time                                        5:00
# Format                                        3 Rnd (5-5-5)
# Referee                                        Marc Goddard
# date                                       October 03, 2020
# location         Abu Dhabi, Abu Dhabi, United Arab Emirates
# Fight_type                                Welterweight Bout
# Winner                                        Carlos Condit
#
#                                                        6     \
# R_fighter                                  Charles Jourdain
# B_fighter                                      Josh Culibao
# R_KD                                                      0
# B_KD                                                      1
# R_SIG_STR.                                        44 of 101
# B_SIG_STR.                                        46 of 124
# R_SIG_STR_pct                                           43%
# B_SIG_STR_pct                                           37%
# R_TOTAL_STR.                                      68 of 126
# B_TOTAL_STR.                                      51 of 130
# R_TD                                                 0 of 0
# B_TD                                                 0 of 7
# R_TD_pct                                                ---
# B_TD_pct                                                 0%
# R_SUB_ATT                                                 3
# B_SUB_ATT                                                 0
# R_REV                                                     0
# B_REV                                                     0
# R_CTRL                                                 2:51
# B_CTRL                                                 2:28
# R_HEAD                                             17 of 63
# B_HEAD                                             19 of 78
# R_BODY                                             10 of 19
# B_BODY                                             22 of 40
# R_LEG                                              17 of 19
# B_LEG                                                5 of 6
# R_DISTANCE                                         34 of 81
# B_DISTANCE                                        40 of 115
# R_CLINCH                                             0 of 0
# B_CLINCH                                             2 of 2
# R_GROUND                                           10 of 20
# B_GROUND                                             4 of 7
# win_by                                     Decision - Split
# last_round                                                3
# last_round_time                                        5:00
# Format                                        3 Rnd (5-5-5)
# Referee                                        Jason Herzog
# date                                       October 03, 2020
# location         Abu Dhabi, Abu Dhabi, United Arab Emirates
# Fight_type                               Featherweight Bout
# Winner                                                  NaN
#
#                                                        7     \
# R_fighter                                   Jordan Williams
# B_fighter                                Nassourdine Imavov
# R_KD                                                      0
# B_KD                                                      0
# R_SIG_STR.                                         30 of 98
# B_SIG_STR.                                        68 of 110
# R_SIG_STR_pct                                           30%
# B_SIG_STR_pct                                           61%
# R_TOTAL_STR.                                      62 of 137
# B_TOTAL_STR.                                      81 of 126
# R_TD                                                 0 of 3
# B_TD                                                 1 of 8
# R_TD_pct                                                 0%
# B_TD_pct                                                12%
# R_SUB_ATT                                                 0
# B_SUB_ATT                                                 4
# R_REV                                                     0
# B_REV                                                     0
# R_CTRL                                                 2:24
# B_CTRL                                                 4:51
# R_HEAD                                             25 of 88
# B_HEAD                                             50 of 90
# R_BODY                                               4 of 9
# B_BODY                                             13 of 14
# R_LEG                                                1 of 1
# B_LEG                                                5 of 6
# R_DISTANCE                                         23 of 88
# B_DISTANCE                                         48 of 83
# R_CLINCH                                            7 of 10
# B_CLINCH                                           12 of 13
# R_GROUND                                             0 of 0
# B_GROUND                                            8 of 14
# win_by                                 Decision - Unanimous
# last_round                                                3
# last_round_time                                        5:00
# Format                                        3 Rnd (5-5-5)
# Referee                                        Kevin Sataki
# date                                       October 03, 2020
# location         Abu Dhabi, Abu Dhabi, United Arab Emirates
# Fight_type                                Middleweight Bout
# Winner                                   Nassourdine Imavov
#
#                                                        8     \
# R_fighter                                  Loma Lookboonmee
# B_fighter                                      Jinh Yu Frey
# R_KD                                                      0
# B_KD                                                      0
# R_SIG_STR.                                        80 of 137
# B_SIG_STR.                                         26 of 61
# R_SIG_STR_pct                                           58%
# B_SIG_STR_pct                                           42%
# R_TOTAL_STR.                                      85 of 142
# B_TOTAL_STR.                                       39 of 75
# R_TD                                                 0 of 1
# B_TD                                                 1 of 4
# R_TD_pct                                                 0%
# B_TD_pct                                                25%
# R_SUB_ATT                                                 0
# B_SUB_ATT                                                 0
# R_REV                                                     0
# B_REV                                                     0
# R_CTRL                                                 1:23
# B_CTRL                                                 2:34
# R_HEAD                                             27 of 61
# B_HEAD                                             21 of 49
# R_BODY                                             35 of 56
# B_BODY                                               4 of 8
# R_LEG                                              18 of 20
# B_LEG                                                1 of 4
# R_DISTANCE                                         42 of 86
# B_DISTANCE                                         13 of 47
# R_CLINCH                                           38 of 50
# B_CLINCH                                           13 of 14
# R_GROUND                                             0 of 1
# B_GROUND                                             0 of 0
# win_by                                 Decision - Unanimous
# last_round                                                3
# last_round_time                                        5:00
# Format                                        3 Rnd (5-5-5)
# Referee                                        Marc Goddard
# date                                       October 03, 2020
# location         Abu Dhabi, Abu Dhabi, United Arab Emirates
# Fight_type                         Women's Strawweight Bout
# Winner                                     Loma Lookboonmee
#
#                                                        9     ...  \
# R_fighter                                      Casey Kenney  ...
# B_fighter                                     Heili Alateng  ...
# R_KD                                                      0  ...
# B_KD                                                      0  ...
# R_SIG_STR.                                       109 of 263  ...
# B_SIG_STR.                                        46 of 171  ...
# R_SIG_STR_pct                                           41%  ...
# B_SIG_STR_pct                                           26%  ...
# R_TOTAL_STR.                                     109 of 263  ...
# B_TOTAL_STR.                                      46 of 171  ...
# R_TD                                                 0 of 1  ...
# B_TD                                                 0 of 0  ...
# R_TD_pct                                                 0%  ...
# B_TD_pct                                                ---  ...
# R_SUB_ATT                                                 0  ...
# B_SUB_ATT                                                 0  ...
# R_REV                                                     0  ...
# B_REV                                                     0  ...
# R_CTRL                                                 0:00  ...
# B_CTRL                                                 0:00  ...
# R_HEAD                                            57 of 192  ...
# B_HEAD                                            26 of 140  ...
# R_BODY                                             41 of 58  ...
# B_BODY                                             11 of 20  ...
# R_LEG                                              11 of 13  ...
# B_LEG                                               9 of 11  ...
# R_DISTANCE                                       109 of 261  ...
# B_DISTANCE                                        46 of 171  ...
# R_CLINCH                                             0 of 2  ...
# B_CLINCH                                             0 of 0  ...
# R_GROUND                                             0 of 0  ...
# B_GROUND                                             0 of 0  ...
# win_by                                 Decision - Unanimous  ...
# last_round                                                3  ...
# last_round_time                                        5:00  ...
# Format                                        3 Rnd (5-5-5)  ...
# Referee                                        Kevin Sataki  ...
# date                                       October 03, 2020  ...
# location         Abu Dhabi, Abu Dhabi, United Arab Emirates  ...
# Fight_type                                Bantamweight Bout  ...
# Winner                                         Casey Kenney  ...
#
#                                   5768                   5769  \
# R_fighter                Johnny Rhodes          Patrick Smith
# B_fighter                  Fred Ettish           Scott Morris
# R_KD                                 1                      0
# B_KD                                 0                      0
# R_SIG_STR.                    13 of 29               13 of 17
# B_SIG_STR.                      4 of 7                 0 of 0
# R_SIG_STR_pct                      44%                    76%
# B_SIG_STR_pct                      57%                    ---
# R_TOTAL_STR.                  21 of 38               19 of 25
# B_TOTAL_STR.                   7 of 11                 0 of 0
# R_TD                            0 of 0                 0 of 0
# B_TD                            0 of 0                 0 of 1
# R_TD_pct                           ---                    ---
# B_TD_pct                           ---                     0%
# R_SUB_ATT                            1                      0
# B_SUB_ATT                            0                      0
# R_REV                                0                      0
# B_REV                                0                      0
# R_CTRL                              --                     --
# B_CTRL                              --                     --
# R_HEAD                        12 of 28               12 of 16
# B_HEAD                          0 of 1                 0 of 0
# R_BODY                          0 of 0                 1 of 1
# B_BODY                          2 of 4                 0 of 0
# R_LEG                           1 of 1                 0 of 0
# B_LEG                           2 of 2                 0 of 0
# R_DISTANCE                      3 of 6                 0 of 0
# B_DISTANCE                      4 of 7                 0 of 0
# R_CLINCH                        1 of 2                 1 of 1
# B_CLINCH                        0 of 0                 0 of 0
# R_GROUND                       9 of 21               12 of 16
# B_GROUND                        0 of 0                 0 of 0
# win_by                      Submission                 KO/TKO
# last_round                           1                      1
# last_round_time                   3:07                   0:30
# Format                   No Time Limit          No Time Limit
# Referee                  John McCarthy          John McCarthy
# date                    March 11, 1994         March 11, 1994
# location         Denver, Colorado, USA  Denver, Colorado, USA
# Fight_type            Open Weight Bout       Open Weight Bout
# Winner                   Johnny Rhodes          Patrick Smith
#
#                                   5770                   5771  \
# R_fighter                 Royce Gracie          Jason DeLucia
# B_fighter              Minoki Ichihara            Scott Baker
# R_KD                                 0                      0
# B_KD                                 0                      0
# R_SIG_STR.                      2 of 4                 3 of 5
# B_SIG_STR.                      3 of 7                 0 of 2
# R_SIG_STR_pct                      50%                    60%
# B_SIG_STR_pct                      42%                     0%
# R_TOTAL_STR.                110 of 114               20 of 25
# B_TOTAL_STR.                  12 of 16               14 of 23
# R_TD                            1 of 1                 0 of 1
# B_TD                            0 of 0                 1 of 1
# R_TD_pct                          100%                     0%
# B_TD_pct                           ---                   100%
# R_SUB_ATT                            2                      5
# B_SUB_ATT                            0                      0
# R_REV                                0                      4
# B_REV                                0                      2
# R_CTRL                              --                     --
# B_CTRL                              --                     --
# R_HEAD                          0 of 0                 1 of 2
# B_HEAD                          3 of 6                 0 of 2
# R_BODY                          0 of 0                 1 of 2
# B_BODY                          0 of 0                 0 of 0
# R_LEG                           2 of 4                 1 of 1
# B_LEG                           0 of 1                 0 of 0
# R_DISTANCE                      2 of 4                 2 of 4
# B_DISTANCE                      0 of 2                 0 of 2
# R_CLINCH                        0 of 0                 0 of 0
# B_CLINCH                        0 of 0                 0 of 0
# R_GROUND                        0 of 0                 1 of 1
# B_GROUND                        3 of 5                 0 of 0
# win_by                      Submission             Submission
# last_round                           1                      1
# last_round_time                   5:08                   6:41
# Format                   No Time Limit          No Time Limit
# Referee                  John McCarthy          John McCarthy
# date                    March 11, 1994         March 11, 1994
# location         Denver, Colorado, USA  Denver, Colorado, USA
# Fight_type            Open Weight Bout       Open Weight Bout
# Winner                    Royce Gracie          Jason DeLucia
#
#                                   5772                   5773  \
# R_fighter                Remco Pardoel           Orlando Wiet
# B_fighter           Alberta Cerra Leon       Robert Lucarelli
# R_KD                                 0                      0
# B_KD                                 0                      0
# R_SIG_STR.                      4 of 6                8 of 12
# B_SIG_STR.                      1 of 3                 2 of 6
# R_SIG_STR_pct                      66%                    66%
# B_SIG_STR_pct                      33%                    33%
# R_TOTAL_STR.                  20 of 22               11 of 15
# B_TOTAL_STR.                   9 of 11                 2 of 6
# R_TD                            1 of 1                 0 of 0
# B_TD                            0 of 0                 1 of 1
# R_TD_pct                          100%                    ---
# B_TD_pct                           ---                   100%
# R_SUB_ATT                            1                      0
# B_SUB_ATT                            0                      1
# R_REV                                0                      0
# B_REV                                0                      0
# R_CTRL                              --                     --
# B_CTRL                              --                     --
# R_HEAD                          4 of 5                7 of 11
# B_HEAD                          1 of 3                 1 of 2
# R_BODY                          0 of 0                 1 of 1
# B_BODY                          0 of 0                 0 of 1
# R_LEG                           0 of 1                 0 of 0
# B_LEG                           0 of 0                 1 of 3
# R_DISTANCE                      0 of 1                 1 of 3
# B_DISTANCE                      1 of 1                 2 of 6
# R_CLINCH                        0 of 0                 0 of 0
# B_CLINCH                        0 of 0                 0 of 0
# R_GROUND                        4 of 5                 7 of 9
# B_GROUND                        0 of 2                 0 of 0
# win_by                      Submission                 KO/TKO
# last_round                           1                      1
# last_round_time                   9:51                   2:50
# Format                   No Time Limit          No Time Limit
# Referee                  John McCarthy          John McCarthy
# date                    March 11, 1994         March 11, 1994
# location         Denver, Colorado, USA  Denver, Colorado, USA
# Fight_type            Open Weight Bout       Open Weight Bout
# Winner                   Remco Pardoel           Orlando Wiet
#
#                                   5774                   5775  \
# R_fighter                Frank Hamaker          Johnny Rhodes
# B_fighter              Thaddeus Luster          David Levicki
# R_KD                                 0                      0
# B_KD                                 0                      0
# R_SIG_STR.                      2 of 3               11 of 17
# B_SIG_STR.                      0 of 0                 4 of 5
# R_SIG_STR_pct                      66%                    64%
# B_SIG_STR_pct                      ---                    80%
# R_TOTAL_STR.                  14 of 15               74 of 86
# B_TOTAL_STR.                    0 of 0              95 of 102
# R_TD                            1 of 1                 1 of 1
# B_TD                            0 of 1                 0 of 0
# R_TD_pct                          100%                   100%
# B_TD_pct                            0%                    ---
# R_SUB_ATT                            3                      0
# B_SUB_ATT                            0                      0
# R_REV                                1                      0
# B_REV                                0                      0
# R_CTRL                              --                     --
# B_CTRL                              --                     --
# R_HEAD                          2 of 3                9 of 15
# B_HEAD                          0 of 0                 4 of 5
# R_BODY                          0 of 0                 1 of 1
# B_BODY                          0 of 0                 0 of 0
# R_LEG                           0 of 0                 1 of 1
# B_LEG                           0 of 0                 0 of 0
# R_DISTANCE                      1 of 1                 1 of 1
# B_DISTANCE                      0 of 0                 1 of 2
# R_CLINCH                        0 of 0                 1 of 1
# B_CLINCH                        0 of 0                 2 of 2
# R_GROUND                        1 of 2                9 of 15
# B_GROUND                        0 of 0                 1 of 1
# win_by                      Submission                 KO/TKO
# last_round                           1                      1
# last_round_time                   4:52                  12:13
# Format                   No Time Limit          No Time Limit
# Referee                  John McCarthy          John McCarthy
# date                    March 11, 1994         March 11, 1994
# location         Denver, Colorado, USA  Denver, Colorado, USA
# Fight_type            Open Weight Bout       Open Weight Bout
# Winner                   Frank Hamaker          Johnny Rhodes
#
#                                   5776                   5777
# R_fighter                Patrick Smith           Scott Morris
# B_fighter                   Ray Wizard         Sean Daugherty
# R_KD                                 0                      0
# B_KD                                 0                      0
# R_SIG_STR.                      1 of 1                 1 of 1
# B_SIG_STR.                      1 of 1                 0 of 4
# R_SIG_STR_pct                     100%                   100%
# B_SIG_STR_pct                     100%                     0%
# R_TOTAL_STR.                    1 of 1                 2 of 2
# B_TOTAL_STR.                    2 of 2                 1 of 5
# R_TD                            0 of 1                 1 of 1
# B_TD                            0 of 0                 0 of 0
# R_TD_pct                            0%                   100%
# B_TD_pct                           ---                    ---
# R_SUB_ATT                            1                      1
# B_SUB_ATT                            0                      0
# R_REV                                0                      0
# B_REV                                0                      0
# R_CTRL                              --                     --
# B_CTRL                              --                     --
# R_HEAD                          0 of 0                 1 of 1
# B_HEAD                          0 of 0                 0 of 2
# R_BODY                          1 of 1                 0 of 0
# B_BODY                          0 of 0                 0 of 0
# R_LEG                           0 of 0                 0 of 0
# B_LEG                           1 of 1                 0 of 2
# R_DISTANCE                      0 of 0                 0 of 0
# B_DISTANCE                      1 of 1                 0 of 3
# R_CLINCH                        1 of 1                 1 of 1
# B_CLINCH                        0 of 0                 0 of 1
# R_GROUND                        0 of 0                 0 of 0
# B_GROUND                        0 of 0                 0 of 0
# win_by                      Submission             Submission
# last_round                           1                      1
# last_round_time                   0:58                   0:20
# Format                   No Time Limit          No Time Limit
# Referee                  John McCarthy          John McCarthy
# date                    March 11, 1994         March 11, 1994
# location         Denver, Colorado, USA  Denver, Colorado, USA
# Fight_type            Open Weight Bout       Open Weight Bout
# Winner                   Patrick Smith           Scott Morris
#
# [41 rows x 5778 columns]

# %%
df.describe()
# Out:
#               R_KD         B_KD    R_SUB_ATT    B_SUB_ATT        R_REV  \
# count  5778.000000  5778.000000  5778.000000  5778.000000  5778.000000
# mean      0.248875     0.180858     0.488750     0.347352     0.139668
# std       0.520003     0.458792     0.932346     0.794200     0.424351
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     0.000000     0.000000     0.000000     0.000000
# 50%       0.000000     0.000000     0.000000     0.000000     0.000000
# 75%       0.000000     0.000000     1.000000     0.000000     0.000000
# max       5.000000     4.000000    10.000000     7.000000     5.000000
#
#              B_REV   last_round
# count  5778.000000  5778.000000
# mean      0.134476     2.311700
# std       0.415327     1.007642
# min       0.000000     1.000000
# 25%       0.000000     1.000000
# 50%       0.000000     3.000000
# 75%       0.000000     3.000000
# max       3.000000     5.000000

# %%
df.dtypes
# Out:
# R_fighter          object
# B_fighter          object
# R_KD                int64
# B_KD                int64
# R_SIG_STR.         object
# B_SIG_STR.         object
# R_SIG_STR_pct      object
# B_SIG_STR_pct      object
# R_TOTAL_STR.       object
# B_TOTAL_STR.       object
# R_TD               object
# B_TD               object
# R_TD_pct           object
# B_TD_pct           object
# R_SUB_ATT           int64
# B_SUB_ATT           int64
# R_REV               int64
# B_REV               int64
# R_CTRL             object
# B_CTRL             object
# R_HEAD             object
# B_HEAD             object
# R_BODY             object
# B_BODY             object
# R_LEG              object
# B_LEG              object
# R_DISTANCE         object
# B_DISTANCE         object
# R_CLINCH           object
# B_CLINCH           object
# R_GROUND           object
# B_GROUND           object
# win_by             object
# last_round          int64
# last_round_time    object
# Format             object
# Referee            object
# date               object
# location           object
# Fight_type         object
# Winner             object
# dtype: object

# %%
df.columns
# Out:
# Index(['R_fighter', 'B_fighter', 'R_KD', 'B_KD', 'R_SIG_STR.', 'B_SIG_STR.',
#        'R_SIG_STR_pct', 'B_SIG_STR_pct', 'R_TOTAL_STR.', 'B_TOTAL_STR.',
#        'R_TD', 'B_TD', 'R_TD_pct', 'B_TD_pct', 'R_SUB_ATT', 'B_SUB_ATT',
#        'R_REV', 'B_REV', 'R_CTRL', 'B_CTRL', 'R_HEAD', 'B_HEAD', 'R_BODY',
#        'B_BODY', 'R_LEG', 'B_LEG', 'R_DISTANCE', 'B_DISTANCE', 'R_CLINCH',
#        'B_CLINCH', 'R_GROUND', 'B_GROUND', 'win_by', 'last_round',
#        'last_round_time', 'Format', 'Referee', 'date', 'location',
#        'Fight_type', 'Winner'],
#       dtype='object')

# %% [markdown]
# ### Column definitions:
#
# - `R_` and `B_` prefix signifies red and blue corner fighter stats respectively
# - `KD` is number of knockdowns
# - `SIG_STR` is no. of significant strikes 'landed of attempted'
# - `SIG_STR_pct` is significant strikes percentage
# - `TOTAL_STR` is total strikes 'landed of attempted'
# - `TD` is no. of takedowns
# - `TD_pct` is takedown percentages
# - `SUB_ATT` is no. of submission attempts
# - `PASS` is no. times the guard was passed?
# - `REV` is the no. of reversals
# - `CTRL` is the time spent with ground control
# - `HEAD` is no. of significant strinks to the head 'landed of attempted'
# - `BODY` is no. of significant strikes to the body 'landed of attempted'
# - `CLINCH` is no. of significant strikes in the clinch 'landed of attempted'
# - `GROUND` is no. of significant strikes on the ground 'landed of attempted'
# - `win_by` is method of win
# - `last_round` is last round of the fight (ex. if it was a KO in 1st, then this will be 1)
# - `last_round_time` is when the fight ended in the last round
# - `Format` is the format of the fight (3 rounds, 5 rounds etc.)
# - `Referee` is the name of the Ref
# - `date` is the date of the fight
# - `location` is the location in which the event took place
# - `Fight_type` is which weight class and whether it's a title bout or not
# - `Winner` is the winner of the fight

# %% [markdown]
# ## Todo:
#
# - Separate `landed of attempted` to separate columns
#
# - Convert `Fight_type` into two separate columns, `weight_class` and `Title_fight` (True or False)
#
# - Convert `last_round_time` to `total_time_fought` by using `last_round` and `Format`
#
# - Convert `CTRL` to `time_in_CTRL`
#
# - Convert percentages to fractions
#
# - Since the data is a description of each fight, we have to convert it into a format that shows the compilation data of each fighter up until that fight. This means every row will look a lot different than it looks now.
#
# - Create `current_win_streak`, `current_lose_streak`, `longest_win_streak`, `wins`, `losses`, `draw`
#
# - Create fighter `height`, `reach`, `weight`, `age`

# %% [markdown]
# ### Splitting landed of attempted to different columns

# %%
columns = ['R_SIG_STR.', 'B_SIG_STR.', 'R_TOTAL_STR.', 'B_TOTAL_STR.',
       'R_TD', 'B_TD', 'R_HEAD', 'B_HEAD', 'R_BODY','B_BODY', 'R_LEG', 'B_LEG', 
        'R_DISTANCE', 'B_DISTANCE', 'R_CLINCH','B_CLINCH', 'R_GROUND', 'B_GROUND']

for column in columns:
    print(f"{column} data type is: {df[column].dtype}")
# Out:
# R_SIG_STR. data type is: object
# B_SIG_STR. data type is: object
# R_TOTAL_STR. data type is: object
# B_TOTAL_STR. data type is: object
# R_TD data type is: object
# B_TD data type is: object
# R_HEAD data type is: object
# B_HEAD data type is: object
# R_BODY data type is: object
# B_BODY data type is: object
# R_LEG data type is: object
# B_LEG data type is: object
# R_DISTANCE data type is: object
# B_DISTANCE data type is: object
# R_CLINCH data type is: object
# B_CLINCH data type is: object
# R_GROUND data type is: object
# B_GROUND data type is: object

# %%
attempt_suffix = '_att'
landed_suffix = '_landed'

for column in columns:
    df[column+attempt_suffix] = df[column].apply(lambda X: int(X.split('of')[1]))
    df[column+landed_suffix] = df[column].apply(lambda X: int(X.split('of')[0]))
    
df.drop(columns, axis=1, inplace=True)

# %%
df.columns
# Out:
# Index(['R_fighter', 'B_fighter', 'R_KD', 'B_KD', 'R_SIG_STR_pct',
#        'B_SIG_STR_pct', 'R_TD_pct', 'B_TD_pct', 'R_SUB_ATT', 'B_SUB_ATT',
#        'R_REV', 'B_REV', 'R_CTRL', 'B_CTRL', 'win_by', 'last_round',
#        'last_round_time', 'Format', 'Referee', 'date', 'location',
#        'Fight_type', 'Winner', 'R_SIG_STR._att', 'R_SIG_STR._landed',
#        'B_SIG_STR._att', 'B_SIG_STR._landed', 'R_TOTAL_STR._att',
#        'R_TOTAL_STR._landed', 'B_TOTAL_STR._att', 'B_TOTAL_STR._landed',
#        'R_TD_att', 'R_TD_landed', 'B_TD_att', 'B_TD_landed', 'R_HEAD_att',
#        'R_HEAD_landed', 'B_HEAD_att', 'B_HEAD_landed', 'R_BODY_att',
#        'R_BODY_landed', 'B_BODY_att', 'B_BODY_landed', 'R_LEG_att',
#        'R_LEG_landed', 'B_LEG_att', 'B_LEG_landed', 'R_DISTANCE_att',
#        'R_DISTANCE_landed', 'B_DISTANCE_att', 'B_DISTANCE_landed',
#        'R_CLINCH_att', 'R_CLINCH_landed', 'B_CLINCH_att', 'B_CLINCH_landed',
#        'R_GROUND_att', 'R_GROUND_landed', 'B_GROUND_att', 'B_GROUND_landed'],
#       dtype='object')

# %% [markdown]
# ### Replacing Winner NaNs as Draw

# %%
for column in df.columns:
    if df[column].isnull().sum() != 0:
        print(f"NaN values in {column} = {df[column].isnull().sum()}")
# Out:
# NaN values in Referee = 30
# NaN values in Winner = 100

# %% [markdown]
# * 83 missing values in winner and 23 missing values in Referee

# %%
df[df['Winner'].isnull()]['win_by'].value_counts()
# Out:
# Overturned              40
# Decision - Majority     24
# Could Not Continue      15
# Decision - Split        12
# Decision - Unanimous     6
# Other                    2
# Submission               1
# Name: win_by, dtype: int64

# %% [markdown]
# * Here, Overturned means due to drug test being positive and Could not Continue means there was an illegal blow which was not enough to be disqualified but the fighter could not continue.
# * The rest are different forms of draw
#
# * Replacing all of these with draw

# %%
df['Winner'].fillna('Draw', inplace=True)

# %% [markdown]
# ### Converting percentages to fractions

# %%
pct_columns = ['R_SIG_STR_pct','B_SIG_STR_pct', 'R_TD_pct', 'B_TD_pct']

def pct_to_frac(X):
    if X != '---':
        return float(X.replace('%', ''))/100
    else:
        # if '---' means it's taking pct of `0 of 0`. 
        # Taking a call here to consider 0 landed of 0 attempted as 0 percentage
        return 0

for column in pct_columns:
    df[column] = df[column].apply(pct_to_frac)

# %%
df.T
# Out:
#                                                            0     \
# R_fighter                                            Holly Holm
# B_fighter                                          Irene Aldana
# R_KD                                                          0
# B_KD                                                          0
# R_SIG_STR_pct                                              0.51
# B_SIG_STR_pct                                              0.37
# R_TD_pct                                                   0.35
# B_TD_pct                                                      0
# R_SUB_ATT                                                     0
# B_SUB_ATT                                                     0
# R_REV                                                         0
# B_REV                                                         0
# R_CTRL                                                     5:16
# B_CTRL                                                     0:03
# win_by                                     Decision - Unanimous
# last_round                                                    5
# last_round_time                                            5:00
# Format                                        5 Rnd (5-5-5-5-5)
# Referee                                            Marc Goddard
# date                                           October 03, 2020
# location             Abu Dhabi, Abu Dhabi, United Arab Emirates
# Fight_type                            Women's Bantamweight Bout
# Winner                                               Holly Holm
# R_SIG_STR._att                                              301
# R_SIG_STR._landed                                           154
# B_SIG_STR._att                                              185
# B_SIG_STR._landed                                            69
# R_TOTAL_STR._att                                            342
# R_TOTAL_STR._landed                                         187
# B_TOTAL_STR._att                                            210
# B_TOTAL_STR._landed                                          92
# R_TD_att                                                     14
# R_TD_landed                                                   5
# B_TD_att                                                      0
# B_TD_landed                                                   0
# R_HEAD_att                                                  214
# R_HEAD_landed                                                81
# B_HEAD_att                                                  128
# B_HEAD_landed                                                38
# R_BODY_att                                                   68
# R_BODY_landed                                                56
# B_BODY_att                                                   30
# B_BODY_landed                                                12
# R_LEG_att                                                    19
# R_LEG_landed                                                 17
# B_LEG_att                                                    27
# B_LEG_landed                                                 19
# R_DISTANCE_att                                              272
# R_DISTANCE_landed                                           140
# B_DISTANCE_att                                              181
# B_DISTANCE_landed                                            65
# R_CLINCH_att                                                  1
# R_CLINCH_landed                                               1
# B_CLINCH_att                                                  4
# B_CLINCH_landed                                               4
# R_GROUND_att                                                 28
# R_GROUND_landed                                              13
# B_GROUND_att                                                  0
# B_GROUND_landed                                               0
#
#                                                            1     \
# R_fighter                                      Yorgan De Castro
# B_fighter                                         Carlos Felipe
# R_KD                                                          0
# B_KD                                                          0
# R_SIG_STR_pct                                              0.48
# B_SIG_STR_pct                                              0.44
# R_TD_pct                                                      0
# B_TD_pct                                                      0
# R_SUB_ATT                                                     0
# B_SUB_ATT                                                     0
# R_REV                                                         0
# B_REV                                                         0
# R_CTRL                                                     3:13
# B_CTRL                                                     1:28
# win_by                                     Decision - Unanimous
# last_round                                                    3
# last_round_time                                            5:00
# Format                                            3 Rnd (5-5-5)
# Referee                                            Kevin Sataki
# date                                           October 03, 2020
# location             Abu Dhabi, Abu Dhabi, United Arab Emirates
# Fight_type                                     Heavyweight Bout
# Winner                                            Carlos Felipe
# R_SIG_STR._att                                              100
# R_SIG_STR._landed                                            48
# B_SIG_STR._att                                              177
# B_SIG_STR._landed                                            78
# R_TOTAL_STR._att                                            174
# R_TOTAL_STR._landed                                         113
# B_TOTAL_STR._att                                            187
# B_TOTAL_STR._landed                                          88
# R_TD_att                                                      1
# R_TD_landed                                                   0
# B_TD_att                                                      0
# B_TD_landed                                                   0
# R_HEAD_att                                                   72
# R_HEAD_landed                                                24
# B_HEAD_att                                                  127
# B_HEAD_landed                                                39
# R_BODY_att                                                   11
# R_BODY_landed                                                 8
# B_BODY_att                                                   38
# B_BODY_landed                                                28
# R_LEG_att                                                    17
# R_LEG_landed                                                 16
# B_LEG_att                                                    12
# B_LEG_landed                                                 11
# R_DISTANCE_att                                               99
# R_DISTANCE_landed                                            48
# B_DISTANCE_att                                              161
# B_DISTANCE_landed                                            65
# R_CLINCH_att                                                  1
# R_CLINCH_landed                                               0
# B_CLINCH_att                                                 16
# B_CLINCH_landed                                              13
# R_GROUND_att                                                  0
# R_GROUND_landed                                               0
# B_GROUND_att                                                  0
# B_GROUND_landed                                               0
#
#                                                            2     \
# R_fighter                                  Germaine de Randamie
# B_fighter                                         Julianna Pena
# R_KD                                                          0
# B_KD                                                          0
# R_SIG_STR_pct                                               0.4
# B_SIG_STR_pct                                              0.29
# R_TD_pct                                                      0
# B_TD_pct                                                    0.5
# R_SUB_ATT                                                     2
# B_SUB_ATT                                                     0
# R_REV                                                         0
# B_REV                                                         0
# R_CTRL                                                     0:48
# B_CTRL                                                     5:55
# win_by                                               Submission
# last_round                                                    3
# last_round_time                                            3:25
# Format                                            3 Rnd (5-5-5)
# Referee                                                     NaN
# date                                           October 03, 2020
# location             Abu Dhabi, Abu Dhabi, United Arab Emirates
# Fight_type                            Women's Bantamweight Bout
# Winner                                     Germaine de Randamie
# R_SIG_STR._att                                               91
# R_SIG_STR._landed                                            37
# B_SIG_STR._att                                               91
# B_SIG_STR._landed                                            27
# R_TOTAL_STR._att                                            119
# R_TOTAL_STR._landed                                          57
# B_TOTAL_STR._att                                            125
# B_TOTAL_STR._landed                                          58
# R_TD_att                                                      0
# R_TD_landed                                                   0
# B_TD_att                                                      6
# B_TD_landed                                                   3
# R_HEAD_att                                                   86
# R_HEAD_landed                                                32
# B_HEAD_att                                                   79
# B_HEAD_landed                                                19
# R_BODY_att                                                    5
# R_BODY_landed                                                 5
# B_BODY_att                                                   10
# B_BODY_landed                                                 7
# R_LEG_att                                                     0
# R_LEG_landed                                                  0
# B_LEG_att                                                     2
# B_LEG_landed                                                  1
# R_DISTANCE_att                                               84
# R_DISTANCE_landed                                            32
# B_DISTANCE_att                                               75
# B_DISTANCE_landed                                            18
# R_CLINCH_att                                                  6
# R_CLINCH_landed                                               4
# B_CLINCH_att                                                  2
# B_CLINCH_landed                                               2
# R_GROUND_att                                                  1
# R_GROUND_landed                                               1
# B_GROUND_att                                                 14
# B_GROUND_landed                                               7
#
#                                                            3     \
# R_fighter                                        Kyler Phillips
# B_fighter                                          Cameron Else
# R_KD                                                          0
# B_KD                                                          0
# R_SIG_STR_pct                                              0.41
# B_SIG_STR_pct                                              0.36
# R_TD_pct                                                      1
# B_TD_pct                                                      0
# R_SUB_ATT                                                     0
# B_SUB_ATT                                                     0
# R_REV                                                         0
# B_REV                                                         0
# R_CTRL                                                     2:25
# B_CTRL                                                     0:03
# win_by                                                   KO/TKO
# last_round                                                    2
# last_round_time                                            0:44
# Format                                            3 Rnd (5-5-5)
# Referee                                            Marc Goddard
# date                                           October 03, 2020
# location             Abu Dhabi, Abu Dhabi, United Arab Emirates
# Fight_type                                    Bantamweight Bout
# Winner                                           Kyler Phillips
# R_SIG_STR._att                                               78
# R_SIG_STR._landed                                            32
# B_SIG_STR._att                                               30
# B_SIG_STR._landed                                            11
# R_TOTAL_STR._att                                             80
# R_TOTAL_STR._landed                                          34
# B_TOTAL_STR._att                                             43
# B_TOTAL_STR._landed                                          20
# R_TD_att                                                      2
# R_TD_landed                                                   2
# B_TD_att                                                      0
# B_TD_landed                                                   0
# R_HEAD_att                                                   63
# R_HEAD_landed                                                22
# B_HEAD_att                                                   20
# B_HEAD_landed                                                 4
# R_BODY_att                                                    8
# R_BODY_landed                                                 5
# B_BODY_att                                                    8
# B_BODY_landed                                                 6
# R_LEG_att                                                     7
# R_LEG_landed                                                  5
# B_LEG_att                                                     2
# B_LEG_landed                                                  1
# R_DISTANCE_att                                               41
# R_DISTANCE_landed                                            13
# B_DISTANCE_att                                               28
# B_DISTANCE_landed                                            10
# R_CLINCH_att                                                  0
# R_CLINCH_landed                                               0
# B_CLINCH_att                                                  0
# B_CLINCH_landed                                               0
# R_GROUND_att                                                 37
# R_GROUND_landed                                              19
# B_GROUND_att                                                  2
# B_GROUND_landed                                               1
#
#                                                            4     \
# R_fighter                                       Dequan Townsend
# B_fighter                                       Dusko Todorovic
# R_KD                                                          0
# B_KD                                                          0
# R_SIG_STR_pct                                              0.31
# B_SIG_STR_pct                                              0.63
# R_TD_pct                                                      0
# B_TD_pct                                                    0.5
# R_SUB_ATT                                                     0
# B_SUB_ATT                                                     0
# R_REV                                                         0
# B_REV                                                         0
# R_CTRL                                                     0:18
# B_CTRL                                                     3:25
# win_by                                                   KO/TKO
# last_round                                                    2
# last_round_time                                            3:15
# Format                                            3 Rnd (5-5-5)
# Referee                                            Jason Herzog
# date                                           October 03, 2020
# location             Abu Dhabi, Abu Dhabi, United Arab Emirates
# Fight_type                                    Middleweight Bout
# Winner                                          Dusko Todorovic
# R_SIG_STR._att                                               41
# R_SIG_STR._landed                                            13
# B_SIG_STR._att                                              134
# B_SIG_STR._landed                                            85
# R_TOTAL_STR._att                                             49
# R_TOTAL_STR._landed                                          21
# B_TOTAL_STR._att                                            167
# B_TOTAL_STR._landed                                         109
# R_TD_att                                                      0
# R_TD_landed                                                   0
# B_TD_att                                                      2
# B_TD_landed                                                   1
# R_HEAD_att                                                   28
# R_HEAD_landed                                                 5
# B_HEAD_att                                                  114
# B_HEAD_landed                                                66
# R_BODY_att                                                   11
# R_BODY_landed                                                 6
# B_BODY_att                                                   12
# B_BODY_landed                                                11
# R_LEG_att                                                     2
# R_LEG_landed                                                  2
# B_LEG_att                                                     8
# B_LEG_landed                                                  8
# R_DISTANCE_att                                               38
# R_DISTANCE_landed                                            10
# B_DISTANCE_att                                               67
# B_DISTANCE_landed                                            39
# R_CLINCH_att                                                  3
# R_CLINCH_landed                                               3
# B_CLINCH_att                                                 20
# B_CLINCH_landed                                              17
# R_GROUND_att                                                  0
# R_GROUND_landed                                               0
# B_GROUND_att                                                 47
# B_GROUND_landed                                              29
#
#                                                            5     \
# R_fighter                                         Carlos Condit
# B_fighter                                           Court McGee
# R_KD                                                          1
# B_KD                                                          0
# R_SIG_STR_pct                                              0.38
# B_SIG_STR_pct                                              0.46
# R_TD_pct                                                      0
# B_TD_pct                                                      0
# R_SUB_ATT                                                     0
# B_SUB_ATT                                                     0
# R_REV                                                         0
# B_REV                                                         0
# R_CTRL                                                     0:02
# B_CTRL                                                     0:00
# win_by                                     Decision - Unanimous
# last_round                                                    3
# last_round_time                                            5:00
# Format                                            3 Rnd (5-5-5)
# Referee                                            Marc Goddard
# date                                           October 03, 2020
# location             Abu Dhabi, Abu Dhabi, United Arab Emirates
# Fight_type                                    Welterweight Bout
# Winner                                            Carlos Condit
# R_SIG_STR._att                                              230
# R_SIG_STR._landed                                            88
# B_SIG_STR._att                                              182
# B_SIG_STR._landed                                            84
# R_TOTAL_STR._att                                            230
# R_TOTAL_STR._landed                                          88
# B_TOTAL_STR._att                                            182
# B_TOTAL_STR._landed                                          84
# R_TD_att                                                      0
# R_TD_landed                                                   0
# B_TD_att                                                      0
# B_TD_landed                                                   0
# R_HEAD_att                                                  173
# R_HEAD_landed                                                50
# B_HEAD_att                                                   73
# B_HEAD_landed                                                 9
# R_BODY_att                                                   34
# R_BODY_landed                                                17
# B_BODY_att                                                   51
# B_BODY_landed                                                28
# R_LEG_att                                                    23
# R_LEG_landed                                                 21
# B_LEG_att                                                    58
# B_LEG_landed                                                 47
# R_DISTANCE_att                                              228
# R_DISTANCE_landed                                            87
# B_DISTANCE_att                                              182
# B_DISTANCE_landed                                            84
# R_CLINCH_att                                                  0
# R_CLINCH_landed                                               0
# B_CLINCH_att                                                  0
# B_CLINCH_landed                                               0
# R_GROUND_att                                                  2
# R_GROUND_landed                                               1
# B_GROUND_att                                                  0
# B_GROUND_landed                                               0
#
#                                                            6     \
# R_fighter                                      Charles Jourdain
# B_fighter                                          Josh Culibao
# R_KD                                                          0
# B_KD                                                          1
# R_SIG_STR_pct                                              0.43
# B_SIG_STR_pct                                              0.37
# R_TD_pct                                                      0
# B_TD_pct                                                      0
# R_SUB_ATT                                                     3
# B_SUB_ATT                                                     0
# R_REV                                                         0
# B_REV                                                         0
# R_CTRL                                                     2:51
# B_CTRL                                                     2:28
# win_by                                         Decision - Split
# last_round                                                    3
# last_round_time                                            5:00
# Format                                            3 Rnd (5-5-5)
# Referee                                            Jason Herzog
# date                                           October 03, 2020
# location             Abu Dhabi, Abu Dhabi, United Arab Emirates
# Fight_type                                   Featherweight Bout
# Winner                                                     Draw
# R_SIG_STR._att                                              101
# R_SIG_STR._landed                                            44
# B_SIG_STR._att                                              124
# B_SIG_STR._landed                                            46
# R_TOTAL_STR._att                                            126
# R_TOTAL_STR._landed                                          68
# B_TOTAL_STR._att                                            130
# B_TOTAL_STR._landed                                          51
# R_TD_att                                                      0
# R_TD_landed                                                   0
# B_TD_att                                                      7
# B_TD_landed                                                   0
# R_HEAD_att                                                   63
# R_HEAD_landed                                                17
# B_HEAD_att                                                   78
# B_HEAD_landed                                                19
# R_BODY_att                                                   19
# R_BODY_landed                                                10
# B_BODY_att                                                   40
# B_BODY_landed                                                22
# R_LEG_att                                                    19
# R_LEG_landed                                                 17
# B_LEG_att                                                     6
# B_LEG_landed                                                  5
# R_DISTANCE_att                                               81
# R_DISTANCE_landed                                            34
# B_DISTANCE_att                                              115
# B_DISTANCE_landed                                            40
# R_CLINCH_att                                                  0
# R_CLINCH_landed                                               0
# B_CLINCH_att                                                  2
# B_CLINCH_landed                                               2
# R_GROUND_att                                                 20
# R_GROUND_landed                                              10
# B_GROUND_att                                                  7
# B_GROUND_landed                                               4
#
#                                                            7     \
# R_fighter                                       Jordan Williams
# B_fighter                                    Nassourdine Imavov
# R_KD                                                          0
# B_KD                                                          0
# R_SIG_STR_pct                                               0.3
# B_SIG_STR_pct                                              0.61
# R_TD_pct                                                      0
# B_TD_pct                                                   0.12
# R_SUB_ATT                                                     0
# B_SUB_ATT                                                     4
# R_REV                                                         0
# B_REV                                                         0
# R_CTRL                                                     2:24
# B_CTRL                                                     4:51
# win_by                                     Decision - Unanimous
# last_round                                                    3
# last_round_time                                            5:00
# Format                                            3 Rnd (5-5-5)
# Referee                                            Kevin Sataki
# date                                           October 03, 2020
# location             Abu Dhabi, Abu Dhabi, United Arab Emirates
# Fight_type                                    Middleweight Bout
# Winner                                       Nassourdine Imavov
# R_SIG_STR._att                                               98
# R_SIG_STR._landed                                            30
# B_SIG_STR._att                                              110
# B_SIG_STR._landed                                            68
# R_TOTAL_STR._att                                            137
# R_TOTAL_STR._landed                                          62
# B_TOTAL_STR._att                                            126
# B_TOTAL_STR._landed                                          81
# R_TD_att                                                      3
# R_TD_landed                                                   0
# B_TD_att                                                      8
# B_TD_landed                                                   1
# R_HEAD_att                                                   88
# R_HEAD_landed                                                25
# B_HEAD_att                                                   90
# B_HEAD_landed                                                50
# R_BODY_att                                                    9
# R_BODY_landed                                                 4
# B_BODY_att                                                   14
# B_BODY_landed                                                13
# R_LEG_att                                                     1
# R_LEG_landed                                                  1
# B_LEG_att                                                     6
# B_LEG_landed                                                  5
# R_DISTANCE_att                                               88
# R_DISTANCE_landed                                            23
# B_DISTANCE_att                                               83
# B_DISTANCE_landed                                            48
# R_CLINCH_att                                                 10
# R_CLINCH_landed                                               7
# B_CLINCH_att                                                 13
# B_CLINCH_landed                                              12
# R_GROUND_att                                                  0
# R_GROUND_landed                                               0
# B_GROUND_att                                                 14
# B_GROUND_landed                                               8
#
#                                                            8     \
# R_fighter                                      Loma Lookboonmee
# B_fighter                                          Jinh Yu Frey
# R_KD                                                          0
# B_KD                                                          0
# R_SIG_STR_pct                                              0.58
# B_SIG_STR_pct                                              0.42
# R_TD_pct                                                      0
# B_TD_pct                                                   0.25
# R_SUB_ATT                                                     0
# B_SUB_ATT                                                     0
# R_REV                                                         0
# B_REV                                                         0
# R_CTRL                                                     1:23
# B_CTRL                                                     2:34
# win_by                                     Decision - Unanimous
# last_round                                                    3
# last_round_time                                            5:00
# Format                                            3 Rnd (5-5-5)
# Referee                                            Marc Goddard
# date                                           October 03, 2020
# location             Abu Dhabi, Abu Dhabi, United Arab Emirates
# Fight_type                             Women's Strawweight Bout
# Winner                                         Loma Lookboonmee
# R_SIG_STR._att                                              137
# R_SIG_STR._landed                                            80
# B_SIG_STR._att                                               61
# B_SIG_STR._landed                                            26
# R_TOTAL_STR._att                                            142
# R_TOTAL_STR._landed                                          85
# B_TOTAL_STR._att                                             75
# B_TOTAL_STR._landed                                          39
# R_TD_att                                                      1
# R_TD_landed                                                   0
# B_TD_att                                                      4
# B_TD_landed                                                   1
# R_HEAD_att                                                   61
# R_HEAD_landed                                                27
# B_HEAD_att                                                   49
# B_HEAD_landed                                                21
# R_BODY_att                                                   56
# R_BODY_landed                                                35
# B_BODY_att                                                    8
# B_BODY_landed                                                 4
# R_LEG_att                                                    20
# R_LEG_landed                                                 18
# B_LEG_att                                                     4
# B_LEG_landed                                                  1
# R_DISTANCE_att                                               86
# R_DISTANCE_landed                                            42
# B_DISTANCE_att                                               47
# B_DISTANCE_landed                                            13
# R_CLINCH_att                                                 50
# R_CLINCH_landed                                              38
# B_CLINCH_att                                                 14
# B_CLINCH_landed                                              13
# R_GROUND_att                                                  1
# R_GROUND_landed                                               0
# B_GROUND_att                                                  0
# B_GROUND_landed                                               0
#
#                                                            9     ...  \
# R_fighter                                          Casey Kenney  ...
# B_fighter                                         Heili Alateng  ...
# R_KD                                                          0  ...
# B_KD                                                          0  ...
# R_SIG_STR_pct                                              0.41  ...
# B_SIG_STR_pct                                              0.26  ...
# R_TD_pct                                                      0  ...
# B_TD_pct                                                      0  ...
# R_SUB_ATT                                                     0  ...
# B_SUB_ATT                                                     0  ...
# R_REV                                                         0  ...
# B_REV                                                         0  ...
# R_CTRL                                                     0:00  ...
# B_CTRL                                                     0:00  ...
# win_by                                     Decision - Unanimous  ...
# last_round                                                    3  ...
# last_round_time                                            5:00  ...
# Format                                            3 Rnd (5-5-5)  ...
# Referee                                            Kevin Sataki  ...
# date                                           October 03, 2020  ...
# location             Abu Dhabi, Abu Dhabi, United Arab Emirates  ...
# Fight_type                                    Bantamweight Bout  ...
# Winner                                             Casey Kenney  ...
# R_SIG_STR._att                                              263  ...
# R_SIG_STR._landed                                           109  ...
# B_SIG_STR._att                                              171  ...
# B_SIG_STR._landed                                            46  ...
# R_TOTAL_STR._att                                            263  ...
# R_TOTAL_STR._landed                                         109  ...
# B_TOTAL_STR._att                                            171  ...
# B_TOTAL_STR._landed                                          46  ...
# R_TD_att                                                      1  ...
# R_TD_landed                                                   0  ...
# B_TD_att                                                      0  ...
# B_TD_landed                                                   0  ...
# R_HEAD_att                                                  192  ...
# R_HEAD_landed                                                57  ...
# B_HEAD_att                                                  140  ...
# B_HEAD_landed                                                26  ...
# R_BODY_att                                                   58  ...
# R_BODY_landed                                                41  ...
# B_BODY_att                                                   20  ...
# B_BODY_landed                                                11  ...
# R_LEG_att                                                    13  ...
# R_LEG_landed                                                 11  ...
# B_LEG_att                                                    11  ...
# B_LEG_landed                                                  9  ...
# R_DISTANCE_att                                              261  ...
# R_DISTANCE_landed                                           109  ...
# B_DISTANCE_att                                              171  ...
# B_DISTANCE_landed                                            46  ...
# R_CLINCH_att                                                  2  ...
# R_CLINCH_landed                                               0  ...
# B_CLINCH_att                                                  0  ...
# B_CLINCH_landed                                               0  ...
# R_GROUND_att                                                  0  ...
# R_GROUND_landed                                               0  ...
# B_GROUND_att                                                  0  ...
# B_GROUND_landed                                               0  ...
#
#                                       5768                   5769  \
# R_fighter                    Johnny Rhodes          Patrick Smith
# B_fighter                      Fred Ettish           Scott Morris
# R_KD                                     1                      0
# B_KD                                     0                      0
# R_SIG_STR_pct                         0.44                   0.76
# B_SIG_STR_pct                         0.57                      0
# R_TD_pct                                 0                      0
# B_TD_pct                                 0                      0
# R_SUB_ATT                                1                      0
# B_SUB_ATT                                0                      0
# R_REV                                    0                      0
# B_REV                                    0                      0
# R_CTRL                                  --                     --
# B_CTRL                                  --                     --
# win_by                          Submission                 KO/TKO
# last_round                               1                      1
# last_round_time                       3:07                   0:30
# Format                       No Time Limit          No Time Limit
# Referee                      John McCarthy          John McCarthy
# date                        March 11, 1994         March 11, 1994
# location             Denver, Colorado, USA  Denver, Colorado, USA
# Fight_type                Open Weight Bout       Open Weight Bout
# Winner                       Johnny Rhodes          Patrick Smith
# R_SIG_STR._att                          29                     17
# R_SIG_STR._landed                       13                     13
# B_SIG_STR._att                           7                      0
# B_SIG_STR._landed                        4                      0
# R_TOTAL_STR._att                        38                     25
# R_TOTAL_STR._landed                     21                     19
# B_TOTAL_STR._att                        11                      0
# B_TOTAL_STR._landed                      7                      0
# R_TD_att                                 0                      0
# R_TD_landed                              0                      0
# B_TD_att                                 0                      1
# B_TD_landed                              0                      0
# R_HEAD_att                              28                     16
# R_HEAD_landed                           12                     12
# B_HEAD_att                               1                      0
# B_HEAD_landed                            0                      0
# R_BODY_att                               0                      1
# R_BODY_landed                            0                      1
# B_BODY_att                               4                      0
# B_BODY_landed                            2                      0
# R_LEG_att                                1                      0
# R_LEG_landed                             1                      0
# B_LEG_att                                2                      0
# B_LEG_landed                             2                      0
# R_DISTANCE_att                           6                      0
# R_DISTANCE_landed                        3                      0
# B_DISTANCE_att                           7                      0
# B_DISTANCE_landed                        4                      0
# R_CLINCH_att                             2                      1
# R_CLINCH_landed                          1                      1
# B_CLINCH_att                             0                      0
# B_CLINCH_landed                          0                      0
# R_GROUND_att                            21                     16
# R_GROUND_landed                          9                     12
# B_GROUND_att                             0                      0
# B_GROUND_landed                          0                      0
#
#                                       5770                   5771  \
# R_fighter                     Royce Gracie          Jason DeLucia
# B_fighter                  Minoki Ichihara            Scott Baker
# R_KD                                     0                      0
# B_KD                                     0                      0
# R_SIG_STR_pct                          0.5                    0.6
# B_SIG_STR_pct                         0.42                      0
# R_TD_pct                                 1                      0
# B_TD_pct                                 0                      1
# R_SUB_ATT                                2                      5
# B_SUB_ATT                                0                      0
# R_REV                                    0                      4
# B_REV                                    0                      2
# R_CTRL                                  --                     --
# B_CTRL                                  --                     --
# win_by                          Submission             Submission
# last_round                               1                      1
# last_round_time                       5:08                   6:41
# Format                       No Time Limit          No Time Limit
# Referee                      John McCarthy          John McCarthy
# date                        March 11, 1994         March 11, 1994
# location             Denver, Colorado, USA  Denver, Colorado, USA
# Fight_type                Open Weight Bout       Open Weight Bout
# Winner                        Royce Gracie          Jason DeLucia
# R_SIG_STR._att                           4                      5
# R_SIG_STR._landed                        2                      3
# B_SIG_STR._att                           7                      2
# B_SIG_STR._landed                        3                      0
# R_TOTAL_STR._att                       114                     25
# R_TOTAL_STR._landed                    110                     20
# B_TOTAL_STR._att                        16                     23
# B_TOTAL_STR._landed                     12                     14
# R_TD_att                                 1                      1
# R_TD_landed                              1                      0
# B_TD_att                                 0                      1
# B_TD_landed                              0                      1
# R_HEAD_att                               0                      2
# R_HEAD_landed                            0                      1
# B_HEAD_att                               6                      2
# B_HEAD_landed                            3                      0
# R_BODY_att                               0                      2
# R_BODY_landed                            0                      1
# B_BODY_att                               0                      0
# B_BODY_landed                            0                      0
# R_LEG_att                                4                      1
# R_LEG_landed                             2                      1
# B_LEG_att                                1                      0
# B_LEG_landed                             0                      0
# R_DISTANCE_att                           4                      4
# R_DISTANCE_landed                        2                      2
# B_DISTANCE_att                           2                      2
# B_DISTANCE_landed                        0                      0
# R_CLINCH_att                             0                      0
# R_CLINCH_landed                          0                      0
# B_CLINCH_att                             0                      0
# B_CLINCH_landed                          0                      0
# R_GROUND_att                             0                      1
# R_GROUND_landed                          0                      1
# B_GROUND_att                             5                      0
# B_GROUND_landed                          3                      0
#
#                                       5772                   5773  \
# R_fighter                    Remco Pardoel           Orlando Wiet
# B_fighter               Alberta Cerra Leon       Robert Lucarelli
# R_KD                                     0                      0
# B_KD                                     0                      0
# R_SIG_STR_pct                         0.66                   0.66
# B_SIG_STR_pct                         0.33                   0.33
# R_TD_pct                                 1                      0
# B_TD_pct                                 0                      1
# R_SUB_ATT                                1                      0
# B_SUB_ATT                                0                      1
# R_REV                                    0                      0
# B_REV                                    0                      0
# R_CTRL                                  --                     --
# B_CTRL                                  --                     --
# win_by                          Submission                 KO/TKO
# last_round                               1                      1
# last_round_time                       9:51                   2:50
# Format                       No Time Limit          No Time Limit
# Referee                      John McCarthy          John McCarthy
# date                        March 11, 1994         March 11, 1994
# location             Denver, Colorado, USA  Denver, Colorado, USA
# Fight_type                Open Weight Bout       Open Weight Bout
# Winner                       Remco Pardoel           Orlando Wiet
# R_SIG_STR._att                           6                     12
# R_SIG_STR._landed                        4                      8
# B_SIG_STR._att                           3                      6
# B_SIG_STR._landed                        1                      2
# R_TOTAL_STR._att                        22                     15
# R_TOTAL_STR._landed                     20                     11
# B_TOTAL_STR._att                        11                      6
# B_TOTAL_STR._landed                      9                      2
# R_TD_att                                 1                      0
# R_TD_landed                              1                      0
# B_TD_att                                 0                      1
# B_TD_landed                              0                      1
# R_HEAD_att                               5                     11
# R_HEAD_landed                            4                      7
# B_HEAD_att                               3                      2
# B_HEAD_landed                            1                      1
# R_BODY_att                               0                      1
# R_BODY_landed                            0                      1
# B_BODY_att                               0                      1
# B_BODY_landed                            0                      0
# R_LEG_att                                1                      0
# R_LEG_landed                             0                      0
# B_LEG_att                                0                      3
# B_LEG_landed                             0                      1
# R_DISTANCE_att                           1                      3
# R_DISTANCE_landed                        0                      1
# B_DISTANCE_att                           1                      6
# B_DISTANCE_landed                        1                      2
# R_CLINCH_att                             0                      0
# R_CLINCH_landed                          0                      0
# B_CLINCH_att                             0                      0
# B_CLINCH_landed                          0                      0
# R_GROUND_att                             5                      9
# R_GROUND_landed                          4                      7
# B_GROUND_att                             2                      0
# B_GROUND_landed                          0                      0
#
#                                       5774                   5775  \
# R_fighter                    Frank Hamaker          Johnny Rhodes
# B_fighter                  Thaddeus Luster          David Levicki
# R_KD                                     0                      0
# B_KD                                     0                      0
# R_SIG_STR_pct                         0.66                   0.64
# B_SIG_STR_pct                            0                    0.8
# R_TD_pct                                 1                      1
# B_TD_pct                                 0                      0
# R_SUB_ATT                                3                      0
# B_SUB_ATT                                0                      0
# R_REV                                    1                      0
# B_REV                                    0                      0
# R_CTRL                                  --                     --
# B_CTRL                                  --                     --
# win_by                          Submission                 KO/TKO
# last_round                               1                      1
# last_round_time                       4:52                  12:13
# Format                       No Time Limit          No Time Limit
# Referee                      John McCarthy          John McCarthy
# date                        March 11, 1994         March 11, 1994
# location             Denver, Colorado, USA  Denver, Colorado, USA
# Fight_type                Open Weight Bout       Open Weight Bout
# Winner                       Frank Hamaker          Johnny Rhodes
# R_SIG_STR._att                           3                     17
# R_SIG_STR._landed                        2                     11
# B_SIG_STR._att                           0                      5
# B_SIG_STR._landed                        0                      4
# R_TOTAL_STR._att                        15                     86
# R_TOTAL_STR._landed                     14                     74
# B_TOTAL_STR._att                         0                    102
# B_TOTAL_STR._landed                      0                     95
# R_TD_att                                 1                      1
# R_TD_landed                              1                      1
# B_TD_att                                 1                      0
# B_TD_landed                              0                      0
# R_HEAD_att                               3                     15
# R_HEAD_landed                            2                      9
# B_HEAD_att                               0                      5
# B_HEAD_landed                            0                      4
# R_BODY_att                               0                      1
# R_BODY_landed                            0                      1
# B_BODY_att                               0                      0
# B_BODY_landed                            0                      0
# R_LEG_att                                0                      1
# R_LEG_landed                             0                      1
# B_LEG_att                                0                      0
# B_LEG_landed                             0                      0
# R_DISTANCE_att                           1                      1
# R_DISTANCE_landed                        1                      1
# B_DISTANCE_att                           0                      2
# B_DISTANCE_landed                        0                      1
# R_CLINCH_att                             0                      1
# R_CLINCH_landed                          0                      1
# B_CLINCH_att                             0                      2
# B_CLINCH_landed                          0                      2
# R_GROUND_att                             2                     15
# R_GROUND_landed                          1                      9
# B_GROUND_att                             0                      1
# B_GROUND_landed                          0                      1
#
#                                       5776                   5777
# R_fighter                    Patrick Smith           Scott Morris
# B_fighter                       Ray Wizard         Sean Daugherty
# R_KD                                     0                      0
# B_KD                                     0                      0
# R_SIG_STR_pct                            1                      1
# B_SIG_STR_pct                            1                      0
# R_TD_pct                                 0                      1
# B_TD_pct                                 0                      0
# R_SUB_ATT                                1                      1
# B_SUB_ATT                                0                      0
# R_REV                                    0                      0
# B_REV                                    0                      0
# R_CTRL                                  --                     --
# B_CTRL                                  --                     --
# win_by                          Submission             Submission
# last_round                               1                      1
# last_round_time                       0:58                   0:20
# Format                       No Time Limit          No Time Limit
# Referee                      John McCarthy          John McCarthy
# date                        March 11, 1994         March 11, 1994
# location             Denver, Colorado, USA  Denver, Colorado, USA
# Fight_type                Open Weight Bout       Open Weight Bout
# Winner                       Patrick Smith           Scott Morris
# R_SIG_STR._att                           1                      1
# R_SIG_STR._landed                        1                      1
# B_SIG_STR._att                           1                      4
# B_SIG_STR._landed                        1                      0
# R_TOTAL_STR._att                         1                      2
# R_TOTAL_STR._landed                      1                      2
# B_TOTAL_STR._att                         2                      5
# B_TOTAL_STR._landed                      2                      1
# R_TD_att                                 1                      1
# R_TD_landed                              0                      1
# B_TD_att                                 0                      0
# B_TD_landed                              0                      0
# R_HEAD_att                               0                      1
# R_HEAD_landed                            0                      1
# B_HEAD_att                               0                      2
# B_HEAD_landed                            0                      0
# R_BODY_att                               1                      0
# R_BODY_landed                            1                      0
# B_BODY_att                               0                      0
# B_BODY_landed                            0                      0
# R_LEG_att                                0                      0
# R_LEG_landed                             0                      0
# B_LEG_att                                1                      2
# B_LEG_landed                             1                      0
# R_DISTANCE_att                           0                      0
# R_DISTANCE_landed                        0                      0
# B_DISTANCE_att                           1                      3
# B_DISTANCE_landed                        1                      0
# R_CLINCH_att                             1                      1
# R_CLINCH_landed                          1                      1
# B_CLINCH_att                             0                      1
# B_CLINCH_landed                          0                      0
# R_GROUND_att                             0                      0
# R_GROUND_landed                          0                      0
# B_GROUND_att                             0                      0
# B_GROUND_landed                          0                      0
#
# [59 rows x 5778 columns]

# %% [markdown]
# ### Creating a title_bout feature and weight_class

# %%
df['Fight_type'].value_counts()
# Out:
# Lightweight Bout                                                  1025
# Welterweight Bout                                                 1001
# Middleweight Bout                                                  741
# Heavyweight Bout                                                   508
# Light Heavyweight Bout                                             502
#                                                                   ...
# UFC 14 Heavyweight Tournament Title Bout                             1
# Ultimate Japan 2 Heavyweight Tournament Title Bout                   1
# Ultimate Fighter 18 Women's Bantamweight Tournament Title Bout       1
# Ultimate Fighter 27 Lightweight Tournament Title Bout                1
# Ultimate Fighter 18 Bantamweight Tournament Title Bout               1
# Name: Fight_type, Length: 111, dtype: int64

# %%
df['Fight_type'].value_counts()[df['Fight_type'].value_counts() > 1].index
# Out:
# Index(['Lightweight Bout', 'Welterweight Bout', 'Middleweight Bout',
#        'Heavyweight Bout', 'Light Heavyweight Bout', 'Featherweight Bout',
#        'Bantamweight Bout', 'Flyweight Bout', 'Women's Strawweight Bout',
#        'Women's Bantamweight Bout', 'Women's Flyweight Bout',
#        'Open Weight Bout', 'UFC Light Heavyweight Title Bout',
#        'UFC Welterweight Title Bout', 'UFC Heavyweight Title Bout',
#        'Catch Weight Bout', 'UFC Middleweight Title Bout',
#        'UFC Lightweight Title Bout', 'UFC Flyweight Title Bout',
#        'UFC Women's Bantamweight Title Bout', 'UFC Bantamweight Title Bout',
#        'UFC Featherweight Title Bout', 'UFC Women's Strawweight Title Bout',
#        'Women's Featherweight Bout', 'UFC Women's Featherweight Title Bout',
#        'UFC Interim Heavyweight Title Bout',
#        'UFC Superfight Championship Bout', 'UFC Women's Flyweight Title Bout',
#        'UFC Interim Middleweight Title Bout',
#        'UFC Interim Lightweight Title Bout',
#        'UFC Interim Featherweight Title Bout',
#        'UFC Interim Bantamweight Title Bout',
#        'UFC Interim Welterweight Title Bout',
#        'UFC Interim Light Heavyweight Title Bout'],
#       dtype='object')

# %%
df['title_bout'] = df['Fight_type'].apply(lambda X: True if 'Title Bout' in X else False)

# %%
def make_weight_class(X):
    for weight_class in weight_classes:
        if weight_class in X:
            return weight_class
    if X == 'Catch Weight Bout' or 'Catchweight Bout':
        return 'Catch Weight'
    else:
        return 'Open Weight'

# %%
weight_classes = ['Women\'s Strawweight', 'Women\'s Bantamweight', 
                  'Women\'s Featherweight', 'Women\'s Flyweight', 'Lightweight', 
                  'Welterweight', 'Middleweight','Light Heavyweight', 
                  'Heavyweight', 'Featherweight','Bantamweight', 'Flyweight', 'Open Weight']

df['weight_class'] = df['Fight_type'].apply(make_weight_class)

# %%
df[df['weight_class'].isnull()]['Fight_type'].value_counts()
# Out:
# Series([], Name: Fight_type, dtype: int64)

# %% [markdown]
# ### Creating total_time_fought

# %%
df['Format'].value_counts()
# Out:
# 3 Rnd (5-5-5)           5079
# 5 Rnd (5-5-5-5-5)        483
# 1 Rnd + OT (12-3)         80
# No Time Limit             29
# 3 Rnd + OT (5-5-5-5)      22
# 1 Rnd (20)                21
# 1 Rnd + 2OT (15-3-3)      20
# 2 Rnd (5-5)               14
# 1 Rnd (15)                 8
# 1 Rnd (10)                 6
# 1 Rnd (12)                 4
# 1 Rnd + OT (30-5)          3
# 1 Rnd + OT (15-3)          2
# 1 Rnd (18)                 2
# 1 Rnd + OT (31-5)          1
# 1 Rnd + 2OT (24-3-3)       1
# 1 Rnd (30)                 1
# 1 Rnd + OT (30-3)          1
# 1 Rnd + OT (27-3)          1
# Name: Format, dtype: int64

# %%
df['Format'].value_counts().index
# Out:
# Index(['3 Rnd (5-5-5)', '5 Rnd (5-5-5-5-5)', '1 Rnd + OT (12-3)',
#        'No Time Limit', '3 Rnd + OT (5-5-5-5)', '1 Rnd (20)',
#        '1 Rnd + 2OT (15-3-3)', '2 Rnd (5-5)', '1 Rnd (15)', '1 Rnd (10)',
#        '1 Rnd (12)', '1 Rnd + OT (30-5)', '1 Rnd + OT (15-3)', '1 Rnd (18)',
#        '1 Rnd + OT (31-5)', '1 Rnd + 2OT (24-3-3)', '1 Rnd (30)',
#        '1 Rnd + OT (30-3)', '1 Rnd + OT (27-3)'],
#       dtype='object')

# %%
time_in_first_round = {'3 Rnd (5-5-5)': 5*60, '5 Rnd (5-5-5-5-5)': 5*60, '1 Rnd + OT (12-3)': 12*60,
       'No Time Limit': 1, '3 Rnd + OT (5-5-5-5)': 5*60, '1 Rnd (20)': 1*20,
       '2 Rnd (5-5)': 5*60, '1 Rnd (15)': 15*60, '1 Rnd (10)': 10*60,
       '1 Rnd (12)':12*60, '1 Rnd + OT (30-5)': 30*60, '1 Rnd (18)': 18*60, '1 Rnd + OT (15-3)': 15*60,
       '1 Rnd (30)': 30*60, '1 Rnd + OT (31-5)': 31*5,
       '1 Rnd + OT (27-3)': 27*60, '1 Rnd + OT (30-3)': 30*60}

exception_format_time = {'1 Rnd + 2OT (15-3-3)': [15*60, 3*60], '1 Rnd + 2OT (24-3-3)': [24*60, 3*60]}

# '1 Rnd + 2OT (15-3-3)' and '1 Rnd + 2OT (24-3-3)' is not included because it has 3 uneven timed rounds. 
# We'll have to deal with it separately

# %%
# Converting to seconds
df['last_round_time'] = df['last_round_time'].apply(lambda X: int(X.split(':')[0])*60 + int(X.split(':')[1]))

# %%
def get_total_time(row):
    if row['Format'] in time_in_first_round.keys():
        return (row['last_round'] - 1) * time_in_first_round[row['Format']] + row['last_round_time']
    elif row['Format'] in exception_format_time.keys():
        if (row['last_round'] - 1) >= 2:
            return exception_format_time[row['Format']][0] + (row['last_round'] - 2) * \
                    exception_format_time[row['Format']][1] + row['last_round_time']
        else:
            return (row['last_round'] - 1) * exception_format_time[row['Format']][0] + row['last_round_time']
    
# So if the fight ended in round 1, we only need last_round_time. 
# If it ended in round 2, we need the full time of round 1 and the last_round_time
# This works for fights with same time in each round and fights with only two rounds.

# %%
df['total_time_fought(seconds)'] = df.apply(get_total_time, axis=1)

# %%
def get_no_of_rounds(X):
    if X == 'No Time Limit':
        return 1
    else:
        return len(X.split('(')[1].replace(')', '').split('-'))

df['no_of_rounds'] = df['Format'].apply(get_no_of_rounds)

# %%
df
# Out:
#                  R_fighter         B_fighter  R_KD  B_KD  R_SIG_STR_pct  \
# 0               Holly Holm      Irene Aldana     0     0           0.51
# 1         Yorgan De Castro     Carlos Felipe     0     0           0.48
# 2     Germaine de Randamie     Julianna Pena     0     0           0.40
# 3           Kyler Phillips      Cameron Else     0     0           0.41
# 4          Dequan Townsend   Dusko Todorovic     0     0           0.31
# ...                    ...               ...   ...   ...            ...
# 5773          Orlando Wiet  Robert Lucarelli     0     0           0.66
# 5774         Frank Hamaker   Thaddeus Luster     0     0           0.66
# 5775         Johnny Rhodes     David Levicki     0     0           0.64
# 5776         Patrick Smith        Ray Wizard     0     0           1.00
# 5777          Scott Morris    Sean Daugherty     0     0           1.00
#
#       B_SIG_STR_pct  R_TD_pct  B_TD_pct  R_SUB_ATT  B_SUB_ATT  ...  \
# 0              0.37      0.35       0.0          0          0  ...
# 1              0.44      0.00       0.0          0          0  ...
# 2              0.29      0.00       0.5          2          0  ...
# 3              0.36      1.00       0.0          0          0  ...
# 4              0.63      0.00       0.5          0          0  ...
# ...             ...       ...       ...        ...        ...  ...
# 5773           0.33      0.00       1.0          0          1  ...
# 5774           0.00      1.00       0.0          3          0  ...
# 5775           0.80      1.00       0.0          0          0  ...
# 5776           1.00      0.00       0.0          1          0  ...
# 5777           0.00      1.00       0.0          1          0  ...
#
#       B_CLINCH_att  B_CLINCH_landed R_GROUND_att R_GROUND_landed B_GROUND_att  \
# 0                4                4           28              13            0
# 1               16               13            0               0            0
# 2                2                2            1               1           14
# 3                0                0           37              19            2
# 4               20               17            0               0           47
# ...            ...              ...          ...             ...          ...
# 5773             0                0            9               7            0
# 5774             0                0            2               1            0
# 5775             2                2           15               9            1
# 5776             0                0            0               0            0
# 5777             1                0            0               0            0
#
#       B_GROUND_landed  title_bout          weight_class  \
# 0                   0       False  Women's Bantamweight
# 1                   0       False           Heavyweight
# 2                   7       False  Women's Bantamweight
# 3                   1       False          Bantamweight
# 4                  29       False          Middleweight
# ...               ...         ...                   ...
# 5773                0       False           Open Weight
# 5774                0       False           Open Weight
# 5775                1       False           Open Weight
# 5776                0       False           Open Weight
# 5777                0       False           Open Weight
#
#      total_time_fought(seconds) no_of_rounds
# 0                          1500            5
# 1                           900            3
# 2                           805            3
# 3                           344            3
# 4                           495            3
# ...                         ...          ...
# 5773                        170            1
# 5774                        292            1
# 5775                        733            1
# 5776                         58            1
# 5777                         20            1
#
# [5778 rows x 63 columns]

# %%
df.drop(['Format', 'Fight_type', 'last_round_time'], axis = 1, inplace=True)

# %% [markdown]
# ### Create CTRL_time(seconds)

# %%
CTRL_columns = ['R_CTRL','B_CTRL']

def conv_to_sec(X):
    if X != '--':
        return int(X.split(':')[0])*60 + int(X.split(':')[1])
    else:
        # if '--' means there was no time spent on the ground. 
        # Taking a call here to consider this as 0 seconds
        return 0

for column in CTRL_columns:
    df[column+'_time(seconds)'] = df[column].apply(conv_to_sec)

# %%
df.T
# Out:
#                                             0                 1     \
# R_fighter                             Holly Holm  Yorgan De Castro
# B_fighter                           Irene Aldana     Carlos Felipe
# R_KD                                           0                 0
# B_KD                                           0                 0
# R_SIG_STR_pct                               0.51              0.48
# ...                                          ...               ...
# weight_class                Women's Bantamweight       Heavyweight
# total_time_fought(seconds)                  1500               900
# no_of_rounds                                   5                 3
# R_CTRL_time(seconds)                         316               193
# B_CTRL_time(seconds)                           3                88
#
#                                             2               3     \
# R_fighter                   Germaine de Randamie  Kyler Phillips
# B_fighter                          Julianna Pena    Cameron Else
# R_KD                                           0               0
# B_KD                                           0               0
# R_SIG_STR_pct                                0.4            0.41
# ...                                          ...             ...
# weight_class                Women's Bantamweight    Bantamweight
# total_time_fought(seconds)                   805             344
# no_of_rounds                                   3               3
# R_CTRL_time(seconds)                          48             145
# B_CTRL_time(seconds)                         355               3
#
#                                        4              5                 6     \
# R_fighter                   Dequan Townsend  Carlos Condit  Charles Jourdain
# B_fighter                   Dusko Todorovic    Court McGee      Josh Culibao
# R_KD                                      0              1                 0
# B_KD                                      0              0                 1
# R_SIG_STR_pct                          0.31           0.38              0.43
# ...                                     ...            ...               ...
# weight_class                   Middleweight   Welterweight     Featherweight
# total_time_fought(seconds)              495            900               900
# no_of_rounds                              3              3                 3
# R_CTRL_time(seconds)                     18              2               171
# B_CTRL_time(seconds)                    205              0               148
#
#                                           7                    8     \
# R_fighter                      Jordan Williams     Loma Lookboonmee
# B_fighter                   Nassourdine Imavov         Jinh Yu Frey
# R_KD                                         0                    0
# B_KD                                         0                    0
# R_SIG_STR_pct                              0.3                 0.58
# ...                                        ...                  ...
# weight_class                      Middleweight  Women's Strawweight
# total_time_fought(seconds)                 900                  900
# no_of_rounds                                 3                    3
# R_CTRL_time(seconds)                       144                   83
# B_CTRL_time(seconds)                       291                  154
#
#                                      9     ...           5768           5769  \
# R_fighter                    Casey Kenney  ...  Johnny Rhodes  Patrick Smith
# B_fighter                   Heili Alateng  ...    Fred Ettish   Scott Morris
# R_KD                                    0  ...              1              0
# B_KD                                    0  ...              0              0
# R_SIG_STR_pct                        0.41  ...           0.44           0.76
# ...                                   ...  ...            ...            ...
# weight_class                 Bantamweight  ...    Open Weight    Open Weight
# total_time_fought(seconds)            900  ...            187             30
# no_of_rounds                            3  ...              1              1
# R_CTRL_time(seconds)                    0  ...              0              0
# B_CTRL_time(seconds)                    0  ...              0              0
#
#                                        5770           5771  \
# R_fighter                      Royce Gracie  Jason DeLucia
# B_fighter                   Minoki Ichihara    Scott Baker
# R_KD                                      0              0
# B_KD                                      0              0
# R_SIG_STR_pct                           0.5            0.6
# ...                                     ...            ...
# weight_class                    Open Weight    Open Weight
# total_time_fought(seconds)              308            401
# no_of_rounds                              1              1
# R_CTRL_time(seconds)                      0              0
# B_CTRL_time(seconds)                      0              0
#
#                                           5772              5773  \
# R_fighter                        Remco Pardoel      Orlando Wiet
# B_fighter                   Alberta Cerra Leon  Robert Lucarelli
# R_KD                                         0                 0
# B_KD                                         0                 0
# R_SIG_STR_pct                             0.66              0.66
# ...                                        ...               ...
# weight_class                       Open Weight       Open Weight
# total_time_fought(seconds)                 591               170
# no_of_rounds                                 1                 1
# R_CTRL_time(seconds)                         0                 0
# B_CTRL_time(seconds)                         0                 0
#
#                                        5774           5775           5776  \
# R_fighter                     Frank Hamaker  Johnny Rhodes  Patrick Smith
# B_fighter                   Thaddeus Luster  David Levicki     Ray Wizard
# R_KD                                      0              0              0
# B_KD                                      0              0              0
# R_SIG_STR_pct                          0.66           0.64              1
# ...                                     ...            ...            ...
# weight_class                    Open Weight    Open Weight    Open Weight
# total_time_fought(seconds)              292            733             58
# no_of_rounds                              1              1              1
# R_CTRL_time(seconds)                      0              0              0
# B_CTRL_time(seconds)                      0              0              0
#
#                                       5777
# R_fighter                     Scott Morris
# B_fighter                   Sean Daugherty
# R_KD                                     0
# B_KD                                     0
# R_SIG_STR_pct                            1
# ...                                    ...
# weight_class                   Open Weight
# total_time_fought(seconds)              20
# no_of_rounds                             1
# R_CTRL_time(seconds)                     0
# B_CTRL_time(seconds)                     0
#
# [62 rows x 5778 columns]

# %%
df.drop(['R_CTRL','B_CTRL'], axis = 1, inplace=True)

# %% [markdown]
# ### Create another DataFrame to save the compiled data per fighter (Our Prediction DataFrame)

# %%
df.columns
# Out:
# Index(['R_fighter', 'B_fighter', 'R_KD', 'B_KD', 'R_SIG_STR_pct',
#        'B_SIG_STR_pct', 'R_TD_pct', 'B_TD_pct', 'R_SUB_ATT', 'B_SUB_ATT',
#        'R_REV', 'B_REV', 'win_by', 'last_round', 'Referee', 'date', 'location',
#        'Winner', 'R_SIG_STR._att', 'R_SIG_STR._landed', 'B_SIG_STR._att',
#        'B_SIG_STR._landed', 'R_TOTAL_STR._att', 'R_TOTAL_STR._landed',
#        'B_TOTAL_STR._att', 'B_TOTAL_STR._landed', 'R_TD_att', 'R_TD_landed',
#        'B_TD_att', 'B_TD_landed', 'R_HEAD_att', 'R_HEAD_landed', 'B_HEAD_att',
#        'B_HEAD_landed', 'R_BODY_att', 'R_BODY_landed', 'B_BODY_att',
#        'B_BODY_landed', 'R_LEG_att', 'R_LEG_landed', 'B_LEG_att',
#        'B_LEG_landed', 'R_DISTANCE_att', 'R_DISTANCE_landed', 'B_DISTANCE_att',
#        'B_DISTANCE_landed', 'R_CLINCH_att', 'R_CLINCH_landed', 'B_CLINCH_att',
#        'B_CLINCH_landed', 'R_GROUND_att', 'R_GROUND_landed', 'B_GROUND_att',
#        'B_GROUND_landed', 'title_bout', 'weight_class',
#        'total_time_fought(seconds)', 'no_of_rounds', 'R_CTRL_time(seconds)',
#        'B_CTRL_time(seconds)'],
#       dtype='object')

# %%
df2 = df.copy()

# %%
df2.drop(['R_KD', 'B_KD', 'R_SIG_STR_pct',
       'B_SIG_STR_pct', 'R_TD_pct', 'B_TD_pct', 'R_SUB_ATT', 'B_SUB_ATT',
       'R_CTRL_time(seconds)', 'B_CTRL_time(seconds)', 'R_REV', 'B_REV', 'win_by', 'last_round', 
        'R_SIG_STR._att', 'R_SIG_STR._landed',
       'B_SIG_STR._att', 'B_SIG_STR._landed', 'R_TOTAL_STR._att',
       'R_TOTAL_STR._landed', 'B_TOTAL_STR._att', 'B_TOTAL_STR._landed',
       'R_TD_att', 'R_TD_landed', 'B_TD_att', 'B_TD_landed', 'R_HEAD_att',
       'R_HEAD_landed', 'B_HEAD_att', 'B_HEAD_landed', 'R_BODY_att',
       'R_BODY_landed', 'B_BODY_att', 'B_BODY_landed', 'R_LEG_att',
       'R_LEG_landed', 'B_LEG_att', 'B_LEG_landed', 'R_DISTANCE_att',
       'R_DISTANCE_landed', 'B_DISTANCE_att', 'B_DISTANCE_landed',
       'R_CLINCH_att', 'R_CLINCH_landed', 'B_CLINCH_att', 'B_CLINCH_landed',
       'R_GROUND_att', 'R_GROUND_landed', 'B_GROUND_att', 'B_GROUND_landed',
        'total_time_fought(seconds)'], axis = 1, inplace=True)
df2
# Out:
#                  R_fighter         B_fighter        Referee              date  \
# 0               Holly Holm      Irene Aldana   Marc Goddard  October 03, 2020
# 1         Yorgan De Castro     Carlos Felipe   Kevin Sataki  October 03, 2020
# 2     Germaine de Randamie     Julianna Pena            NaN  October 03, 2020
# 3           Kyler Phillips      Cameron Else   Marc Goddard  October 03, 2020
# 4          Dequan Townsend   Dusko Todorovic   Jason Herzog  October 03, 2020
# ...                    ...               ...            ...               ...
# 5773          Orlando Wiet  Robert Lucarelli  John McCarthy    March 11, 1994
# 5774         Frank Hamaker   Thaddeus Luster  John McCarthy    March 11, 1994
# 5775         Johnny Rhodes     David Levicki  John McCarthy    March 11, 1994
# 5776         Patrick Smith        Ray Wizard  John McCarthy    March 11, 1994
# 5777          Scott Morris    Sean Daugherty  John McCarthy    March 11, 1994
#
#                                         location                Winner  \
# 0     Abu Dhabi, Abu Dhabi, United Arab Emirates            Holly Holm
# 1     Abu Dhabi, Abu Dhabi, United Arab Emirates         Carlos Felipe
# 2     Abu Dhabi, Abu Dhabi, United Arab Emirates  Germaine de Randamie
# 3     Abu Dhabi, Abu Dhabi, United Arab Emirates        Kyler Phillips
# 4     Abu Dhabi, Abu Dhabi, United Arab Emirates       Dusko Todorovic
# ...                                          ...                   ...
# 5773                       Denver, Colorado, USA          Orlando Wiet
# 5774                       Denver, Colorado, USA         Frank Hamaker
# 5775                       Denver, Colorado, USA         Johnny Rhodes
# 5776                       Denver, Colorado, USA         Patrick Smith
# 5777                       Denver, Colorado, USA          Scott Morris
#
#       title_bout          weight_class  no_of_rounds
# 0          False  Women's Bantamweight             5
# 1          False           Heavyweight             3
# 2          False  Women's Bantamweight             3
# 3          False          Bantamweight             3
# 4          False          Middleweight             3
# ...          ...                   ...           ...
# 5773       False           Open Weight             1
# 5774       False           Open Weight             1
# 5775       False           Open Weight             1
# 5776       False           Open Weight             1
# 5777       False           Open Weight             1
#
# [5778 rows x 9 columns]

# %% [markdown]
# ### Compiling Data per fighter

# %%
red_fighters = df['R_fighter'].value_counts().index
blue_fighters = df['B_fighter'].value_counts().index

fighters = list(set(red_fighters) | set(blue_fighters))

# %%
def get_renamed_winner(row):
    if row['R_fighter'] == row['Winner']:
        return 'Red'
    elif row['B_fighter'] == row['Winner']:
        return 'Blue'
    elif row['Winner'] == 'Draw':
        return 'Draw'

df2['Winner'] = df2[['R_fighter', 'B_fighter', 'Winner']].apply(get_renamed_winner, axis=1)

# %%
df = pd.concat([df,pd.get_dummies(df['win_by'], prefix='win_by')],axis=1)
df.drop(['win_by'],axis=1, inplace=True)

# %%
Numerical_columns = ['hero_KD', 'opp_KD', 'hero_SIG_STR_pct',
       'opp_SIG_STR_pct', 'hero_TD_pct', 'opp_TD_pct', 'hero_SUB_ATT', 'opp_SUB_ATT',
        'hero_REV', 'opp_REV', 'hero_SIG_STR._att', 'hero_SIG_STR._landed',
       'opp_SIG_STR._att', 'opp_SIG_STR._landed', 'hero_TOTAL_STR._att',
       'hero_TOTAL_STR._landed', 'opp_TOTAL_STR._att', 'opp_TOTAL_STR._landed',
       'hero_TD_att', 'hero_TD_landed', 'opp_TD_att', 'opp_TD_landed', 'hero_HEAD_att',
       'hero_HEAD_landed', 'opp_HEAD_att', 'opp_HEAD_landed', 'hero_BODY_att',
       'hero_BODY_landed', 'opp_BODY_att', 'opp_BODY_landed', 'hero_LEG_att',
       'hero_LEG_landed', 'opp_LEG_att', 'opp_LEG_landed', 'hero_DISTANCE_att',
       'hero_DISTANCE_landed', 'opp_DISTANCE_att', 'opp_DISTANCE_landed',
       'hero_CLINCH_att', 'hero_CLINCH_landed', 'opp_CLINCH_att', 'opp_CLINCH_landed',
       'hero_GROUND_att', 'hero_GROUND_landed', 'opp_GROUND_att', 'opp_GROUND_landed', 
        'hero_CTRL_time(seconds)', 'opp_CTRL_time(seconds)',
       'total_time_fought(seconds)']

Categorical_columns = ['win_by', 'last_round',
        'Winner', 'title_bout']

# %% [markdown]
# For all `Numerical_columns`, we take the average of those columns for every fighter of every fight they had up until that point.
#
# For `Categorical_columns`, we have to come up with different ideas for each column:
#
# * Each `win_by` will be a column of it's own
# * from `last_round` we can get, `total_rounds_fought`
# * from `total_time_fought` we can get `average_time_fought`
# * from `Winner` we get `wins`, `losses`, `draw`, `current_streak`, `longest_streak`
# * from `title_bout` we can get `no_of_title_fights`

# %%
import re

def lreplace(pattern, sub, string):
    """
    Replaces 'pattern' in 'string' with 'sub' if 'pattern' starts 'string'.
    """
    return re.sub('^%s' % pattern, sub, string)

# %%
red = df.groupby('R_fighter')
blue = df.groupby('B_fighter')

# %%
def get_fighter_red(fighter_name):
    try:
        fighter_red = red.get_group(fighter_name)
    except:
        return None
    rename_columns = {}
    for column in fighter_red.columns:
        if re.search('^R_', column) is not None:
            rename_columns[column] = lreplace('R_', 'hero_', column)
        elif re.search('^B_', column) is not None:
            rename_columns[column] = lreplace('B_', 'opp_', column)
    fighter_red = fighter_red.rename(rename_columns, axis='columns')
    return fighter_red

# %%
def get_fighter_blue(fighter_name):
    try:
        fighter_blue = blue.get_group(fighter_name)
    except:
        return None
    rename_columns = {}
    for column in fighter_blue.columns:
        if re.search('^B_', column) is not None:
            rename_columns[column] = lreplace('B_', 'hero_', column)
        elif re.search('^R_', column) is not None:
            rename_columns[column] = lreplace('R_', 'opp_', column)
    fighter_blue = fighter_blue.rename(rename_columns, axis='columns')
    return fighter_blue

# %%
def get_result_stats(result_list):
    result_list.reverse() # To get it in ascending order
    current_win_streak = 0
    current_lose_streak = 0
    longest_win_streak = 0
    wins = 0
    losses = 0
    draw = 0
    for result in result_list:
        if result == 'hero':
            wins += 1
            current_win_streak += 1
            current_lose_streak = 0
            if longest_win_streak < current_win_streak:
                longest_win_streak += 1
        elif result == 'opp':
            losses += 1
            current_win_streak = 0
            current_lose_streak += 1
        elif result == 'draw':
            draw += 1
            current_lose_streak = 0
            current_win_streak = 0
            
    return current_win_streak, current_lose_streak, longest_win_streak, wins, losses, draw

# %%
win_by_columns = ['win_by_Decision - Majority', 'win_by_Decision - Split',
       'win_by_Decision - Unanimous', 'win_by_KO/TKO','win_by_Submission',
       'win_by_TKO - Doctor\'s Stoppage']

# %%
temp_blue_frame = pd.DataFrame()
temp_red_frame = pd.DataFrame()
result_stats = ['current_win_streak', 'current_lose_streak', 'longest_win_streak', 'wins', 'losses', 'draw']

for fighter_name in fighters:
    fighter_red = get_fighter_red(fighter_name)
    fighter_blue = get_fighter_blue(fighter_name)
    fighter_index = None
    
    if fighter_red is None:
        fighter = fighter_blue
        fighter_index = 'blue'
    elif fighter_blue is None:
        fighter = fighter_red
        fighter_index = 'red'
    else:
        fighter = pd.concat([fighter_red, fighter_blue]).sort_index()
    
    fighter['Winner'] = fighter['Winner'].apply(lambda X: 'hero' if X == fighter_name else 'opp')
    
    for i, index in enumerate(fighter.index):
        fighter_slice = fighter[(i+1):]
        s = fighter_slice[Numerical_columns].mean()
        s['total_rounds_fought'] = fighter_slice['last_round'].sum()
        s['total_title_bouts'] = fighter_slice[fighter_slice['title_bout']==True]['title_bout'].count()
        s['hero_fighter'] = fighter_name
        results = get_result_stats(list(fighter_slice['Winner']))
        for result_stat, result in zip(result_stats, results):
            s[result_stat] = result
        win_by_results = fighter_slice[fighter_slice['Winner'] == 'hero'][win_by_columns].sum()
        for win_by_column,win_by_result in zip(win_by_columns, win_by_results):
            s[win_by_column] = win_by_result
        s.name = index

        if fighter_index is None:
            if index in fighter_blue.index:
                temp_blue_frame = temp_blue_frame.append(s)
            elif index in fighter_red.index:
                temp_red_frame = temp_red_frame.append(s)
        elif fighter_index == 'blue':
            temp_blue_frame = temp_blue_frame.append(s)
        elif fighter_index == 'red':
            temp_red_frame = temp_red_frame.append(s)

# %% [markdown]
# ### Adding fighter details like height, weight, reach, stance and dob

# %%
fighter_details = fighter_details[fighter_details.index.isin(fighters)]
for col in fighter_details.columns:
    print(f"Number of NaN in {col} : {fighter_details[col].isnull().sum()}")
# Out:
# Number of NaN in DOB : 0
# Number of NaN in Height : 0
# Number of NaN in Reach : 0
# Number of NaN in Stance : 0
# Number of NaN in Weight : 0
# Number of NaN in fighter_name.1 : 0

# %%
def convert_to_cms(X):
    if X is np.NaN:
        return X
    elif len(X.split("'")) == 2:
        feet = float(X.split("'")[0])
        inches = int(X.split("'")[1].replace(' ', '').replace('"',''))
        return (feet * 30.48) + (inches * 2.54)
    else:
        return float(X.replace('"','')) * 2.54

# %%
fighter_details['Height_cms'] = fighter_details['Height'].apply(convert_to_cms)
fighter_details['Reach_cms'] = fighter_details['Reach'].apply(convert_to_cms)

# %%
fighter_details['Weight_lbs'] = fighter_details['Weight'].apply(lambda X: float(X.replace(' lbs.', '')) if X is not np.NaN else X)

# %%
fighter_details.drop(['Height', 'Weight', 'Reach'], axis=1, inplace=True)

# %%
fighter_details.reset_index(inplace=True)
temp_red_frame.reset_index(inplace=True)
temp_blue_frame.reset_index(inplace=True)

# %%
temp_blue_frame = temp_blue_frame.merge(fighter_details, left_on='hero_fighter', right_on='fighter_name', how='left')
temp_blue_frame.set_index('index', inplace=True)

# %%
temp_blue_frame[['hero_fighter', 'fighter_name', 'Height_cms', 'Weight_lbs', 'DOB']].head(20)
# Out:
#         hero_fighter  fighter_name Height_cms Weight_lbs  DOB
# index
# 3572     Brian Stann           NaN        NaN        NaN  NaN
# 3740     Brian Stann           NaN        NaN        NaN  NaN
# 4058     Brian Stann           NaN        NaN        NaN  NaN
# 4271     Brian Stann           NaN        NaN        NaN  NaN
# 4510     Brian Stann           NaN        NaN        NaN  NaN
# 4679     Brian Stann           NaN        NaN        NaN  NaN
# 115      Mike Grundy           NaN        NaN        NaN  NaN
# 4332     Paul Taylor           NaN        NaN        NaN  NaN
# 4570     Paul Taylor           NaN        NaN        NaN  NaN
# 4801     Paul Taylor           NaN        NaN        NaN  NaN
# 4947     Paul Taylor           NaN        NaN        NaN  NaN
# 5008     Paul Taylor           NaN        NaN        NaN  NaN
# 4673    Andre Gusmao           NaN        NaN        NaN  NaN
# 4835    Andre Gusmao           NaN        NaN        NaN  NaN
# 2974     Phil Harris           NaN        NaN        NaN  NaN
# 3726     Phil Harris           NaN        NaN        NaN  NaN
# 3624   Pascal Krauss           NaN        NaN        NaN  NaN
# 3878   Pascal Krauss           NaN        NaN        NaN  NaN
# 928     Louis Smolka           NaN        NaN        NaN  NaN
# 2375    Louis Smolka           NaN        NaN        NaN  NaN

# %%
temp_red_frame = temp_red_frame.merge(fighter_details, left_on='hero_fighter', right_on='fighter_name', how='left')
temp_red_frame.set_index('index', inplace=True)

# %%
temp_blue_frame.drop('fighter_name', axis=1, inplace=True)
temp_red_frame.drop('fighter_name', axis=1, inplace=True)

# %%
blue_frame = temp_blue_frame.add_prefix('B_')
red_frame = temp_red_frame.add_prefix('R_')

# %%
frame = blue_frame.join(red_frame, how='outer')

# %%
rename_cols = {}
for col in frame.columns:
    if 'hero' in col:
        rename_cols[col] = col.replace('_hero_', '_avg_').replace('.', '')
    if 'opp' in col:
        rename_cols[col] = col.replace('_opp_', '_avg_opp_').replace('.', '')
    if 'win_by' in col:
        rename_cols[col] = col.replace(' ', '').replace('-', '_').replace('\'s', '_')

# %%
frame.rename(rename_cols, axis='columns', inplace=True)

# %%
frame.drop(['R_avg_fighter','B_avg_fighter'], axis=1, inplace=True)

# %%
df2 = df2.join(frame, how='outer')

# %% [markdown]
# ### Create Age

# %%
df2['R_DOB'] = pd.to_datetime(df2['R_DOB'])
df2['B_DOB'] = pd.to_datetime(df2['B_DOB'])
df2['date'] = pd.to_datetime(df2['date'])

# %%
def get_age(row):
    B_age = (row['date'] - row['B_DOB']).days
    R_age = (row['date'] - row['R_DOB']).days
    if np.isnan(B_age)!=True:
        B_age = math.floor(B_age/365.25)
    if np.isnan(R_age)!=True:
        R_age = math.floor(R_age/365.25)
    return pd.Series([B_age, R_age], index=['B_age', 'R_age'])

# %%
df2[['B_age', 'R_age']]= df2[['date', 'R_DOB', 'B_DOB']].apply(get_age, axis=1)

# %%
df2.drop(['R_DOB', 'B_DOB'], axis=1, inplace=True)

# %%
# df2.drop(df2.index[df2['Winner'] == 'draw'], inplace = True)

# %%
# df2.to_csv('data/data.csv', index=False)

# %%
df2
# Out:
#                  R_fighter         B_fighter        Referee       date  \
# 0               Holly Holm      Irene Aldana   Marc Goddard 2020-10-03
# 1         Yorgan De Castro     Carlos Felipe   Kevin Sataki 2020-10-03
# 2     Germaine de Randamie     Julianna Pena            NaN 2020-10-03
# 3           Kyler Phillips      Cameron Else   Marc Goddard 2020-10-03
# 4          Dequan Townsend   Dusko Todorovic   Jason Herzog 2020-10-03
# ...                    ...               ...            ...        ...
# 5773          Orlando Wiet  Robert Lucarelli  John McCarthy 1994-03-11
# 5774         Frank Hamaker   Thaddeus Luster  John McCarthy 1994-03-11
# 5775         Johnny Rhodes     David Levicki  John McCarthy 1994-03-11
# 5776         Patrick Smith        Ray Wizard  John McCarthy 1994-03-11
# 5777          Scott Morris    Sean Daugherty  John McCarthy 1994-03-11
#
#                                         location Winner  title_bout  \
# 0     Abu Dhabi, Abu Dhabi, United Arab Emirates    Red       False
# 1     Abu Dhabi, Abu Dhabi, United Arab Emirates   Blue       False
# 2     Abu Dhabi, Abu Dhabi, United Arab Emirates    Red       False
# 3     Abu Dhabi, Abu Dhabi, United Arab Emirates    Red       False
# 4     Abu Dhabi, Abu Dhabi, United Arab Emirates   Blue       False
# ...                                          ...    ...         ...
# 5773                       Denver, Colorado, USA    Red       False
# 5774                       Denver, Colorado, USA    Red       False
# 5775                       Denver, Colorado, USA    Red       False
# 5776                       Denver, Colorado, USA    Red       False
# 5777                       Denver, Colorado, USA    Red       False
#
#               weight_class  no_of_rounds  B_current_lose_streak  ...  \
# 0     Women's Bantamweight             5                    0.0  ...
# 1              Heavyweight             3                    1.0  ...
# 2     Women's Bantamweight             3                    0.0  ...
# 3             Bantamweight             3                    0.0  ...
# 4             Middleweight             3                    0.0  ...
# ...                    ...           ...                    ...  ...
# 5773           Open Weight             1                    0.0  ...
# 5774           Open Weight             1                    0.0  ...
# 5775           Open Weight             1                    0.0  ...
# 5776           Open Weight             1                    0.0  ...
# 5777           Open Weight             1                    0.0  ...
#
#       R_win_by_Submission  R_win_by_TKO_Doctor_Stoppage  R_wins  R_Stance  \
# 0                     0.0                           0.0     6.0       NaN
# 1                     0.0                           0.0     1.0       NaN
# 2                     0.0                           0.0     6.0       NaN
# 3                     0.0                           0.0     1.0       NaN
# 4                     0.0                           0.0     0.0       NaN
# ...                   ...                           ...     ...       ...
# 5773                  0.0                           0.0     0.0       NaN
# 5774                  0.0                           0.0     0.0       NaN
# 5775                  0.0                           0.0     0.0       NaN
# 5776                  0.0                           0.0     0.0       NaN
# 5777                  0.0                           0.0     0.0       NaN
#
#       R_fighter_name.1  R_Height_cms  R_Reach_cms  R_Weight_lbs  B_age  R_age
# 0                  NaN           NaN          NaN           NaN    NaN    NaN
# 1                  NaN           NaN          NaN           NaN    NaN    NaN
# 2                  NaN           NaN          NaN           NaN    NaN    NaN
# 3                  NaN           NaN          NaN           NaN    NaN    NaN
# 4                  NaN           NaN          NaN           NaN    NaN    NaN
# ...                ...           ...          ...           ...    ...    ...
# 5773               NaN           NaN          NaN           NaN    NaN    NaN
# 5774               NaN           NaN          NaN           NaN    NaN    NaN
# 5775               NaN           NaN          NaN           NaN    NaN    NaN
# 5776               NaN           NaN          NaN           NaN    NaN    NaN
# 5777               NaN           NaN          NaN           NaN    NaN    NaN
#
# [5778 rows x 147 columns]
