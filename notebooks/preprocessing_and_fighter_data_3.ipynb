# %%
from createdata.scrape_fight_links import get_this_event_fight_links
from createdata.scrape_fight_data import create_fight_data_csv

event_links = ['http://ufcstats.com/event-details/b16a7e6a627e9789', 'http://ufcstats.com/event-details/c0c1bc0766df4c00',
              'http://ufcstats.com/event-details/6c9383ffab2725a5', 'http://ufcstats.com/event-details/2f8f3c69522db931',
              'http://ufcstats.com/event-details/9e0f28d1f639ad73', 'http://ufcstats.com/event-details/abcf7e55a0a9ed89']
event_links.reverse()
event_and_fight_links = get_this_event_fight_links(event_links)
create_fight_data_csv(event_and_fight_links, 'new_data.csv')
# Out:
# Scraping all fight data:
# Progress: |██████████████████████████████████████████████████| 100.00% Complete

# %%
import pandas as pd
import numpy as np
import math

df_orig = pd.read_csv('data/total_fight_data.csv', sep=';')
df = pd.read_csv('data/new_data.csv', sep=';')
fighter_details = pd.read_csv('data/fighter_details.csv', index_col='fighter_name')

# %%
df = pd.concat([df, df_orig]).reset_index(drop=True)

# %%
df[:90]
# Out:
#                 R_fighter              B_fighter  R_KD  B_KD  R_SIG_STR.  \
# 0            Max Holloway          Frankie Edgar     0     0  129 of 328
# 1             Cris Cyborg        Felicia Spencer     0     0  122 of 216
# 2              Geoff Neal             Niko Price     0     1    41 of 61
# 3   Olivier Aubin-Mercier        Arman Tsarukyan     0     0    23 of 48
# 4    Marc-Andre Barriault        Krzysztof Jotko     0     0    39 of 77
# 5            Alexis Davis         Viviane Araujo     0     0   68 of 137
# 6           Hakeem Dawodu        Yoshinori Horie     1     0   80 of 154
# 7            Gavin Tucker          SeungWoo Choi     0     0    37 of 62
# 8       Alexandre Pantoja    Deiveson Figueiredo     0     1   61 of 151
# 9       Gillian Robertson            Sarah Frota     0     0    29 of 42
# 10              Erik Koch           Kyle Stewart     0     0    37 of 63
# 11       Rafael Dos Anjos           Leon Edwards     0     0   81 of 169
# 12        Aleksei Oleinik            Walt Harris     0     1      1 of 3
# 13             Greg Hardy             Juan Adams     0     0    36 of 38
# 14             James Vick             Dan Hooker     0     1     7 of 23
# 15    Alexander Hernandez     Francisco Trinaldo     0     0    25 of 91
# 16        Andrei Arlovski           Ben Rothwell     0     0  152 of 263
# 17           Alex Caceres        Steven Peterson     0     0   94 of 197
# 18      Raquel Pennington           Irene Aldana     0     0   47 of 137
# 19              Sam Alvey          Klidson Abreu     0     0    28 of 77
# 20      Roxanne Modafferi          Jennifer Maia     0     0   29 of 110
# 21               Ray Borg          Gabriel Silva     0     0    15 of 23
# 22         Mario Bautista             Jinsoo Son     0     0  129 of 248
# 23        Domingo Pilarte         Felipe Colares     0     0    11 of 21
# 24   Germaine de Randamie             Aspen Ladd     1     0      4 of 5
# 25           Urijah Faber            Ricky Simon     1     0    11 of 15
# 26            Josh Emmett          Mirsad Bektic     1     0    27 of 52
# 27          Karl Roberson      Wellington Turman     0     0    50 of 80
# 28         Marvin Vettori         Cezar Ferreira     0     0   78 of 148
# 29         Mike Rodriguez             John Allan     0     0   70 of 161
# ..                    ...                    ...   ...   ...         ...
# 60         Renato Moicano         Chan Sung Jung     0     1      0 of 3
# 61        Bryan Barberena            Randy Brown     0     1   47 of 101
# 62            Andre Ewell    Anderson Dos Santos     0     0   73 of 173
# 63             Andrea Lee     Montana De La Rosa     0     0   73 of 126
# 64          Kevin Holland     Alessio Di Chirico     0     0   58 of 117
# 65                Dan Ige          Kevin Aguilar     1     0   71 of 125
# 66           Ashley Yoder            Syuri Kondo     0     0   75 of 100
# 67             Matt Wiman              Luis Pena     0     0    24 of 42
# 68          Allen Crowder  Jairzinho Rozenstruik     0     1      0 of 1
# 69          Ariane Lipski           Molly McCann     0     0   68 of 271
# 70             Deron Winn           Eric Spicely     0     0  169 of 367
# 71           Henry Cejudo          Marlon Moraes     0     0   90 of 171
# 72   Valentina Shevchenko            Jessica Eye     1     0     8 of 11
# 73          Tony Ferguson         Donald Cerrone     0     0  104 of 200
# 74          Jimmie Rivera               Petr Yan     0     2   73 of 192
# 75            Tai Tuivasa          Blagoy Ivanov     0     1   64 of 144
# 76         Tatiana Suarez          Nina Ansaroff     0     0   75 of 142
# 77      Aljamain Sterling           Pedro Munhoz     0     0  174 of 349
# 78  Karolina Kowalkiewicz           Alexa Grasso     0     0   90 of 232
# 79          Ricardo Lamas          Calvin Kattar     0     1    12 of 29
# 80            Yan Xiaonan            Angela Hill     0     0   94 of 249
# 81            Bevon Lewis         Darren Stewart     0     0    31 of 84
# 82         Eddie Wineland         Grigorii Popov     2     0   74 of 171
# 83      Katlyn Chookagian      Joanne Calderwood     0     0   82 of 221
# 84   Alexander Gustafsson          Anthony Smith     0     0   72 of 151
# 85            Jimi Manuwa       Aleksandar Rakic     0     1      2 of 3
# 86       Makwan Amirkhani         Chris Fishgold     0     0     9 of 27
# 87         Damir Hadzovic        Christos Giagos     0     0    24 of 61
# 88          Daniel Teymur            Sung Bin Jo     0     0    40 of 83
# 89           Rostem Akman      Sergey Khandozhko     0     1   39 of 100
#
#     B_SIG_STR. R_SIG_STR_pct B_SIG_STR_pct R_TOTAL_STR. B_TOTAL_STR.  \
# 0    96 of 264           39%           36%   131 of 330    96 of 264
# 1     38 of 85           56%           44%   138 of 234    64 of 115
# 2     24 of 57           67%           42%     53 of 73     42 of 79
# 3    47 of 105           47%           44%     36 of 61   110 of 174
# 4    40 of 117           50%           34%    62 of 102    98 of 181
# 5    67 of 148           49%           45%   134 of 213    79 of 162
# 6     39 of 79           51%           49%    89 of 166     41 of 81
# 7     23 of 96           59%           23%     49 of 77    42 of 116
# 8    67 of 113           40%           59%    68 of 160    71 of 117
# 9      9 of 20           69%           45%     51 of 64     33 of 46
# 10    23 of 64           58%           35%     67 of 99    68 of 119
# 11   92 of 215           47%           42%   129 of 219   113 of 244
# 12      4 of 7           33%           57%       1 of 3       4 of 7
# 13      3 of 7           94%           42%     36 of 38       3 of 7
# 14    22 of 41           30%           53%      7 of 23     22 of 41
# 15    25 of 52           27%           48%     26 of 92     28 of 55
# 16   70 of 177           57%           39%   160 of 272    75 of 183
# 17   67 of 218           47%           30%    95 of 198    87 of 241
# 18   52 of 184           34%           28%    86 of 181    75 of 208
# 19    36 of 89           36%           40%    67 of 117    61 of 115
# 20   83 of 174           26%           47%    76 of 161   111 of 205
# 21     8 of 16           65%           50%     23 of 34     58 of 76
# 22   95 of 200           52%           47%   179 of 301   106 of 213
# 23    23 of 42           52%           54%     69 of 89    92 of 132
# 24      0 of 4           80%            0%       4 of 5       0 of 4
# 25      4 of 8           73%           50%     11 of 15       4 of 8
# 26    10 of 65           51%           15%     33 of 60     10 of 65
# 27    25 of 51           62%           49%    79 of 113     38 of 67
# 28    39 of 88           52%           44%   106 of 176     41 of 90
# 29   55 of 128           43%           42%    95 of 186    75 of 154
# ..         ...           ...           ...          ...          ...
# 60    16 of 24            0%           66%       0 of 3     18 of 26
# 61   89 of 152           46%           58%   122 of 178    91 of 154
# 62   35 of 132           42%           26%    74 of 174    63 of 163
# 63   14 of 107           57%           13%    82 of 135    40 of 136
# 64    51 of 84           49%           60%   192 of 253     62 of 97
# 65   33 of 104           56%           31%    92 of 146    65 of 136
# 66    23 of 40           75%           57%   147 of 194     35 of 56
# 67   87 of 148           57%           58%     28 of 46    98 of 160
# 68      4 of 4            0%          100%       0 of 1       4 of 4
# 69  108 of 213           25%           50%    68 of 271   109 of 214
# 70  108 of 224           46%           48%   171 of 369   108 of 224
# 71   57 of 119           52%           47%    99 of 182    59 of 121
# 72     2 of 12           72%           16%     37 of 40     42 of 52
# 73   68 of 185           52%           36%   104 of 200    68 of 185
# 74   56 of 189           38%           29%    76 of 195    58 of 192
# 75   73 of 123           44%           59%    66 of 146    81 of 131
# 76    48 of 99           52%           48%    95 of 166    54 of 105
# 77  105 of 265           49%           39%   175 of 350   108 of 269
# 78  148 of 369           38%           40%    92 of 234   163 of 384
# 79    22 of 41           41%           53%     12 of 29     22 of 41
# 80   71 of 144           37%           49%   105 of 264    78 of 151
# 81    30 of 73           36%           41%     45 of 98     40 of 84
# 82   55 of 150           43%           36%    74 of 171    55 of 150
# 83  112 of 266           37%           42%   108 of 250   141 of 300
# 84   49 of 104           47%           47%    73 of 152    51 of 107
# 85      2 of 7           66%           28%       2 of 3       2 of 7
# 86    16 of 52           33%           30%     18 of 36     16 of 52
# 87   47 of 113           39%           41%     42 of 87    67 of 141
# 88    21 of 63           48%           33%     49 of 93     23 of 65
# 89   60 of 149           39%           40%    40 of 103    60 of 151
#
#             ...            B_GROUND                   win_by last_round  \
# 0           ...              1 of 2     Decision - Unanimous          5
# 1           ...              4 of 6     Decision - Unanimous          3
# 2           ...             4 of 10                   KO/TKO          2
# 3           ...            22 of 29     Decision - Unanimous          3
# 4           ...              0 of 0         Decision - Split          3
# 5           ...              1 of 1     Decision - Unanimous          3
# 6           ...              0 of 0                   KO/TKO          3
# 7           ...              0 of 0               Submission          3
# 8           ...            10 of 16     Decision - Unanimous          3
# 9           ...             6 of 12                   KO/TKO          2
# 10          ...              0 of 0     Decision - Unanimous          3
# 11          ...              3 of 6     Decision - Unanimous          5
# 12          ...              2 of 2                   KO/TKO          1
# 13          ...              0 of 0                   KO/TKO          1
# 14          ...              3 of 3                   KO/TKO          1
# 15          ...              0 of 0     Decision - Unanimous          3
# 16          ...              0 of 0     Decision - Unanimous          3
# 17          ...              2 of 4     Decision - Unanimous          3
# 18          ...              0 of 0         Decision - Split          3
# 19          ...              0 of 0     Decision - Unanimous          3
# 20          ...              1 of 4     Decision - Unanimous          3
# 21          ...              0 of 0     Decision - Unanimous          3
# 22          ...              0 of 0     Decision - Unanimous          3
# 23          ...             7 of 14         Decision - Split          3
# 24          ...              0 of 0                   KO/TKO          1
# 25          ...              0 of 0                   KO/TKO          1
# 26          ...              0 of 0                   KO/TKO          1
# 27          ...            12 of 18         Decision - Split          3
# 28          ...              0 of 0     Decision - Unanimous          3
# 29          ...            15 of 19     Decision - Unanimous          3
# ..          ...                 ...                      ...        ...
# 60          ...            13 of 18                   KO/TKO          1
# 61          ...              0 of 0                   KO/TKO          3
# 62          ...              2 of 5     Decision - Unanimous          3
# 63          ...              0 of 1     Decision - Unanimous          3
# 64          ...              1 of 1     Decision - Unanimous          3
# 65          ...             7 of 11     Decision - Unanimous          3
# 66          ...              3 of 3     Decision - Unanimous          3
# 67          ...            60 of 91                   KO/TKO          3
# 68          ...              3 of 3                   KO/TKO          1
# 69          ...             8 of 15     Decision - Unanimous          3
# 70          ...              0 of 0     Decision - Unanimous          3
# 71          ...              1 of 1                   KO/TKO          3
# 72          ...              0 of 0                   KO/TKO          2
# 73          ...              0 of 0  TKO - Doctor's Stoppage          2
# 74          ...             4 of 10     Decision - Unanimous          3
# 75          ...              6 of 6     Decision - Unanimous          3
# 76          ...              5 of 5     Decision - Unanimous          3
# 77          ...              0 of 0     Decision - Unanimous          3
# 78          ...              0 of 0     Decision - Unanimous          3
# 79          ...              4 of 5                   KO/TKO          1
# 80          ...              2 of 2     Decision - Unanimous          3
# 81          ...              0 of 0     Decision - Unanimous          3
# 82          ...              0 of 0                   KO/TKO          2
# 83          ...              1 of 2     Decision - Unanimous          3
# 84          ...              5 of 5               Submission          4
# 85          ...              0 of 0                   KO/TKO          1
# 86          ...              0 of 0               Submission          2
# 87          ...             3 of 12     Decision - Unanimous          3
# 88          ...              1 of 1     Decision - Unanimous          3
# 89          ...              0 of 0     Decision - Unanimous          3
#
#    last_round_time             Format          Referee           date  \
# 0             5:00  5 Rnd (5-5-5-5-5)        Herb Dean  July 27, 2019
# 1             5:00      3 Rnd (5-5-5)     Yves Lavigne  July 27, 2019
# 2             2:39      3 Rnd (5-5-5)  Dan Miragliotta  July 27, 2019
# 3             5:00      3 Rnd (5-5-5)     Marc Goddard  July 27, 2019
# 4             5:00      3 Rnd (5-5-5)        Herb Dean  July 27, 2019
# 5             5:00      3 Rnd (5-5-5)     Yves Lavigne  July 27, 2019
# 6             4:09      3 Rnd (5-5-5)    Kyle Cardinal  July 27, 2019
# 7             3:17      3 Rnd (5-5-5)     Marc Goddard  July 27, 2019
# 8             5:00      3 Rnd (5-5-5)  Dan Miragliotta  July 27, 2019
# 9             4:13      3 Rnd (5-5-5)    Kyle Cardinal  July 27, 2019
# 10            5:00      3 Rnd (5-5-5)     Marc Goddard  July 27, 2019
# 11            5:00  5 Rnd (5-5-5-5-5)  Dan Miragliotta  July 20, 2019
# 12            0:12      3 Rnd (5-5-5)   Jacob Montalvo  July 20, 2019
# 13            0:45      3 Rnd (5-5-5)  Dan Miragliotta  July 20, 2019
# 14            2:33      3 Rnd (5-5-5)     Kerry Hatley  July 20, 2019
# 15            5:00      3 Rnd (5-5-5)    Frank Collazo  July 20, 2019
# 16            5:00      3 Rnd (5-5-5)     Kerry Hatley  July 20, 2019
# 17            5:00      3 Rnd (5-5-5)  Dan Miragliotta  July 20, 2019
# 18            5:00      3 Rnd (5-5-5)    Frank Collazo  July 20, 2019
# 19            5:00      3 Rnd (5-5-5)   Jacob Montalvo  July 20, 2019
# 20            5:00      3 Rnd (5-5-5)   Jacob Montalvo  July 20, 2019
# 21            5:00      3 Rnd (5-5-5)  Dan Miragliotta  July 20, 2019
# 22            5:00      3 Rnd (5-5-5)     Kerry Hatley  July 20, 2019
# 23            5:00      3 Rnd (5-5-5)    Frank Collazo  July 20, 2019
# 24            0:16  5 Rnd (5-5-5-5-5)        Herb Dean  July 13, 2019
# 25            0:46      3 Rnd (5-5-5)     Mike Beltran  July 13, 2019
# 26            4:25      3 Rnd (5-5-5)     Jason Herzog  July 13, 2019
# 27            5:00      3 Rnd (5-5-5)      Blake Grice  July 13, 2019
# 28            5:00      3 Rnd (5-5-5)        Herb Dean  July 13, 2019
# 29            5:00      3 Rnd (5-5-5)     Mike Beltran  July 13, 2019
# ..             ...                ...              ...            ...
# 60            0:58  5 Rnd (5-5-5-5-5)      Blake Grice  June 22, 2019
# 61            2:54      3 Rnd (5-5-5)  Dan Miragliotta  June 22, 2019
# 62            5:00      3 Rnd (5-5-5)    Gary Copeland  June 22, 2019
# 63            5:00      3 Rnd (5-5-5)    Gary Copeland  June 22, 2019
# 64            5:00      3 Rnd (5-5-5)      Blake Grice  June 22, 2019
# 65            5:00      3 Rnd (5-5-5)      Jimmy Neely  June 22, 2019
# 66            5:00      3 Rnd (5-5-5)    Gary Copeland  June 22, 2019
# 67            1:14      3 Rnd (5-5-5)  Dan Miragliotta  June 22, 2019
# 68            0:09      3 Rnd (5-5-5)      Blake Grice  June 22, 2019
# 69            5:00      3 Rnd (5-5-5)      Jimmy Neely  June 22, 2019
# 70            5:00      3 Rnd (5-5-5)  Dan Miragliotta  June 22, 2019
# 71            4:51  5 Rnd (5-5-5-5-5)     Marc Goddard  June 08, 2019
# 72            0:26  5 Rnd (5-5-5-5-5)  Robert Madrigal  June 08, 2019
# 73            5:00      3 Rnd (5-5-5)  Dan Miragliotta  June 08, 2019
# 74            5:00      3 Rnd (5-5-5)  Kevin MacDonald  June 08, 2019
# 75            5:00      3 Rnd (5-5-5)  Dan Miragliotta  June 08, 2019
# 76            5:00      3 Rnd (5-5-5)  Robert Madrigal  June 08, 2019
# 77            5:00      3 Rnd (5-5-5)     Marc Goddard  June 08, 2019
# 78            5:00      3 Rnd (5-5-5)  Kevin MacDonald  June 08, 2019
# 79            4:06      3 Rnd (5-5-5)  Dan Miragliotta  June 08, 2019
# 80            5:00      3 Rnd (5-5-5)  Robert Madrigal  June 08, 2019
# 81            5:00      3 Rnd (5-5-5)     Marc Goddard  June 08, 2019
# 82            4:47      3 Rnd (5-5-5)  Kevin MacDonald  June 08, 2019
# 83            5:00      3 Rnd (5-5-5)  Dan Miragliotta  June 08, 2019
# 84            2:38  5 Rnd (5-5-5-5-5)     Marc Goddard  June 01, 2019
# 85            0:47      3 Rnd (5-5-5)     Kevin Sataki  June 01, 2019
# 86            4:25      3 Rnd (5-5-5)     Marc Goddard  June 01, 2019
# 87            5:00      3 Rnd (5-5-5)    Rich Mitchell  June 01, 2019
# 88            5:00      3 Rnd (5-5-5)      Rebin Saber  June 01, 2019
# 89            5:00      3 Rnd (5-5-5)     Leon Roberts  June 01, 2019
#
#                            location                        Fight_type  \
# 0         Edmonton, Alberta, Canada      UFC Featherweight Title Bout
# 1         Edmonton, Alberta, Canada        Women's Featherweight Bout
# 2         Edmonton, Alberta, Canada                 Welterweight Bout
# 3         Edmonton, Alberta, Canada                  Lightweight Bout
# 4         Edmonton, Alberta, Canada                 Middleweight Bout
# 5         Edmonton, Alberta, Canada            Women's Flyweight Bout
# 6         Edmonton, Alberta, Canada                Featherweight Bout
# 7         Edmonton, Alberta, Canada                Featherweight Bout
# 8         Edmonton, Alberta, Canada                    Flyweight Bout
# 9         Edmonton, Alberta, Canada            Women's Flyweight Bout
# 10        Edmonton, Alberta, Canada                 Welterweight Bout
# 11          San Antonio, Texas, USA                 Welterweight Bout
# 12          San Antonio, Texas, USA                  Heavyweight Bout
# 13          San Antonio, Texas, USA                  Heavyweight Bout
# 14          San Antonio, Texas, USA                  Lightweight Bout
# 15          San Antonio, Texas, USA                  Lightweight Bout
# 16          San Antonio, Texas, USA                  Heavyweight Bout
# 17          San Antonio, Texas, USA                Featherweight Bout
# 18          San Antonio, Texas, USA         Women's Bantamweight Bout
# 19          San Antonio, Texas, USA            Light Heavyweight Bout
# 20          San Antonio, Texas, USA            Women's Flyweight Bout
# 21          San Antonio, Texas, USA                 Bantamweight Bout
# 22          San Antonio, Texas, USA                 Bantamweight Bout
# 23          San Antonio, Texas, USA                 Bantamweight Bout
# 24      Sacramento, California, USA         Women's Bantamweight Bout
# 25      Sacramento, California, USA                 Bantamweight Bout
# 26      Sacramento, California, USA                Featherweight Bout
# 27      Sacramento, California, USA                 Middleweight Bout
# 28      Sacramento, California, USA                 Middleweight Bout
# 29      Sacramento, California, USA            Light Heavyweight Bout
# ..                              ...                               ...
# 60  Greenville, South Carolina, USA                Featherweight Bout
# 61  Greenville, South Carolina, USA                 Welterweight Bout
# 62  Greenville, South Carolina, USA                 Bantamweight Bout
# 63  Greenville, South Carolina, USA            Women's Flyweight Bout
# 64  Greenville, South Carolina, USA                 Middleweight Bout
# 65  Greenville, South Carolina, USA                Featherweight Bout
# 66  Greenville, South Carolina, USA          Women's Strawweight Bout
# 67  Greenville, South Carolina, USA                  Lightweight Bout
# 68  Greenville, South Carolina, USA                  Heavyweight Bout
# 69  Greenville, South Carolina, USA            Women's Flyweight Bout
# 70  Greenville, South Carolina, USA                 Middleweight Bout
# 71           Chicago, Illinois, USA       UFC Bantamweight Title Bout
# 72           Chicago, Illinois, USA  UFC Women's Flyweight Title Bout
# 73           Chicago, Illinois, USA                  Lightweight Bout
# 74           Chicago, Illinois, USA                 Bantamweight Bout
# 75           Chicago, Illinois, USA                  Heavyweight Bout
# 76           Chicago, Illinois, USA          Women's Strawweight Bout
# 77           Chicago, Illinois, USA                 Bantamweight Bout
# 78           Chicago, Illinois, USA          Women's Strawweight Bout
# 79           Chicago, Illinois, USA                Featherweight Bout
# 80           Chicago, Illinois, USA          Women's Strawweight Bout
# 81           Chicago, Illinois, USA                 Middleweight Bout
# 82           Chicago, Illinois, USA                 Bantamweight Bout
# 83           Chicago, Illinois, USA            Women's Flyweight Bout
# 84                Stockholm, Sweden            Light Heavyweight Bout
# 85                Stockholm, Sweden            Light Heavyweight Bout
# 86                Stockholm, Sweden                Featherweight Bout
# 87                Stockholm, Sweden                  Lightweight Bout
# 88                Stockholm, Sweden                Featherweight Bout
# 89                Stockholm, Sweden                 Welterweight Bout
#
#                    Winner
# 0            Max Holloway
# 1             Cris Cyborg
# 2              Geoff Neal
# 3         Arman Tsarukyan
# 4         Krzysztof Jotko
# 5          Viviane Araujo
# 6           Hakeem Dawodu
# 7            Gavin Tucker
# 8     Deiveson Figueiredo
# 9       Gillian Robertson
# 10              Erik Koch
# 11           Leon Edwards
# 12            Walt Harris
# 13             Greg Hardy
# 14             Dan Hooker
# 15    Alexander Hernandez
# 16        Andrei Arlovski
# 17           Alex Caceres
# 18      Raquel Pennington
# 19          Klidson Abreu
# 20          Jennifer Maia
# 21               Ray Borg
# 22         Mario Bautista
# 23         Felipe Colares
# 24   Germaine de Randamie
# 25           Urijah Faber
# 26            Josh Emmett
# 27          Karl Roberson
# 28         Marvin Vettori
# 29             John Allan
# ..                    ...
# 60         Chan Sung Jung
# 61            Randy Brown
# 62            Andre Ewell
# 63             Andrea Lee
# 64          Kevin Holland
# 65                Dan Ige
# 66           Ashley Yoder
# 67              Luis Pena
# 68  Jairzinho Rozenstruik
# 69           Molly McCann
# 70             Deron Winn
# 71           Henry Cejudo
# 72   Valentina Shevchenko
# 73          Tony Ferguson
# 74               Petr Yan
# 75          Blagoy Ivanov
# 76         Tatiana Suarez
# 77      Aljamain Sterling
# 78           Alexa Grasso
# 79          Calvin Kattar
# 80            Yan Xiaonan
# 81         Darren Stewart
# 82         Eddie Wineland
# 83      Katlyn Chookagian
# 84          Anthony Smith
# 85       Aleksandar Rakic
# 86       Makwan Amirkhani
# 87        Christos Giagos
# 88          Daniel Teymur
# 89      Sergey Khandozhko
#
# [90 rows x 41 columns]

# %%
weight_classes = ['Women\'s Strawweight', 'Women\'s Bantamweight', 
                  'Women\'s Featherweight', 'Women\'s Flyweight', 'Lightweight', 
                  'Welterweight', 'Middleweight','Light Heavyweight', 
                  'Heavyweight', 'Featherweight','Bantamweight', 'Flyweight', 'Open Weight']
columns = ['R_SIG_STR.', 'B_SIG_STR.', 'R_TOTAL_STR.', 'B_TOTAL_STR.',
       'R_TD', 'B_TD', 'R_HEAD', 'B_HEAD', 'R_BODY','B_BODY', 'R_LEG', 'B_LEG', 
        'R_DISTANCE', 'B_DISTANCE', 'R_CLINCH','B_CLINCH', 'R_GROUND', 'B_GROUND']

pct_columns = ['R_SIG_STR_pct','B_SIG_STR_pct', 'R_TD_pct', 'B_TD_pct']

# %%
def make_weight_class(X):
    for weight_class in weight_classes:
        if weight_class in X:
            return weight_class
    if X == 'Catch Weight Bout' or 'Catchweight Bout':
        return 'Catch Weight'
    else:
        return 'Open Weight'

# %%
def get_total_time(row):
    if row['Format'] in time_in_first_round.keys():
        return (row['last_round'] - 1) * time_in_first_round[row['Format']] + row['last_round_time']
    elif row['Format'] in exception_format_time.keys():
        if (row['last_round'] - 1) >= 2:
            return exception_format_time[row['Format']][0] + (row['last_round'] - 2) * \
                    exception_format_time[row['Format']][1] + row['last_round_time']
        else:
            return (row['last_round'] - 1) * exception_format_time[row['Format']][0] + row['last_round_time']
    
# So if the fight ended in round 1, we only need last_round_time. 
# If it ended in round 2, we need the full time of round 1 and the last_round_time
# This works for fights with same time in each round and fights with only two rounds.

# %%
def get_no_of_rounds(X):
    if X == 'No Time Limit':
        return 1
    else:
        return len(X.split('(')[1].replace(')', '').split('-'))

# %%
attempt_suffix = '_att'
landed_suffix = '_landed'

for column in columns:
    df[column+attempt_suffix] = df[column].apply(lambda X: int(X.split('of')[1]))
    df[column+landed_suffix] = df[column].apply(lambda X: int(X.split('of')[0]))
    
df.drop(columns, axis=1, inplace=True)
df['Winner'].fillna('Draw', inplace=True)

for column in pct_columns:
    df[column] = df[column].apply(lambda X: float(X.replace('%', ''))/100)
    
df['title_bout'] = df['Fight_type'].apply(lambda X: True if 'Title Bout' in X else False)
df['weight_class'] = df['Fight_type'].apply(make_weight_class)

time_in_first_round = {'3 Rnd (5-5-5)': 5*60, '5 Rnd (5-5-5-5-5)': 5*60, '1 Rnd + OT (12-3)': 12*60,
       'No Time Limit': 1, '3 Rnd + OT (5-5-5-5)': 5*60, '1 Rnd (20)': 1*20,
       '2 Rnd (5-5)': 5*60, '1 Rnd (15)': 15*60, '1 Rnd (10)': 10*60,
       '1 Rnd (12)':12*60, '1 Rnd + OT (30-5)': 30*60, '1 Rnd (18)': 18*60, '1 Rnd + OT (15-3)': 15*60,
       '1 Rnd (30)': 30*60, '1 Rnd + OT (31-5)': 31*5,
       '1 Rnd + OT (27-3)': 27*60, '1 Rnd + OT (30-3)': 30*60}

exception_format_time = {'1 Rnd + 2OT (15-3-3)': [15*60, 3*60], '1 Rnd + 2OT (24-3-3)': [24*60, 3*60]}

df['last_round_time'] = df['last_round_time'].apply(lambda X: int(X.split(':')[0])*60 + int(X.split(':')[1]))

df['total_time_fought(seconds)'] = df.apply(get_total_time, axis=1)

df['no_of_rounds'] = df['Format'].apply(get_no_of_rounds)

df2 = df.copy()
df2.drop(['Format', 'Fight_type', 'last_round_time','R_KD', 'B_KD', 'R_SIG_STR_pct',
       'B_SIG_STR_pct', 'R_TD_pct', 'B_TD_pct', 'R_SUB_ATT', 'B_SUB_ATT',
       'R_PASS', 'B_PASS', 'R_REV', 'B_REV', 'win_by', 'last_round', 
        'R_SIG_STR._att', 'R_SIG_STR._landed',
       'B_SIG_STR._att', 'B_SIG_STR._landed', 'R_TOTAL_STR._att',
       'R_TOTAL_STR._landed', 'B_TOTAL_STR._att', 'B_TOTAL_STR._landed',
       'R_TD_att', 'R_TD_landed', 'B_TD_att', 'B_TD_landed', 'R_HEAD_att',
       'R_HEAD_landed', 'B_HEAD_att', 'B_HEAD_landed', 'R_BODY_att',
       'R_BODY_landed', 'B_BODY_att', 'B_BODY_landed', 'R_LEG_att',
       'R_LEG_landed', 'B_LEG_att', 'B_LEG_landed', 'R_DISTANCE_att',
       'R_DISTANCE_landed', 'B_DISTANCE_att', 'B_DISTANCE_landed',
       'R_CLINCH_att', 'R_CLINCH_landed', 'B_CLINCH_att', 'B_CLINCH_landed',
       'R_GROUND_att', 'R_GROUND_landed', 'B_GROUND_att', 'B_GROUND_landed',
        'total_time_fought(seconds)'], axis = 1, inplace=True)

# %%
red_fighters = df['R_fighter'].value_counts().index
blue_fighters = df['B_fighter'].value_counts().index

fighters = list(set(red_fighters) | set(blue_fighters))

# %%
def get_renamed_winner(row):
    if row['R_fighter'] == row['Winner']:
        return 'Red'
    elif row['B_fighter'] == row['Winner']:
        return 'Blue'
    elif row['Winner'] == 'Draw':
        return 'Draw'

df2['Winner'] = df2[['R_fighter', 'B_fighter', 'Winner']].apply(get_renamed_winner, axis=1)

# %%
df = pd.concat([df,pd.get_dummies(df['win_by'], prefix='win_by')],axis=1)
df.drop(['win_by'],axis=1, inplace=True)

# %%
Numerical_columns = ['hero_KD', 'opp_KD', 'hero_SIG_STR_pct',
       'opp_SIG_STR_pct', 'hero_TD_pct', 'opp_TD_pct', 'hero_SUB_ATT', 'opp_SUB_ATT',
       'hero_PASS', 'opp_PASS', 'hero_REV', 'opp_REV', 'hero_SIG_STR._att', 'hero_SIG_STR._landed',
       'opp_SIG_STR._att', 'opp_SIG_STR._landed', 'hero_TOTAL_STR._att',
       'hero_TOTAL_STR._landed', 'opp_TOTAL_STR._att', 'opp_TOTAL_STR._landed',
       'hero_TD_att', 'hero_TD_landed', 'opp_TD_att', 'opp_TD_landed', 'hero_HEAD_att',
       'hero_HEAD_landed', 'opp_HEAD_att', 'opp_HEAD_landed', 'hero_BODY_att',
       'hero_BODY_landed', 'opp_BODY_att', 'opp_BODY_landed', 'hero_LEG_att',
       'hero_LEG_landed', 'opp_LEG_att', 'opp_LEG_landed', 'hero_DISTANCE_att',
       'hero_DISTANCE_landed', 'opp_DISTANCE_att', 'opp_DISTANCE_landed',
       'hero_CLINCH_att', 'hero_CLINCH_landed', 'opp_CLINCH_att', 'opp_CLINCH_landed',
       'hero_GROUND_att', 'hero_GROUND_landed', 'opp_GROUND_att', 'opp_GROUND_landed',
       'total_time_fought(seconds)']

Categorical_columns = ['win_by', 'last_round',
        'Winner', 'title_bout']

# %%
import re

def lreplace(pattern, sub, string):
    """
    Replaces 'pattern' in 'string' with 'sub' if 'pattern' starts 'string'.
    """
    return re.sub('^%s' % pattern, sub, string)

# %%
red = df.groupby('R_fighter')
blue = df.groupby('B_fighter')

# %%
def get_fighter_red(fighter_name):
    try:
        fighter_red = red.get_group(fighter_name)
    except:
        return None
    rename_columns = {}
    for column in fighter_red.columns:
        if re.search('^R_', column) is not None:
            rename_columns[column] = lreplace('R_', 'hero_', column)
        elif re.search('^B_', column) is not None:
            rename_columns[column] = lreplace('B_', 'opp_', column)
    fighter_red = fighter_red.rename(rename_columns, axis='columns')
    return fighter_red

# %%
def get_fighter_blue(fighter_name):
    try:
        fighter_blue = blue.get_group(fighter_name)
    except:
        return None
    rename_columns = {}
    for column in fighter_blue.columns:
        if re.search('^B_', column) is not None:
            rename_columns[column] = lreplace('B_', 'hero_', column)
        elif re.search('^R_', column) is not None:
            rename_columns[column] = lreplace('R_', 'opp_', column)
    fighter_blue = fighter_blue.rename(rename_columns, axis='columns')
    return fighter_blue

# %%
def get_result_stats(result_list):
    result_list.reverse() # To get it in ascending order
    current_win_streak = 0
    current_lose_streak = 0
    longest_win_streak = 0
    wins = 0
    losses = 0
    draw = 0
    for result in result_list:
        if result == 'hero':
            wins += 1
            current_win_streak += 1
            current_lose_streak = 0
            if longest_win_streak < current_win_streak:
                longest_win_streak += 1
        elif result == 'opp':
            losses += 1
            current_win_streak = 0
            current_lose_streak += 1
        elif result == 'draw':
            draw += 1
            current_lose_streak = 0
            current_win_streak = 0
            
    return current_win_streak, current_lose_streak, longest_win_streak, wins, losses, draw

# %%
win_by_columns = ['win_by_Decision - Majority', 'win_by_Decision - Split',
       'win_by_Decision - Unanimous', 'win_by_KO/TKO','win_by_Submission',
       'win_by_TKO - Doctor\'s Stoppage']

# %%
temp_blue_frame = pd.DataFrame()
temp_red_frame = pd.DataFrame()
latest_fighter_stats = pd.DataFrame()
result_stats = ['current_win_streak', 'current_lose_streak', 'longest_win_streak', 'wins', 'losses', 'draw']

for fighter_name in fighters:
    fighter_red = get_fighter_red(fighter_name)
    fighter_blue = get_fighter_blue(fighter_name)
    fighter_index = None

    if fighter_red is None:
        fighter = fighter_blue
        fighter_index = 'blue'
    elif fighter_blue is None:
        fighter = fighter_red
        fighter_index = 'red'
    else:
        fighter = pd.concat([fighter_red, fighter_blue]).sort_index()

    fighter['Winner'] = fighter['Winner'].apply(lambda X: 'hero' if X == fighter_name else 'opp')

    latest = fighter[Numerical_columns].mean()
    latest['total_rounds_fought'] = fighter['last_round'].sum()
    latest['total_title_bouts'] = fighter[fighter['title_bout']==True]['title_bout'].count()
    latest['hero_fighter'] = fighter_name
    results = get_result_stats(list(fighter['Winner']))
    for result_stat, result in zip(result_stats, results):
        latest[result_stat] = result
    win_by_results = fighter[fighter['Winner'] == 'hero'][win_by_columns].sum()
    for win_by_column,win_by_result in zip(win_by_columns, win_by_results):
        latest[win_by_column] = win_by_result
    latest.name = fighter_name

    latest_fighter_stats = latest_fighter_stats.append(latest)
    
    for i, index in enumerate(fighter.index):
        fighter_slice = fighter[(i+1):]
        s = fighter_slice[Numerical_columns].mean()
        s['total_rounds_fought'] = fighter_slice['last_round'].sum()
        s['total_title_bouts'] = fighter_slice[fighter_slice['title_bout']==True]['title_bout'].count()
        s['hero_fighter'] = fighter_name
        results = get_result_stats(list(fighter_slice['Winner']))
        for result_stat, result in zip(result_stats, results):
            s[result_stat] = result
        win_by_results = fighter_slice[fighter_slice['Winner'] == 'hero'][win_by_columns].sum()
        for win_by_column,win_by_result in zip(win_by_columns, win_by_results):
            s[win_by_column] = win_by_result
        s.name = index

        if fighter_index is None:
            if index in fighter_blue.index:
                temp_blue_frame = temp_blue_frame.append(s)
            elif index in fighter_red.index:
                temp_red_frame = temp_red_frame.append(s)
        elif fighter_index == 'blue':
            temp_blue_frame = temp_blue_frame.append(s)
        elif fighter_index == 'red':
            temp_red_frame = temp_red_frame.append(s)

# %%
fighter_details = fighter_details[fighter_details.index.isin(fighters)]

# %%
def convert_to_cms(X):
    if X is np.NaN:
        return X
    elif len(X.split("'")) == 2:
        feet = float(X.split("'")[0])
        inches = int(X.split("'")[1].replace(' ', '').replace('"',''))
        return (feet * 30.48) + (inches * 2.54)
    else:
        return float(X.replace('"','')) * 2.54

# %%
fighter_details['Height_cms'] = fighter_details['Height'].apply(convert_to_cms)
fighter_details['Reach_cms'] = fighter_details['Reach'].apply(convert_to_cms)

# %%
fighter_details['Weight_lbs'] = fighter_details['Weight'].apply(lambda X: float(X.replace(' lbs.', '')) if X is not np.NaN else X)

# %%
fighter_details.drop(['Height', 'Weight', 'Reach'], axis=1, inplace=True)

# %%
fighter_details.reset_index(inplace=True)
latest_fighter_stats.reset_index(inplace=True)
temp_red_frame.reset_index(inplace=True)
temp_blue_frame.reset_index(inplace=True)

# %%
temp_blue_frame = temp_blue_frame.merge(fighter_details, left_on='hero_fighter', right_on='fighter_name', how='left')
temp_blue_frame.set_index('index', inplace=True)

# %%
latest_fighter_stats = latest_fighter_stats.merge(fighter_details, left_on='index', right_on='fighter_name', how='left')
latest_fighter_stats.set_index('index', inplace=True)

# %%
temp_red_frame = temp_red_frame.merge(fighter_details, left_on='hero_fighter', right_on='fighter_name', how='left')
temp_red_frame.set_index('index', inplace=True)

# %%
temp_blue_frame.drop('fighter_name', axis=1, inplace=True)
temp_red_frame.drop('fighter_name', axis=1, inplace=True)
latest_fighter_stats.drop('fighter_name', axis=1, inplace=True)

# %%
blue_frame = temp_blue_frame.add_prefix('B_')
red_frame = temp_red_frame.add_prefix('R_')

# %%
frame = blue_frame.join(red_frame, how='outer')

# %%
rename_cols = {}
for col in frame.columns:
    if 'hero' in col:
        rename_cols[col] = col.replace('_hero_', '_avg_').replace('.', '')
    if 'opp' in col:
        rename_cols[col] = col.replace('_opp_', '_avg_opp_').replace('.', '')
    if 'win_by' in col:
        rename_cols[col] = col.replace(' ', '').replace('-', '_').replace('\'s', '_')

# %%
fs_rename_cols = {}
for col in latest_fighter_stats.columns:
    if 'hero' in col:
        fs_rename_cols[col] = col.replace('hero_', 'avg_').replace('.', '')
    if 'opp' in col:
        fs_rename_cols[col] = col.replace('opp_', 'avg_opp_').replace('.', '')
    if 'win_by' in col:
        fs_rename_cols[col] = col.replace(' ', '').replace('-', '_').replace('\'s', '_')

# %%
frame.rename(rename_cols, axis='columns', inplace=True)
latest_fighter_stats.rename(fs_rename_cols, axis='columns', inplace=True)

# %%
frame.drop(['R_avg_fighter','B_avg_fighter'], axis=1, inplace=True)
latest_fighter_stats.drop(['avg_fighter'], axis=1, inplace=True)

# %%
df2 = df2.join(frame, how='outer')

# %%
df2['R_DOB'] = pd.to_datetime(df2['R_DOB'])
df2['B_DOB'] = pd.to_datetime(df2['B_DOB'])
df2['date'] = pd.to_datetime(df2['date'])

# %%
def get_age(row):
    B_age = (row['date'] - row['B_DOB']).days
    R_age = (row['date'] - row['R_DOB']).days
    if np.isnan(B_age)!=True:
        B_age = math.floor(B_age/365.25)
    if np.isnan(R_age)!=True:
        R_age = math.floor(R_age/365.25)
    return pd.Series([B_age, R_age], index=['B_age', 'R_age'])

# %%
df2[['B_age', 'R_age']]= df2[['date', 'R_DOB', 'B_DOB']].apply(get_age, axis=1)

# %%
df2['R_Reach_cms'].fillna(df2['R_Height_cms'], inplace=True)
df2['B_Reach_cms'].fillna(df2['B_Height_cms'], inplace=True)
df2.fillna(df2.median(), inplace=True)

# %%
latest_fighter_stats['Reach_cms'].fillna(latest_fighter_stats['Height_cms'], inplace=True)
latest_fighter_stats.fillna(latest_fighter_stats.median(), inplace=True)

# %%
df2['R_Stance'].fillna('Orthodox', inplace=True)
df2['B_Stance'].fillna('Orthodox', inplace=True)
latest_fighter_stats['Stance'].fillna('Orthodox', inplace=True)

# %%
df2 = pd.concat([df2, pd.get_dummies(df2[['weight_class', 'B_Stance', 'R_Stance']])], axis=1)
df2.drop(columns=['weight_class', 'B_Stance', 'R_Stance', 
                  'location', 'date', 'R_fighter', 'B_fighter', 'R_DOB', 'B_DOB', 'Referee'], inplace=True)
df2.drop(df2.index[df2['Winner'] == 'Draw'], inplace = True)

# %%
latest_fighter_stats = pd.concat([latest_fighter_stats, pd.get_dummies(latest_fighter_stats[['Stance']])], axis=1)
latest_fighter_stats.drop(columns=['Stance'], inplace=True)

# %%
rename_cols = {}
for col in df2.columns:
    rename_cols[col] = col.replace(' ', '').replace('-', '_').replace('\'s', '_')
lfs_rename_cols = {}
for col in latest_fighter_stats.columns:
    lfs_rename_cols[col] = col.replace(' ', '').replace('-', '_').replace('\'s', '_')
df2.rename(rename_cols, axis='columns', inplace=True)
latest_fighter_stats.rename(lfs_rename_cols, axis='columns', inplace=True)

# %%
df2.to_csv('data/new_preprocessed_data.csv', index=False)
latest_fighter_stats.to_csv('data/latest_fighter_stats.csv', index=True)

# %% [markdown]
# ### I have to now deal with
# * `dob` to `age`,
# * adding `weight_class` as dummies,
# * adding `title_bout`,
# * adding `no_of_rounds`,
# * adding `R_` and `B_`

# %%
import pandas as pd
import numpy as np
import math

df_orig = pd.read_csv('data/total_fight_data.csv', sep=';')
df = pd.read_csv('data/new_data.csv', sep=';')
fighter_details = pd.read_csv('data/fighter_details.csv', index_col='fighter_name')

# %%
df = pd.concat([df, df_orig]).reset_index(drop=True)

# %%
weight_classes = ['Women\'s Strawweight', 'Women\'s Bantamweight', 
                  'Women\'s Featherweight', 'Women\'s Flyweight', 'Lightweight', 
                  'Welterweight', 'Middleweight','Light Heavyweight', 
                  'Heavyweight', 'Featherweight','Bantamweight', 'Flyweight', 'Open Weight']

# %%
def make_weight_class(X):
    for weight_class in weight_classes:
        if weight_class in X:
            return weight_class
    if X == 'Catch Weight Bout' or 'Catchweight Bout':
        return 'Catch Weight'
    else:
        return 'Open Weight'

# %%
df['weight_class'] = df['Fight_type'].apply(make_weight_class)

# %%
df = df[['R_fighter', 'B_fighter', 'weight_class']]

# %%
df1 = df[['R_fighter', 'weight_class']].rename(index=str, columns={'R_fighter':'fighter'})
df2 = df[['B_fighter', 'weight_class']].rename(index=str, columns={'B_fighter':'fighter'})

                                               
df3 = pd.concat([df1,df2]).reset_index(drop=True)

# %%
df3 = df3.drop_duplicates().reset_index(drop=True)

df3.to_csv('data/weight_classes.csv', index=False)

# %%
import pandas as pd
import pickle
import numpy as np
import math

df = pd.read_csv('data/latest_fighter_stats.csv', index_col='index')
with open('data/cols.list', 'rb') as c:
    cols = pickle.load(c)

# %%
df_weight_classes = {'Flyweight':'weight_class_Flyweight',
 'Bantamweight':'weight_class_Bantamweight',
 'Featherweight':'weight_class_Featherweight',
 'Lightweight':'weight_class_Lightweight',
 'Welterweight':'weight_class_Welterweight',
 'Middleweight':'weight_class_Middleweight',
 'Light Heavyweight':'weight_class_LightHeavyweight',
 'Heavyweight':'weight_class_Heavyweight',
 'Women\'s Strawweight':'weight_class_Women_Strawweight',
 'Women\'s Flyweight':'weight_class_Women_Flyweight',
 'Women\'s Bantamweight':'weight_class_Women_Bantamweight',
'Women\'s Featherweight':'weight_class_Women_Featherweight',
 'Catch Weight':'weight_class_CatchWeight',
 'Open Weight':'weight_class_OpenWeight'}

# %%
def get_age(X):

    median_age = 29

    DOB = pd.to_datetime(X)
    today = pd.to_datetime('today')

    if pd.isnull(DOB):
        return median_age
    else:
        age = math.floor((today-DOB).days/365.25)
        return age

# %%
title_bout = True
no_of_rounds = 5
weightclass = 'Middleweight'

cols_dict = {df_weight_classes[k]:(1 if weightclass==k else 0) for k in df_weight_classes.keys()}
cols_dict.update({'title_bout':title_bout, 'no_of_rounds':no_of_rounds})

# %%
extra_cols = pd.DataFrame([list(cols_dict.values())], columns=cols_dict.keys())

# %%
df['age'] = df['DOB'].apply(get_age)
df.drop(columns=['DOB'], inplace=True)

# %%
r = df.loc[['Alex Perez']].add_prefix('R_').reset_index(drop=True)
b = df.loc[['Frank Hamaker']].add_prefix('B_').reset_index(drop=True)

# %%
final = pd.concat([r,b,extra_cols], axis=1)[cols]

# %%
final
# Out:
#    title_bout  no_of_rounds  B_current_lose_streak  B_current_win_streak  \
# 0        True             5                    0.0                   1.0
#
#    B_draw  B_avg_BODY_att  B_avg_BODY_landed  B_avg_CLINCH_att  \
# 0     0.0             0.0                0.0               0.0
#
#    B_avg_CLINCH_landed  B_avg_DISTANCE_att       ...         \
# 0                  0.0                 1.0       ...
#
#    B_Stance_OpenStance  B_Stance_Orthodox  B_Stance_Sideways  \
# 0                    0                  1                  0
#
#    B_Stance_Southpaw  B_Stance_Switch  R_Stance_OpenStance  R_Stance_Orthodox  \
# 0                  0                0                    0                  1
#
#    R_Stance_Sideways  R_Stance_Southpaw  R_Stance_Switch
# 0                  0                  0                0
#
# [1 rows x 160 columns]

# %%
with open('data/xgb-model-1.sav', 'rb') as mdl:
    model = pickle.load(mdl)
with open('data/standard.scaler', 'rb') as ss:
    scaler = pickle.load(ss)

# %%
model
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=0.8, gamma=0.1, learning_rate=0.1,
#        max_delta_step=0, max_depth=4, min_child_weight=1, missing=nan,
#        n_estimators=244, n_jobs=1, nthread=None,
#        objective='binary:logistic', random_state=0, reg_alpha=0,
#        reg_lambda=1, scale_pos_weight=1, seed=None, silent=True,
#        subsample=0.8)

# %%
def normalize(df: pd.DataFrame, scaler) -> pd.DataFrame:
    df_num = df.select_dtypes(include=[np.float, np.int])
    df[list(df_num.columns)] = scaler.transform(df[list(df_num.columns)])
    return df

# %%
from xgboost import XGBClassifier
from sklearn.preprocessing import StandardScaler

model.predict_proba(np.array(normalize(final, scaler)))
# Out:
# array([[ 0.51440406,  0.48559597]], dtype=float32)

# %%
from xgboost import XGBClassifier
from sklearn.preprocessing import StandardScaler

model.predict_proba(np.array(normalize(final, scaler)))[0]
# Out:
# array([ 0.05455363,  0.94544637], dtype=float32)
